# %% [markdown]
# # Exploring HDF5 (`.h5`) Files

# %%
# %pip install -q -r ../Docs/requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
try:
    import os
    import sys
    import glob
    import h5py
    import numpy as np
    import pandas as pd
    import torch
    import matplotlib.pyplot as plt
except Exception as e:
    print(f"Error : {e}")

# %%
# Print the PyTorch version
print(f"PyTorch version: {torch.__version__}")

# Check if running in Google Colab
if "google.colab" in str(get_ipython()):
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = 'cpu'
        print("GPU not available in Colab, consider enabling a GPU runtime.")
# Running on a local machine
else:
    if torch.backends.mps.is_available():
        device = 'mps'
        print(f"Is Apple MPS (Metal Performance Shader) built? {torch.backends.mps.is_built()}")
        print(f"Is Apple MPS available? {torch.backends.mps.is_available()}")
    elif torch.cuda.is_available():
        device = 'cuda'
    else:
        device = 'cpu'

# TODO: Add support for AMD ROCm GPU if needed

# Print the device being used
print(f"Using device: {device}")
# Out:
# PyTorch version: 2.5.0.dev20240806
# Is Apple MPS (Metal Performance Shader) built? True
# Is Apple MPS available? True
# Using device: mps

# %%
def get_h5_files(base_path):
    # Use glob to find all .h5 files in base_path and its subdirectories
    search_pattern = os.path.join(base_path, '**', '*.h5')
    h5_files = glob.glob(search_pattern, recursive=True)
    return h5_files

# Specify the base directory to search
directory = '../Datasets/NASA-Earthdata/PLOT1'  # Change this path to do a different search

# Get the list of .h5 files
files = get_h5_files(directory)

# Print the list of files
for file in files:
    print(file)

# %%
def explore_file_structure(file_path):
    with h5py.File(file_path, 'r') as file:
        def print_structure(group, indent=0):
            for key in group:
                item = group[key]
                print('  ' * indent + f'{key}/')
                if isinstance(item, h5py.Group):
                    print_structure(item, indent + 1)
                else:
                    print('  ' * (indent + 1) + f'{key} (dataset)')
        
        print(f'Exploring {file_path}:')
        print_structure(file)
        print('-' * 40)

# Apply the exploration to each file
for file in files:
    explore_file_structure(file)

# %%
def examine_datasets(file_path):
    with h5py.File(file_path, 'r') as file:
        def print_dataset_info(dataset):
            print(f'  Dataset: {dataset.name}')
            print(f'    Shape: {dataset.shape}')
            print(f'    Dtype: {dataset.dtype}')
        
        print(f'Examining {file_path}:')
        for key in file.keys():
            item = file[key]
            if isinstance(item, h5py.Dataset):
                print_dataset_info(item)
            elif isinstance(item, h5py.Group):
                for subkey in item.keys():
                    sub_item = item[subkey]
                    if isinstance(sub_item, h5py.Dataset):
                        print_dataset_info(sub_item)
        print('-' * 40)

# Apply the examination to each file
# for file in files:
#     examine_datasets(file)

explore_file_structure(file)
# Out:
# Exploring ../Datasets/NASA-Earthdata/PLOT1/ATL03_20210714222751_03251207_006_01.h5:
# METADATA/
#   AcquisitionInformation/
#     lidar/
#     lidarDocument/
#     platform/
#     platformDocument/
#   DataQuality/
#     CompletenessOmission/
#     DomainConsistency/
#   DatasetIdentification/
#   Extent/
#   Lineage/
#     ANC01/
#     ANC03/
#     ANC04/
#     ANC05/
#     ANC06-01/
#     ANC06-02/
#     ANC06-03/
#     ANC07/
#     ANC08/
#     ANC11/
#     ANC12-01/
#     ANC12-02/
#     ANC19/
#     ANC22/
#     ANC23/
#     ANC25-03/
#     ANC26-03/
#     ANC28/
#     ANC29/
#     ANC36-03/
#     ANC38-03/
#     ANC41/
#     ATL02/
#     Control/
#   ProcessStep/
#     Browse/
#     Metadata/
#     PGE/
#     QA/
#   ProductSpecificationDocument/
#   QADatasetIdentification/
#   SeriesIdentification/
# ancillary_data/
#   atlas_sdp_gps_epoch/
#     atlas_sdp_gps_epoch (dataset)
#   control/
#     control (dataset)
#   data_end_utc/
#     data_end_utc (dataset)
#   data_start_utc/
#     data_start_utc (dataset)
#   end_cycle/
#     end_cycle (dataset)
#   end_delta_time/
#     end_delta_time (dataset)
#   end_geoseg/
#     end_geoseg (dataset)
#   end_gpssow/
#     end_gpssow (dataset)
#   end_gpsweek/
#     end_gpsweek (dataset)
#   end_orbit/
#     end_orbit (dataset)
#   end_region/
#     end_region (dataset)
#   end_rgt/
#     end_rgt (dataset)
#   granule_end_utc/
#     granule_end_utc (dataset)
#   granule_start_utc/
#     granule_start_utc (dataset)
#   release/
#     release (dataset)
#   start_cycle/
#     start_cycle (dataset)
#   start_delta_time/
#     start_delta_time (dataset)
#   start_geoseg/
#     start_geoseg (dataset)
#   start_gpssow/
#     start_gpssow (dataset)
#   start_gpsweek/
#     start_gpsweek (dataset)
#   start_orbit/
#     start_orbit (dataset)
#   start_region/
#     start_region (dataset)
#   start_rgt/
#     start_rgt (dataset)
#   version/
#     version (dataset)
#   altimetry/
#     atl03_pad/
#       atl03_pad (dataset)
#     band_tol/
#       band_tol (dataset)
#     min_full_sat/
#       min_full_sat (dataset)
#     min_knn/
#       min_knn (dataset)
#     min_near_sat/
#       min_near_sat (dataset)
#     min_sat_h/
#       min_sat_h (dataset)
#     min_scan_s/
#       min_scan_s (dataset)
#     ph_sat_flag/
#       ph_sat_flag (dataset)
#     ph_sat_lb/
#       ph_sat_lb (dataset)
#     ph_sat_ub/
#       ph_sat_ub (dataset)
#     podppd_pad/
#       podppd_pad (dataset)
#     scan_settle_s/
#       scan_settle_s (dataset)
#     win_h/
#       win_h (dataset)
#     win_x/
#       win_x (dataset)
#   atlas_engineering/
#     det_ab_flag/
#       det_ab_flag (dataset)
#     ds_gt/
#       ds_gt (dataset)
#     ds_stat/
#       ds_stat (dataset)
#     hvpc_ab_flag/
#       hvpc_ab_flag (dataset)
#     laser_12_flag/
#       laser_12_flag (dataset)
#     lrs_ab_flag/
#       lrs_ab_flag (dataset)
#     pdu_ab_flag/
#       pdu_ab_flag (dataset)
#     ph_uncorrelated_error/
#       ph_uncorrelated_error (dataset)
#     spd_ab_flag/
#       spd_ab_flag (dataset)
#     tams_ab_flag/
#       tams_ab_flag (dataset)
#     receiver/
#       rx_bckgrd_sensitivity/
#         rx_bckgrd_sensitivity (dataset)
#       rx_return_sensitivity/
#         rx_return_sensitivity (dataset)
#     transmit/
#       tx_pulse_distribution/
#         tx_pulse_distribution (dataset)
#       tx_pulse_energy/
#         tx_pulse_energy (dataset)
#       tx_pulse_skew_est/
#         tx_pulse_skew_est (dataset)
#       tx_pulse_thresh_lower/
#         tx_pulse_thresh_lower (dataset)
#       tx_pulse_thresh_upper/
#         tx_pulse_thresh_upper (dataset)
#       tx_pulse_width_lower/
#         tx_pulse_width_lower (dataset)
#       tx_pulse_width_upper/
#         tx_pulse_width_upper (dataset)
#   calibrations/
#     ds_channel/
#       ds_channel (dataset)
#     dead_time/
#       cal42_product/
#         cal42_product (dataset)
#       side/
#         side (dataset)
#       temperature/
#         temperature (dataset)
#       gt1l/
#         dead_time/
#           dead_time (dataset)
#         sigma/
#           sigma (dataset)
#       gt1r/
#         dead_time/
#           dead_time (dataset)
#         sigma/
#           sigma (dataset)
#       gt2l/
#         dead_time/
#           dead_time (dataset)
#         sigma/
#           sigma (dataset)
#       gt2r/
#         dead_time/
#           dead_time (dataset)
#         sigma/
#           sigma (dataset)
#       gt3l/
#         dead_time/
#           dead_time (dataset)
#         sigma/
#           sigma (dataset)
#       gt3r/
#         dead_time/
#           dead_time (dataset)
#         sigma/
#           sigma (dataset)
#     dead_time_radiometric_signal_loss/
#       cal34_product/
#         cal34_product (dataset)
#       gt1l/
#         dead_time/
#           dead_time (dataset)
#         rad_corr/
#           rad_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt1r/
#         dead_time/
#           dead_time (dataset)
#         rad_corr/
#           rad_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt2l/
#         dead_time/
#           dead_time (dataset)
#         rad_corr/
#           rad_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt2r/
#         dead_time/
#           dead_time (dataset)
#         rad_corr/
#           rad_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt3l/
#         dead_time/
#           dead_time (dataset)
#         rad_corr/
#           rad_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt3r/
#         dead_time/
#           dead_time (dataset)
#         rad_corr/
#           rad_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#     first_photon_bias/
#       cal19_product/
#         cal19_product (dataset)
#       gt1l/
#         dead_time/
#           dead_time (dataset)
#         ffb_corr/
#           ffb_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt1r/
#         dead_time/
#           dead_time (dataset)
#         ffb_corr/
#           ffb_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt2l/
#         dead_time/
#           dead_time (dataset)
#         ffb_corr/
#           ffb_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt2r/
#         dead_time/
#           dead_time (dataset)
#         ffb_corr/
#           ffb_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt3l/
#         dead_time/
#           dead_time (dataset)
#         ffb_corr/
#           ffb_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#       gt3r/
#         dead_time/
#           dead_time (dataset)
#         ffb_corr/
#           ffb_corr (dataset)
#         strength/
#           strength (dataset)
#         width/
#           width (dataset)
#     low_link_impulse_response/
#       bin_width/
#         bin_width (dataset)
#       cal20_product/
#         cal20_product (dataset)
#       hist_x/
#         hist_x (dataset)
#       laser/
#         laser (dataset)
#       mode/
#         mode (dataset)
#       num_bins/
#         num_bins (dataset)
#       return_source/
#         return_source (dataset)
#       side/
#         side (dataset)
#       temperature/
#         temperature (dataset)
#       gt1l/
#         hist/
#           hist (dataset)
#         total_events/
#           total_events (dataset)
#       gt1r/
#         hist/
#           hist (dataset)
#         total_events/
#           total_events (dataset)
#       gt2l/
#         hist/
#           hist (dataset)
#         total_events/
#           total_events (dataset)
#       gt2r/
#         hist/
#           hist (dataset)
#         total_events/
#           total_events (dataset)
#       gt3l/
#         hist/
#           hist (dataset)
#         total_events/
#           total_events (dataset)
#       gt3r/
#         hist/
#           hist (dataset)
#         total_events/
#           total_events (dataset)
#   tep/
#     ds_gt/
#       ds_gt (dataset)
#     min_tep_ph/
#       min_tep_ph (dataset)
#     min_tep_secs/
#       min_tep_secs (dataset)
#     n_tep_bins/
#       n_tep_bins (dataset)
#     tep_bin_size/
#       tep_bin_size (dataset)
#     tep_gap_size/
#       tep_gap_size (dataset)
#     tep_normalize/
#       tep_normalize (dataset)
#     tep_peak_bins/
#       tep_peak_bins (dataset)
#     tep_prim_window/
#       tep_prim_window (dataset)
#     tep_range_prim/
#       tep_range_prim (dataset)
#     tep_rm_noise/
#       tep_rm_noise (dataset)
#     tep_sec_window/
#       tep_sec_window (dataset)
#     tep_start_x/
#       tep_start_x (dataset)
#     tep_valid_spot/
#       tep_valid_spot (dataset)
#   gt2r/
#     signal_find_input/
#       addpad_flag/
#         addpad_flag (dataset)
#       alpha_inc/
#         alpha_inc (dataset)
#       alpha_max/
#         alpha_max (dataset)
#       delta_t_gap_min/
#         delta_t_gap_min (dataset)
#       delta_t_lin_fit/
#         delta_t_lin_fit (dataset)
#       delta_t_max/
#         delta_t_max (dataset)
#       delta_t_min/
#         delta_t_min (dataset)
#       delta_z_bg/
#         delta_z_bg (dataset)
#       delta_zmax2/
#         delta_zmax2 (dataset)
#       delta_zmin/
#         delta_zmin (dataset)
#       e_a/
#         e_a (dataset)
#       e_linfit_edit/
#         e_linfit_edit (dataset)
#       e_linfit_slant/
#         e_linfit_slant (dataset)
#       e_m/
#         e_m (dataset)
#       e_m_mult/
#         e_m_mult (dataset)
#       htspanmin/
#         htspanmin (dataset)
#       lslant_flag/
#         lslant_flag (dataset)
#       min_fit_time_fact/
#         min_fit_time_fact (dataset)
#       n_delta_z1/
#         n_delta_z1 (dataset)
#       n_delta_z2/
#         n_delta_z2 (dataset)
#       nbin_min/
#         nbin_min (dataset)
#       nphot_min/
#         nphot_min (dataset)
#       nslw/
#         nslw (dataset)
#       nslw_v/
#         nslw_v (dataset)
#       out_edit_flag/
#         out_edit_flag (dataset)
#       pc_bckgrd_flag/
#         pc_bckgrd_flag (dataset)
#       r/
#         r (dataset)
#       r2/
#         r2 (dataset)
#       sig_find_t_inc/
#         sig_find_t_inc (dataset)
#       snrlow/
#         snrlow (dataset)
#       snrmed/
#         snrmed (dataset)
#       t_gap_big/
#         t_gap_big (dataset)
#   gt2l/
#     signal_find_input/
#       addpad_flag/
#         addpad_flag (dataset)
#       alpha_inc/
#         alpha_inc (dataset)
#       alpha_max/
#         alpha_max (dataset)
#       delta_t_gap_min/
#         delta_t_gap_min (dataset)
#       delta_t_lin_fit/
#         delta_t_lin_fit (dataset)
#       delta_t_max/
#         delta_t_max (dataset)
#       delta_t_min/
#         delta_t_min (dataset)
#       delta_z_bg/
#         delta_z_bg (dataset)
#       delta_zmax2/
#         delta_zmax2 (dataset)
#       delta_zmin/
#         delta_zmin (dataset)
#       e_a/
#         e_a (dataset)
#       e_linfit_edit/
#         e_linfit_edit (dataset)
#       e_linfit_slant/
#         e_linfit_slant (dataset)
#       e_m/
#         e_m (dataset)
#       e_m_mult/
#         e_m_mult (dataset)
#       htspanmin/
#         htspanmin (dataset)
#       lslant_flag/
#         lslant_flag (dataset)
#       min_fit_time_fact/
#         min_fit_time_fact (dataset)
#       n_delta_z1/
#         n_delta_z1 (dataset)
#       n_delta_z2/
#         n_delta_z2 (dataset)
#       nbin_min/
#         nbin_min (dataset)
#       nphot_min/
#         nphot_min (dataset)
#       nslw/
#         nslw (dataset)
#       nslw_v/
#         nslw_v (dataset)
#       out_edit_flag/
#         out_edit_flag (dataset)
#       pc_bckgrd_flag/
#         pc_bckgrd_flag (dataset)
#       r/
#         r (dataset)
#       r2/
#         r2 (dataset)
#       sig_find_t_inc/
#         sig_find_t_inc (dataset)
#       snrlow/
#         snrlow (dataset)
#       snrmed/
#         snrmed (dataset)
#       t_gap_big/
#         t_gap_big (dataset)
#   gt3r/
#     signal_find_input/
#       addpad_flag/
#         addpad_flag (dataset)
#       alpha_inc/
#         alpha_inc (dataset)
#       alpha_max/
#         alpha_max (dataset)
#       delta_t_gap_min/
#         delta_t_gap_min (dataset)
#       delta_t_lin_fit/
#         delta_t_lin_fit (dataset)
#       delta_t_max/
#         delta_t_max (dataset)
#       delta_t_min/
#         delta_t_min (dataset)
#       delta_z_bg/
#         delta_z_bg (dataset)
#       delta_zmax2/
#         delta_zmax2 (dataset)
#       delta_zmin/
#         delta_zmin (dataset)
#       e_a/
#         e_a (dataset)
#       e_linfit_edit/
#         e_linfit_edit (dataset)
#       e_linfit_slant/
#         e_linfit_slant (dataset)
#       e_m/
#         e_m (dataset)
#       e_m_mult/
#         e_m_mult (dataset)
#       htspanmin/
#         htspanmin (dataset)
#       lslant_flag/
#         lslant_flag (dataset)
#       min_fit_time_fact/
#         min_fit_time_fact (dataset)
#       n_delta_z1/
#         n_delta_z1 (dataset)
#       n_delta_z2/
#         n_delta_z2 (dataset)
#       nbin_min/
#         nbin_min (dataset)
#       nphot_min/
#         nphot_min (dataset)
#       nslw/
#         nslw (dataset)
#       nslw_v/
#         nslw_v (dataset)
#       out_edit_flag/
#         out_edit_flag (dataset)
#       pc_bckgrd_flag/
#         pc_bckgrd_flag (dataset)
#       r/
#         r (dataset)
#       r2/
#         r2 (dataset)
#       sig_find_t_inc/
#         sig_find_t_inc (dataset)
#       snrlow/
#         snrlow (dataset)
#       snrmed/
#         snrmed (dataset)
#       t_gap_big/
#         t_gap_big (dataset)
#   gt3l/
#     signal_find_input/
#       addpad_flag/
#         addpad_flag (dataset)
#       alpha_inc/
#         alpha_inc (dataset)
#       alpha_max/
#         alpha_max (dataset)
#       delta_t_gap_min/
#         delta_t_gap_min (dataset)
#       delta_t_lin_fit/
#         delta_t_lin_fit (dataset)
#       delta_t_max/
#         delta_t_max (dataset)
#       delta_t_min/
#         delta_t_min (dataset)
#       delta_z_bg/
#         delta_z_bg (dataset)
#       delta_zmax2/
#         delta_zmax2 (dataset)
#       delta_zmin/
#         delta_zmin (dataset)
#       e_a/
#         e_a (dataset)
#       e_linfit_edit/
#         e_linfit_edit (dataset)
#       e_linfit_slant/
#         e_linfit_slant (dataset)
#       e_m/
#         e_m (dataset)
#       e_m_mult/
#         e_m_mult (dataset)
#       htspanmin/
#         htspanmin (dataset)
#       lslant_flag/
#         lslant_flag (dataset)
#       min_fit_time_fact/
#         min_fit_time_fact (dataset)
#       n_delta_z1/
#         n_delta_z1 (dataset)
#       n_delta_z2/
#         n_delta_z2 (dataset)
#       nbin_min/
#         nbin_min (dataset)
#       nphot_min/
#         nphot_min (dataset)
#       nslw/
#         nslw (dataset)
#       nslw_v/
#         nslw_v (dataset)
#       out_edit_flag/
#         out_edit_flag (dataset)
#       pc_bckgrd_flag/
#         pc_bckgrd_flag (dataset)
#       r/
#         r (dataset)
#       r2/
#         r2 (dataset)
#       sig_find_t_inc/
#         sig_find_t_inc (dataset)
#       snrlow/
#         snrlow (dataset)
#       snrmed/
#         snrmed (dataset)
#       t_gap_big/
#         t_gap_big (dataset)
#   gt1r/
#     signal_find_input/
#       addpad_flag/
#         addpad_flag (dataset)
#       alpha_inc/
#         alpha_inc (dataset)
#       alpha_max/
#         alpha_max (dataset)
#       delta_t_gap_min/
#         delta_t_gap_min (dataset)
#       delta_t_lin_fit/
#         delta_t_lin_fit (dataset)
#       delta_t_max/
#         delta_t_max (dataset)
#       delta_t_min/
#         delta_t_min (dataset)
#       delta_z_bg/
#         delta_z_bg (dataset)
#       delta_zmax2/
#         delta_zmax2 (dataset)
#       delta_zmin/
#         delta_zmin (dataset)
#       e_a/
#         e_a (dataset)
#       e_linfit_edit/
#         e_linfit_edit (dataset)
#       e_linfit_slant/
#         e_linfit_slant (dataset)
#       e_m/
#         e_m (dataset)
#       e_m_mult/
#         e_m_mult (dataset)
#       htspanmin/
#         htspanmin (dataset)
#       lslant_flag/
#         lslant_flag (dataset)
#       min_fit_time_fact/
#         min_fit_time_fact (dataset)
#       n_delta_z1/
#         n_delta_z1 (dataset)
#       n_delta_z2/
#         n_delta_z2 (dataset)
#       nbin_min/
#         nbin_min (dataset)
#       nphot_min/
#         nphot_min (dataset)
#       nslw/
#         nslw (dataset)
#       nslw_v/
#         nslw_v (dataset)
#       out_edit_flag/
#         out_edit_flag (dataset)
#       pc_bckgrd_flag/
#         pc_bckgrd_flag (dataset)
#       r/
#         r (dataset)
#       r2/
#         r2 (dataset)
#       sig_find_t_inc/
#         sig_find_t_inc (dataset)
#       snrlow/
#         snrlow (dataset)
#       snrmed/
#         snrmed (dataset)
#       t_gap_big/
#         t_gap_big (dataset)
#   gt1l/
#     signal_find_input/
#       addpad_flag/
#         addpad_flag (dataset)
#       alpha_inc/
#         alpha_inc (dataset)
#       alpha_max/
#         alpha_max (dataset)
#       delta_t_gap_min/
#         delta_t_gap_min (dataset)
#       delta_t_lin_fit/
#         delta_t_lin_fit (dataset)
#       delta_t_max/
#         delta_t_max (dataset)
#       delta_t_min/
#         delta_t_min (dataset)
#       delta_z_bg/
#         delta_z_bg (dataset)
#       delta_zmax2/
#         delta_zmax2 (dataset)
#       delta_zmin/
#         delta_zmin (dataset)
#       e_a/
#         e_a (dataset)
#       e_linfit_edit/
#         e_linfit_edit (dataset)
#       e_linfit_slant/
#         e_linfit_slant (dataset)
#       e_m/
#         e_m (dataset)
#       e_m_mult/
#         e_m_mult (dataset)
#       htspanmin/
#         htspanmin (dataset)
#       lslant_flag/
#         lslant_flag (dataset)
#       min_fit_time_fact/
#         min_fit_time_fact (dataset)
#       n_delta_z1/
#         n_delta_z1 (dataset)
#       n_delta_z2/
#         n_delta_z2 (dataset)
#       nbin_min/
#         nbin_min (dataset)
#       nphot_min/
#         nphot_min (dataset)
#       nslw/
#         nslw (dataset)
#       nslw_v/
#         nslw_v (dataset)
#       out_edit_flag/
#         out_edit_flag (dataset)
#       pc_bckgrd_flag/
#         pc_bckgrd_flag (dataset)
#       r/
#         r (dataset)
#       r2/
#         r2 (dataset)
#       sig_find_t_inc/
#         sig_find_t_inc (dataset)
#       snrlow/
#         snrlow (dataset)
#       snrmed/
#         snrmed (dataset)
#       t_gap_big/
#         t_gap_big (dataset)
# atlas_impulse_response/
#   pce1_spot1/
#     tep_histogram/
#       reference_tep_flag/
#         reference_tep_flag (dataset)
#       tep_bckgrd/
#         tep_bckgrd (dataset)
#       tep_duration/
#         tep_duration (dataset)
#       tep_hist/
#         tep_hist (dataset)
#       tep_hist_sum/
#         tep_hist_sum (dataset)
#       tep_hist_time/
#         tep_hist_time (dataset)
#       tep_tod/
#         tep_tod (dataset)
#   pce2_spot3/
#     tep_histogram/
#       reference_tep_flag/
#         reference_tep_flag (dataset)
#       tep_bckgrd/
#         tep_bckgrd (dataset)
#       tep_duration/
#         tep_duration (dataset)
#       tep_hist/
#         tep_hist (dataset)
#       tep_hist_sum/
#         tep_hist_sum (dataset)
#       tep_hist_time/
#         tep_hist_time (dataset)
#       tep_tod/
#         tep_tod (dataset)
# ds_surf_type/
#   ds_surf_type (dataset)
# ds_xyz/
#   ds_xyz (dataset)
# gt1l/
#   bckgrd_atlas/
#     bckgrd_counts/
#       bckgrd_counts (dataset)
#     bckgrd_counts_reduced/
#       bckgrd_counts_reduced (dataset)
#     bckgrd_hist_top/
#       bckgrd_hist_top (dataset)
#     bckgrd_int_height/
#       bckgrd_int_height (dataset)
#     bckgrd_int_height_reduced/
#       bckgrd_int_height_reduced (dataset)
#     bckgrd_rate/
#       bckgrd_rate (dataset)
#     delta_time/
#       delta_time (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     tlm_height_band1/
#       tlm_height_band1 (dataset)
#     tlm_height_band2/
#       tlm_height_band2 (dataset)
#     tlm_top_band1/
#       tlm_top_band1 (dataset)
#     tlm_top_band2/
#       tlm_top_band2 (dataset)
#   geolocation/
#     altitude_sc/
#       altitude_sc (dataset)
#     bounce_time_offset/
#       bounce_time_offset (dataset)
#     delta_time/
#       delta_time (dataset)
#     full_sat_fract/
#       full_sat_fract (dataset)
#     knn/
#       knn (dataset)
#     near_sat_fract/
#       near_sat_fract (dataset)
#     neutat_delay_derivative/
#       neutat_delay_derivative (dataset)
#     neutat_delay_total/
#       neutat_delay_total (dataset)
#     neutat_ht/
#       neutat_ht (dataset)
#     ph_index_beg/
#       ph_index_beg (dataset)
#     pitch/
#       pitch (dataset)
#     podppd_flag/
#       podppd_flag (dataset)
#     range_bias_corr/
#       range_bias_corr (dataset)
#     ref_azimuth/
#       ref_azimuth (dataset)
#     ref_elev/
#       ref_elev (dataset)
#     reference_photon_index/
#       reference_photon_index (dataset)
#     reference_photon_lat/
#       reference_photon_lat (dataset)
#     reference_photon_lon/
#       reference_photon_lon (dataset)
#     roll/
#       roll (dataset)
#     segment_dist_x/
#       segment_dist_x (dataset)
#     segment_id/
#       segment_id (dataset)
#     segment_length/
#       segment_length (dataset)
#     segment_ph_cnt/
#       segment_ph_cnt (dataset)
#     sigma_across/
#       sigma_across (dataset)
#     sigma_along/
#       sigma_along (dataset)
#     sigma_h/
#       sigma_h (dataset)
#     sigma_lat/
#       sigma_lat (dataset)
#     sigma_lon/
#       sigma_lon (dataset)
#     solar_azimuth/
#       solar_azimuth (dataset)
#     solar_elevation/
#       solar_elevation (dataset)
#     surf_type/
#       surf_type (dataset)
#     tx_pulse_energy/
#       tx_pulse_energy (dataset)
#     tx_pulse_skew_est/
#       tx_pulse_skew_est (dataset)
#     tx_pulse_width_lower/
#       tx_pulse_width_lower (dataset)
#     tx_pulse_width_upper/
#       tx_pulse_width_upper (dataset)
#     velocity_sc/
#       velocity_sc (dataset)
#     yaw/
#       yaw (dataset)
#   geophys_corr/
#     dac/
#       dac (dataset)
#     delta_time/
#       delta_time (dataset)
#     dem_flag/
#       dem_flag (dataset)
#     dem_h/
#       dem_h (dataset)
#     geoid/
#       geoid (dataset)
#     geoid_free2mean/
#       geoid_free2mean (dataset)
#     tide_earth/
#       tide_earth (dataset)
#     tide_earth_free2mean/
#       tide_earth_free2mean (dataset)
#     tide_equilibrium/
#       tide_equilibrium (dataset)
#     tide_load/
#       tide_load (dataset)
#     tide_oc_pole/
#       tide_oc_pole (dataset)
#     tide_ocean/
#       tide_ocean (dataset)
#     tide_pole/
#       tide_pole (dataset)
#   heights/
#     delta_time/
#       delta_time (dataset)
#     dist_ph_across/
#       dist_ph_across (dataset)
#     dist_ph_along/
#       dist_ph_along (dataset)
#     h_ph/
#       h_ph (dataset)
#     lat_ph/
#       lat_ph (dataset)
#     lon_ph/
#       lon_ph (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     ph_id_channel/
#       ph_id_channel (dataset)
#     ph_id_count/
#       ph_id_count (dataset)
#     ph_id_pulse/
#       ph_id_pulse (dataset)
#     quality_ph/
#       quality_ph (dataset)
#     signal_conf_ph/
#       signal_conf_ph (dataset)
#     weight_ph/
#       weight_ph (dataset)
#   signal_find_output/
#     land/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     ocean/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     inlandwater/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
# gt1r/
#   bckgrd_atlas/
#     bckgrd_counts/
#       bckgrd_counts (dataset)
#     bckgrd_counts_reduced/
#       bckgrd_counts_reduced (dataset)
#     bckgrd_hist_top/
#       bckgrd_hist_top (dataset)
#     bckgrd_int_height/
#       bckgrd_int_height (dataset)
#     bckgrd_int_height_reduced/
#       bckgrd_int_height_reduced (dataset)
#     bckgrd_rate/
#       bckgrd_rate (dataset)
#     delta_time/
#       delta_time (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     tlm_height_band1/
#       tlm_height_band1 (dataset)
#     tlm_height_band2/
#       tlm_height_band2 (dataset)
#     tlm_top_band1/
#       tlm_top_band1 (dataset)
#     tlm_top_band2/
#       tlm_top_band2 (dataset)
#   geolocation/
#     altitude_sc/
#       altitude_sc (dataset)
#     bounce_time_offset/
#       bounce_time_offset (dataset)
#     delta_time/
#       delta_time (dataset)
#     full_sat_fract/
#       full_sat_fract (dataset)
#     knn/
#       knn (dataset)
#     near_sat_fract/
#       near_sat_fract (dataset)
#     neutat_delay_derivative/
#       neutat_delay_derivative (dataset)
#     neutat_delay_total/
#       neutat_delay_total (dataset)
#     neutat_ht/
#       neutat_ht (dataset)
#     ph_index_beg/
#       ph_index_beg (dataset)
#     pitch/
#       pitch (dataset)
#     podppd_flag/
#       podppd_flag (dataset)
#     range_bias_corr/
#       range_bias_corr (dataset)
#     ref_azimuth/
#       ref_azimuth (dataset)
#     ref_elev/
#       ref_elev (dataset)
#     reference_photon_index/
#       reference_photon_index (dataset)
#     reference_photon_lat/
#       reference_photon_lat (dataset)
#     reference_photon_lon/
#       reference_photon_lon (dataset)
#     roll/
#       roll (dataset)
#     segment_dist_x/
#       segment_dist_x (dataset)
#     segment_id/
#       segment_id (dataset)
#     segment_length/
#       segment_length (dataset)
#     segment_ph_cnt/
#       segment_ph_cnt (dataset)
#     sigma_across/
#       sigma_across (dataset)
#     sigma_along/
#       sigma_along (dataset)
#     sigma_h/
#       sigma_h (dataset)
#     sigma_lat/
#       sigma_lat (dataset)
#     sigma_lon/
#       sigma_lon (dataset)
#     solar_azimuth/
#       solar_azimuth (dataset)
#     solar_elevation/
#       solar_elevation (dataset)
#     surf_type/
#       surf_type (dataset)
#     tx_pulse_energy/
#       tx_pulse_energy (dataset)
#     tx_pulse_skew_est/
#       tx_pulse_skew_est (dataset)
#     tx_pulse_width_lower/
#       tx_pulse_width_lower (dataset)
#     tx_pulse_width_upper/
#       tx_pulse_width_upper (dataset)
#     velocity_sc/
#       velocity_sc (dataset)
#     yaw/
#       yaw (dataset)
#   geophys_corr/
#     dac/
#       dac (dataset)
#     delta_time/
#       delta_time (dataset)
#     dem_flag/
#       dem_flag (dataset)
#     dem_h/
#       dem_h (dataset)
#     geoid/
#       geoid (dataset)
#     geoid_free2mean/
#       geoid_free2mean (dataset)
#     tide_earth/
#       tide_earth (dataset)
#     tide_earth_free2mean/
#       tide_earth_free2mean (dataset)
#     tide_equilibrium/
#       tide_equilibrium (dataset)
#     tide_load/
#       tide_load (dataset)
#     tide_oc_pole/
#       tide_oc_pole (dataset)
#     tide_ocean/
#       tide_ocean (dataset)
#     tide_pole/
#       tide_pole (dataset)
#   heights/
#     delta_time/
#       delta_time (dataset)
#     dist_ph_across/
#       dist_ph_across (dataset)
#     dist_ph_along/
#       dist_ph_along (dataset)
#     h_ph/
#       h_ph (dataset)
#     lat_ph/
#       lat_ph (dataset)
#     lon_ph/
#       lon_ph (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     ph_id_channel/
#       ph_id_channel (dataset)
#     ph_id_count/
#       ph_id_count (dataset)
#     ph_id_pulse/
#       ph_id_pulse (dataset)
#     quality_ph/
#       quality_ph (dataset)
#     signal_conf_ph/
#       signal_conf_ph (dataset)
#     weight_ph/
#       weight_ph (dataset)
#   signal_find_output/
#     land/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     ocean/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     inlandwater/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
# gt2l/
#   bckgrd_atlas/
#     bckgrd_counts/
#       bckgrd_counts (dataset)
#     bckgrd_counts_reduced/
#       bckgrd_counts_reduced (dataset)
#     bckgrd_hist_top/
#       bckgrd_hist_top (dataset)
#     bckgrd_int_height/
#       bckgrd_int_height (dataset)
#     bckgrd_int_height_reduced/
#       bckgrd_int_height_reduced (dataset)
#     bckgrd_rate/
#       bckgrd_rate (dataset)
#     delta_time/
#       delta_time (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     tlm_height_band1/
#       tlm_height_band1 (dataset)
#     tlm_height_band2/
#       tlm_height_band2 (dataset)
#     tlm_top_band1/
#       tlm_top_band1 (dataset)
#     tlm_top_band2/
#       tlm_top_band2 (dataset)
#   geolocation/
#     altitude_sc/
#       altitude_sc (dataset)
#     bounce_time_offset/
#       bounce_time_offset (dataset)
#     delta_time/
#       delta_time (dataset)
#     full_sat_fract/
#       full_sat_fract (dataset)
#     knn/
#       knn (dataset)
#     near_sat_fract/
#       near_sat_fract (dataset)
#     neutat_delay_derivative/
#       neutat_delay_derivative (dataset)
#     neutat_delay_total/
#       neutat_delay_total (dataset)
#     neutat_ht/
#       neutat_ht (dataset)
#     ph_index_beg/
#       ph_index_beg (dataset)
#     pitch/
#       pitch (dataset)
#     podppd_flag/
#       podppd_flag (dataset)
#     range_bias_corr/
#       range_bias_corr (dataset)
#     ref_azimuth/
#       ref_azimuth (dataset)
#     ref_elev/
#       ref_elev (dataset)
#     reference_photon_index/
#       reference_photon_index (dataset)
#     reference_photon_lat/
#       reference_photon_lat (dataset)
#     reference_photon_lon/
#       reference_photon_lon (dataset)
#     roll/
#       roll (dataset)
#     segment_dist_x/
#       segment_dist_x (dataset)
#     segment_id/
#       segment_id (dataset)
#     segment_length/
#       segment_length (dataset)
#     segment_ph_cnt/
#       segment_ph_cnt (dataset)
#     sigma_across/
#       sigma_across (dataset)
#     sigma_along/
#       sigma_along (dataset)
#     sigma_h/
#       sigma_h (dataset)
#     sigma_lat/
#       sigma_lat (dataset)
#     sigma_lon/
#       sigma_lon (dataset)
#     solar_azimuth/
#       solar_azimuth (dataset)
#     solar_elevation/
#       solar_elevation (dataset)
#     surf_type/
#       surf_type (dataset)
#     tx_pulse_energy/
#       tx_pulse_energy (dataset)
#     tx_pulse_skew_est/
#       tx_pulse_skew_est (dataset)
#     tx_pulse_width_lower/
#       tx_pulse_width_lower (dataset)
#     tx_pulse_width_upper/
#       tx_pulse_width_upper (dataset)
#     velocity_sc/
#       velocity_sc (dataset)
#     yaw/
#       yaw (dataset)
#   geophys_corr/
#     dac/
#       dac (dataset)
#     delta_time/
#       delta_time (dataset)
#     dem_flag/
#       dem_flag (dataset)
#     dem_h/
#       dem_h (dataset)
#     geoid/
#       geoid (dataset)
#     geoid_free2mean/
#       geoid_free2mean (dataset)
#     tide_earth/
#       tide_earth (dataset)
#     tide_earth_free2mean/
#       tide_earth_free2mean (dataset)
#     tide_equilibrium/
#       tide_equilibrium (dataset)
#     tide_load/
#       tide_load (dataset)
#     tide_oc_pole/
#       tide_oc_pole (dataset)
#     tide_ocean/
#       tide_ocean (dataset)
#     tide_pole/
#       tide_pole (dataset)
#   heights/
#     delta_time/
#       delta_time (dataset)
#     dist_ph_across/
#       dist_ph_across (dataset)
#     dist_ph_along/
#       dist_ph_along (dataset)
#     h_ph/
#       h_ph (dataset)
#     lat_ph/
#       lat_ph (dataset)
#     lon_ph/
#       lon_ph (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     ph_id_channel/
#       ph_id_channel (dataset)
#     ph_id_count/
#       ph_id_count (dataset)
#     ph_id_pulse/
#       ph_id_pulse (dataset)
#     quality_ph/
#       quality_ph (dataset)
#     signal_conf_ph/
#       signal_conf_ph (dataset)
#     weight_ph/
#       weight_ph (dataset)
#   signal_find_output/
#     land/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     ocean/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     inlandwater/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
# gt2r/
#   bckgrd_atlas/
#     bckgrd_counts/
#       bckgrd_counts (dataset)
#     bckgrd_counts_reduced/
#       bckgrd_counts_reduced (dataset)
#     bckgrd_hist_top/
#       bckgrd_hist_top (dataset)
#     bckgrd_int_height/
#       bckgrd_int_height (dataset)
#     bckgrd_int_height_reduced/
#       bckgrd_int_height_reduced (dataset)
#     bckgrd_rate/
#       bckgrd_rate (dataset)
#     delta_time/
#       delta_time (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     tlm_height_band1/
#       tlm_height_band1 (dataset)
#     tlm_height_band2/
#       tlm_height_band2 (dataset)
#     tlm_top_band1/
#       tlm_top_band1 (dataset)
#     tlm_top_band2/
#       tlm_top_band2 (dataset)
#   geolocation/
#     altitude_sc/
#       altitude_sc (dataset)
#     bounce_time_offset/
#       bounce_time_offset (dataset)
#     delta_time/
#       delta_time (dataset)
#     full_sat_fract/
#       full_sat_fract (dataset)
#     knn/
#       knn (dataset)
#     near_sat_fract/
#       near_sat_fract (dataset)
#     neutat_delay_derivative/
#       neutat_delay_derivative (dataset)
#     neutat_delay_total/
#       neutat_delay_total (dataset)
#     neutat_ht/
#       neutat_ht (dataset)
#     ph_index_beg/
#       ph_index_beg (dataset)
#     pitch/
#       pitch (dataset)
#     podppd_flag/
#       podppd_flag (dataset)
#     range_bias_corr/
#       range_bias_corr (dataset)
#     ref_azimuth/
#       ref_azimuth (dataset)
#     ref_elev/
#       ref_elev (dataset)
#     reference_photon_index/
#       reference_photon_index (dataset)
#     reference_photon_lat/
#       reference_photon_lat (dataset)
#     reference_photon_lon/
#       reference_photon_lon (dataset)
#     roll/
#       roll (dataset)
#     segment_dist_x/
#       segment_dist_x (dataset)
#     segment_id/
#       segment_id (dataset)
#     segment_length/
#       segment_length (dataset)
#     segment_ph_cnt/
#       segment_ph_cnt (dataset)
#     sigma_across/
#       sigma_across (dataset)
#     sigma_along/
#       sigma_along (dataset)
#     sigma_h/
#       sigma_h (dataset)
#     sigma_lat/
#       sigma_lat (dataset)
#     sigma_lon/
#       sigma_lon (dataset)
#     solar_azimuth/
#       solar_azimuth (dataset)
#     solar_elevation/
#       solar_elevation (dataset)
#     surf_type/
#       surf_type (dataset)
#     tx_pulse_energy/
#       tx_pulse_energy (dataset)
#     tx_pulse_skew_est/
#       tx_pulse_skew_est (dataset)
#     tx_pulse_width_lower/
#       tx_pulse_width_lower (dataset)
#     tx_pulse_width_upper/
#       tx_pulse_width_upper (dataset)
#     velocity_sc/
#       velocity_sc (dataset)
#     yaw/
#       yaw (dataset)
#   geophys_corr/
#     dac/
#       dac (dataset)
#     delta_time/
#       delta_time (dataset)
#     dem_flag/
#       dem_flag (dataset)
#     dem_h/
#       dem_h (dataset)
#     geoid/
#       geoid (dataset)
#     geoid_free2mean/
#       geoid_free2mean (dataset)
#     tide_earth/
#       tide_earth (dataset)
#     tide_earth_free2mean/
#       tide_earth_free2mean (dataset)
#     tide_equilibrium/
#       tide_equilibrium (dataset)
#     tide_load/
#       tide_load (dataset)
#     tide_oc_pole/
#       tide_oc_pole (dataset)
#     tide_ocean/
#       tide_ocean (dataset)
#     tide_pole/
#       tide_pole (dataset)
#   heights/
#     delta_time/
#       delta_time (dataset)
#     dist_ph_across/
#       dist_ph_across (dataset)
#     dist_ph_along/
#       dist_ph_along (dataset)
#     h_ph/
#       h_ph (dataset)
#     lat_ph/
#       lat_ph (dataset)
#     lon_ph/
#       lon_ph (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     ph_id_channel/
#       ph_id_channel (dataset)
#     ph_id_count/
#       ph_id_count (dataset)
#     ph_id_pulse/
#       ph_id_pulse (dataset)
#     quality_ph/
#       quality_ph (dataset)
#     signal_conf_ph/
#       signal_conf_ph (dataset)
#     weight_ph/
#       weight_ph (dataset)
#   signal_find_output/
#     land/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     ocean/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     inlandwater/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
# gt3l/
#   bckgrd_atlas/
#     bckgrd_counts/
#       bckgrd_counts (dataset)
#     bckgrd_counts_reduced/
#       bckgrd_counts_reduced (dataset)
#     bckgrd_hist_top/
#       bckgrd_hist_top (dataset)
#     bckgrd_int_height/
#       bckgrd_int_height (dataset)
#     bckgrd_int_height_reduced/
#       bckgrd_int_height_reduced (dataset)
#     bckgrd_rate/
#       bckgrd_rate (dataset)
#     delta_time/
#       delta_time (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     tlm_height_band1/
#       tlm_height_band1 (dataset)
#     tlm_height_band2/
#       tlm_height_band2 (dataset)
#     tlm_top_band1/
#       tlm_top_band1 (dataset)
#     tlm_top_band2/
#       tlm_top_band2 (dataset)
#   geolocation/
#     altitude_sc/
#       altitude_sc (dataset)
#     bounce_time_offset/
#       bounce_time_offset (dataset)
#     delta_time/
#       delta_time (dataset)
#     full_sat_fract/
#       full_sat_fract (dataset)
#     knn/
#       knn (dataset)
#     near_sat_fract/
#       near_sat_fract (dataset)
#     neutat_delay_derivative/
#       neutat_delay_derivative (dataset)
#     neutat_delay_total/
#       neutat_delay_total (dataset)
#     neutat_ht/
#       neutat_ht (dataset)
#     ph_index_beg/
#       ph_index_beg (dataset)
#     pitch/
#       pitch (dataset)
#     podppd_flag/
#       podppd_flag (dataset)
#     range_bias_corr/
#       range_bias_corr (dataset)
#     ref_azimuth/
#       ref_azimuth (dataset)
#     ref_elev/
#       ref_elev (dataset)
#     reference_photon_index/
#       reference_photon_index (dataset)
#     reference_photon_lat/
#       reference_photon_lat (dataset)
#     reference_photon_lon/
#       reference_photon_lon (dataset)
#     roll/
#       roll (dataset)
#     segment_dist_x/
#       segment_dist_x (dataset)
#     segment_id/
#       segment_id (dataset)
#     segment_length/
#       segment_length (dataset)
#     segment_ph_cnt/
#       segment_ph_cnt (dataset)
#     sigma_across/
#       sigma_across (dataset)
#     sigma_along/
#       sigma_along (dataset)
#     sigma_h/
#       sigma_h (dataset)
#     sigma_lat/
#       sigma_lat (dataset)
#     sigma_lon/
#       sigma_lon (dataset)
#     solar_azimuth/
#       solar_azimuth (dataset)
#     solar_elevation/
#       solar_elevation (dataset)
#     surf_type/
#       surf_type (dataset)
#     tx_pulse_energy/
#       tx_pulse_energy (dataset)
#     tx_pulse_skew_est/
#       tx_pulse_skew_est (dataset)
#     tx_pulse_width_lower/
#       tx_pulse_width_lower (dataset)
#     tx_pulse_width_upper/
#       tx_pulse_width_upper (dataset)
#     velocity_sc/
#       velocity_sc (dataset)
#     yaw/
#       yaw (dataset)
#   geophys_corr/
#     dac/
#       dac (dataset)
#     delta_time/
#       delta_time (dataset)
#     dem_flag/
#       dem_flag (dataset)
#     dem_h/
#       dem_h (dataset)
#     geoid/
#       geoid (dataset)
#     geoid_free2mean/
#       geoid_free2mean (dataset)
#     tide_earth/
#       tide_earth (dataset)
#     tide_earth_free2mean/
#       tide_earth_free2mean (dataset)
#     tide_equilibrium/
#       tide_equilibrium (dataset)
#     tide_load/
#       tide_load (dataset)
#     tide_oc_pole/
#       tide_oc_pole (dataset)
#     tide_ocean/
#       tide_ocean (dataset)
#     tide_pole/
#       tide_pole (dataset)
#   heights/
#     delta_time/
#       delta_time (dataset)
#     dist_ph_across/
#       dist_ph_across (dataset)
#     dist_ph_along/
#       dist_ph_along (dataset)
#     h_ph/
#       h_ph (dataset)
#     lat_ph/
#       lat_ph (dataset)
#     lon_ph/
#       lon_ph (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     ph_id_channel/
#       ph_id_channel (dataset)
#     ph_id_count/
#       ph_id_count (dataset)
#     ph_id_pulse/
#       ph_id_pulse (dataset)
#     quality_ph/
#       quality_ph (dataset)
#     signal_conf_ph/
#       signal_conf_ph (dataset)
#     weight_ph/
#       weight_ph (dataset)
#   signal_find_output/
#     land/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     ocean/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     inlandwater/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
# gt3r/
#   bckgrd_atlas/
#     bckgrd_counts/
#       bckgrd_counts (dataset)
#     bckgrd_counts_reduced/
#       bckgrd_counts_reduced (dataset)
#     bckgrd_hist_top/
#       bckgrd_hist_top (dataset)
#     bckgrd_int_height/
#       bckgrd_int_height (dataset)
#     bckgrd_int_height_reduced/
#       bckgrd_int_height_reduced (dataset)
#     bckgrd_rate/
#       bckgrd_rate (dataset)
#     delta_time/
#       delta_time (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     tlm_height_band1/
#       tlm_height_band1 (dataset)
#     tlm_height_band2/
#       tlm_height_band2 (dataset)
#     tlm_top_band1/
#       tlm_top_band1 (dataset)
#     tlm_top_band2/
#       tlm_top_band2 (dataset)
#   geolocation/
#     altitude_sc/
#       altitude_sc (dataset)
#     bounce_time_offset/
#       bounce_time_offset (dataset)
#     delta_time/
#       delta_time (dataset)
#     full_sat_fract/
#       full_sat_fract (dataset)
#     knn/
#       knn (dataset)
#     near_sat_fract/
#       near_sat_fract (dataset)
#     neutat_delay_derivative/
#       neutat_delay_derivative (dataset)
#     neutat_delay_total/
#       neutat_delay_total (dataset)
#     neutat_ht/
#       neutat_ht (dataset)
#     ph_index_beg/
#       ph_index_beg (dataset)
#     pitch/
#       pitch (dataset)
#     podppd_flag/
#       podppd_flag (dataset)
#     range_bias_corr/
#       range_bias_corr (dataset)
#     ref_azimuth/
#       ref_azimuth (dataset)
#     ref_elev/
#       ref_elev (dataset)
#     reference_photon_index/
#       reference_photon_index (dataset)
#     reference_photon_lat/
#       reference_photon_lat (dataset)
#     reference_photon_lon/
#       reference_photon_lon (dataset)
#     roll/
#       roll (dataset)
#     segment_dist_x/
#       segment_dist_x (dataset)
#     segment_id/
#       segment_id (dataset)
#     segment_length/
#       segment_length (dataset)
#     segment_ph_cnt/
#       segment_ph_cnt (dataset)
#     sigma_across/
#       sigma_across (dataset)
#     sigma_along/
#       sigma_along (dataset)
#     sigma_h/
#       sigma_h (dataset)
#     sigma_lat/
#       sigma_lat (dataset)
#     sigma_lon/
#       sigma_lon (dataset)
#     solar_azimuth/
#       solar_azimuth (dataset)
#     solar_elevation/
#       solar_elevation (dataset)
#     surf_type/
#       surf_type (dataset)
#     tx_pulse_energy/
#       tx_pulse_energy (dataset)
#     tx_pulse_skew_est/
#       tx_pulse_skew_est (dataset)
#     tx_pulse_width_lower/
#       tx_pulse_width_lower (dataset)
#     tx_pulse_width_upper/
#       tx_pulse_width_upper (dataset)
#     velocity_sc/
#       velocity_sc (dataset)
#     yaw/
#       yaw (dataset)
#   geophys_corr/
#     dac/
#       dac (dataset)
#     delta_time/
#       delta_time (dataset)
#     dem_flag/
#       dem_flag (dataset)
#     dem_h/
#       dem_h (dataset)
#     geoid/
#       geoid (dataset)
#     geoid_free2mean/
#       geoid_free2mean (dataset)
#     tide_earth/
#       tide_earth (dataset)
#     tide_earth_free2mean/
#       tide_earth_free2mean (dataset)
#     tide_equilibrium/
#       tide_equilibrium (dataset)
#     tide_load/
#       tide_load (dataset)
#     tide_oc_pole/
#       tide_oc_pole (dataset)
#     tide_ocean/
#       tide_ocean (dataset)
#     tide_pole/
#       tide_pole (dataset)
#   heights/
#     delta_time/
#       delta_time (dataset)
#     dist_ph_across/
#       dist_ph_across (dataset)
#     dist_ph_along/
#       dist_ph_along (dataset)
#     h_ph/
#       h_ph (dataset)
#     lat_ph/
#       lat_ph (dataset)
#     lon_ph/
#       lon_ph (dataset)
#     pce_mframe_cnt/
#       pce_mframe_cnt (dataset)
#     ph_id_channel/
#       ph_id_channel (dataset)
#     ph_id_count/
#       ph_id_count (dataset)
#     ph_id_pulse/
#       ph_id_pulse (dataset)
#     quality_ph/
#       quality_ph (dataset)
#     signal_conf_ph/
#       signal_conf_ph (dataset)
#     weight_ph/
#       weight_ph (dataset)
#   signal_find_output/
#     land/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     ocean/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
#     inlandwater/
#       bckgrd_mean/
#         bckgrd_mean (dataset)
#       bckgrd_sigma/
#         bckgrd_sigma (dataset)
#       delta_time/
#         delta_time (dataset)
#       t_pc_delta/
#         t_pc_delta (dataset)
#       z_pc_delta/
#         z_pc_delta (dataset)
# orbit_info/
#   bounding_polygon_lat1/
#     bounding_polygon_lat1 (dataset)
#   bounding_polygon_lon1/
#     bounding_polygon_lon1 (dataset)
#   crossing_time/
#     crossing_time (dataset)
#   cycle_number/
#     cycle_number (dataset)
#   lan/
#     lan (dataset)
#   orbit_number/
#     orbit_number (dataset)
#   rgt/
#     rgt (dataset)
#   sc_orient/
#     sc_orient (dataset)
#   sc_orient_time/
#     sc_orient_time (dataset)
# quality_assessment/
#   delta_time/
#     delta_time (dataset)
#   qa_granule_fail_reason/
#     qa_granule_fail_reason (dataset)
#   qa_granule_pass_fail/
#     qa_granule_pass_fail (dataset)
#   gt1l/
#     qa_perc_signal_conf_ph_high/
#       qa_perc_signal_conf_ph_high (dataset)
#     qa_perc_signal_conf_ph_low/
#       qa_perc_signal_conf_ph_low (dataset)
#     qa_perc_signal_conf_ph_med/
#       qa_perc_signal_conf_ph_med (dataset)
#     qa_perc_surf_type/
#       qa_perc_surf_type (dataset)
#     qa_total_signal_conf_ph_high/
#       qa_total_signal_conf_ph_high (dataset)
#     qa_total_signal_conf_ph_low/
#       qa_total_signal_conf_ph_low (dataset)
#     qa_total_signal_conf_ph_med/
#       qa_total_signal_conf_ph_med (dataset)
#   gt1r/
#     qa_perc_signal_conf_ph_high/
#       qa_perc_signal_conf_ph_high (dataset)
#     qa_perc_signal_conf_ph_low/
#       qa_perc_signal_conf_ph_low (dataset)
#     qa_perc_signal_conf_ph_med/
#       qa_perc_signal_conf_ph_med (dataset)
#     qa_perc_surf_type/
#       qa_perc_surf_type (dataset)
#     qa_total_signal_conf_ph_high/
#       qa_total_signal_conf_ph_high (dataset)
#     qa_total_signal_conf_ph_low/
#       qa_total_signal_conf_ph_low (dataset)
#     qa_total_signal_conf_ph_med/
#       qa_total_signal_conf_ph_med (dataset)
#   gt2l/
#     qa_perc_signal_conf_ph_high/
#       qa_perc_signal_conf_ph_high (dataset)
#     qa_perc_signal_conf_ph_low/
#       qa_perc_signal_conf_ph_low (dataset)
#     qa_perc_signal_conf_ph_med/
#       qa_perc_signal_conf_ph_med (dataset)
#     qa_perc_surf_type/
#       qa_perc_surf_type (dataset)
#     qa_total_signal_conf_ph_high/
#       qa_total_signal_conf_ph_high (dataset)
#     qa_total_signal_conf_ph_low/
#       qa_total_signal_conf_ph_low (dataset)
#     qa_total_signal_conf_ph_med/
#       qa_total_signal_conf_ph_med (dataset)
#   gt2r/
#     qa_perc_signal_conf_ph_high/
#       qa_perc_signal_conf_ph_high (dataset)
#     qa_perc_signal_conf_ph_low/
#       qa_perc_signal_conf_ph_low (dataset)
#     qa_perc_signal_conf_ph_med/
#       qa_perc_signal_conf_ph_med (dataset)
#     qa_perc_surf_type/
#       qa_perc_surf_type (dataset)
#     qa_total_signal_conf_ph_high/
#       qa_total_signal_conf_ph_high (dataset)
#     qa_total_signal_conf_ph_low/
#       qa_total_signal_conf_ph_low (dataset)
#     qa_total_signal_conf_ph_med/
#       qa_total_signal_conf_ph_med (dataset)
#   gt3l/
#     qa_perc_signal_conf_ph_high/
#       qa_perc_signal_conf_ph_high (dataset)
#     qa_perc_signal_conf_ph_low/
#       qa_perc_signal_conf_ph_low (dataset)
#     qa_perc_signal_conf_ph_med/
#       qa_perc_signal_conf_ph_med (dataset)
#     qa_perc_surf_type/
#       qa_perc_surf_type (dataset)
#     qa_total_signal_conf_ph_high/
#       qa_total_signal_conf_ph_high (dataset)
#     qa_total_signal_conf_ph_low/
#       qa_total_signal_conf_ph_low (dataset)
#     qa_total_signal_conf_ph_med/
#       qa_total_signal_conf_ph_med (dataset)
#   gt3r/
#     qa_perc_signal_conf_ph_high/
#       qa_perc_signal_conf_ph_high (dataset)
#     qa_perc_signal_conf_ph_low/
#       qa_perc_signal_conf_ph_low (dataset)
#     qa_perc_signal_conf_ph_med/
#       qa_perc_signal_conf_ph_med (dataset)
#     qa_perc_surf_type/
#       qa_perc_surf_type (dataset)
#     qa_total_signal_conf_ph_high/
#       qa_total_signal_conf_ph_high (dataset)
#     qa_total_signal_conf_ph_low/
#       qa_total_signal_conf_ph_low (dataset)
#     qa_total_signal_conf_ph_med/
#       qa_total_signal_conf_ph_med (dataset)
# ----------------------------------------
