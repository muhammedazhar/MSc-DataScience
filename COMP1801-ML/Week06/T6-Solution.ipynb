# %% [markdown]
# # COMP1801 Tutorial Week 6 - Neural Networks
# *Dr Peter Soar - 2024/25*
# $\newcommand{\Vec}[1]{\boldsymbol{#1}}$
# $\newcommand{\Mat}[1]{\boldsymbol{#1}}$
#
# This tutorial should be pulling together everything we have been learning so far in supervised learning. Neural Networks can be applied to both Regression and Classification problems to create complex deep learning models which if constructed and trained correctly should generally outperform any traditional linear models we've been dealing with so far. This tutorial should show you how to implement a general neural network using `tensorflow.keras` by combining different types of layers.
#
# For this tutorial, read through and try to understand the text and code examples I have provided (ask your tutor if you have any questions) and there will be a selection of exercises. Attempt these exercises on your own, but do ask your tutor for help if you get stuck.
#
# ### Note: It is strongly advised to USE **GOOGLE COLAB** (not offline environments) when using Tensorflow.
#
# *   Tensorflow enables you to leverage relatively powerful GPUs.
# *   Running Tensorflow to your laptop/PC can be difficult to set up and may cause technical problems during training.
# *   In Colab **Ensure runtime is changed to GPU** to accelerate execution speed.

# %% [markdown]
# #0. Do not forget to import all the Python Libraries being used!

# %%
import numpy as np # A useful package for dealing with mathematical processes, we will be using it this week for vectors and matrices.
import pandas as pd # A common package for viewing tabular data
import sklearn.datasets # We want to be able to access the sklearn datasets again
from sklearn.preprocessing import StandardScaler # We will be using the inbuilt scaling functions sklearn provides
import matplotlib.pyplot as plt # We will be using Matplotlib for our graphs
from sklearn.model_selection import train_test_split # A library that can automatically perform data splitting for us
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score, classification_report, balanced_accuracy_score # Various classification metrics we may find useful

# Below are a wide selection of tensorflow libraries we will need to construct our Neural networks.
from tensorflow.keras.activations import sigmoid, linear, relu, softmax # Activation functions we will use
from tensorflow.keras.models import Model, Sequential # Different mays of constructing models, we will primarily be covering the 'functional api' which uses `Model`
from tensorflow.keras.optimizers import SGD # We will be using the SGD optimiser today, though there are other options you may want to explore (such as Adam)
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy, CategoricalCrossentropy, SparseCategoricalCrossentropy  # We will be using TFs MSE loss function for regression and BinaryCross Entropy for classification.
from tensorflow.keras.layers import Input, Dense, Dropout # The layers we will be using to construct our network.
from tensorflow.keras.regularizers import L1, L2 # Regularisation being used in model layers
from tensorflow.keras.metrics import BinaryAccuracy, Accuracy # Accuracy Metric for classification
from tensorflow.keras.callbacks import EarlyStopping # Allows Early Stopping regularisation method.

# %% [markdown]
# #1. Basic pipeline of implementing a neural network model in `tensorflow.keras` (Regression case).
# We can implement various neural networks using `tensorflow.keras`. First, we discuss multi-layer perceptron (fully connected neural network) as the easiest model before going into trying to construct more complicated models in the exercises.

# %% [markdown]
# ## 1.1 Data preparation

# %% [markdown]
# Load the house price data:
#
# To keep things straightforward and get straight to building the Neural Networks, we don't want to deal with data cleansing and EDA. For this reason, we will be take the now very familiar California House Price dataset (and later for classification the breast cancer dataset) as our examples.

# %%
# Load the house price dataset
X_pd, y_pd = sklearn.datasets.fetch_california_housing(return_X_y=True, as_frame=True)

# Display the whole dataset
XY_pd = pd.concat([X_pd, y_pd], axis=1)
display(XY_pd)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %% [markdown]
# Data splitting:
#
# We first convert the data into `numpy.ndarray`, then apply the `sklearn.model_selection.train_test_split` function.

# %%
# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
# While we have 20640 pairs of a feature and target, we use 20% only for the test, not for training and validation.
# `shuffle=True` for non-time series case. You should set `shuffle=False` to avoid future data being contaminated in the training data.
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

# %% [markdown]
# Pre-processing:
#
# Fit a `sklearn.preprocessing.StandardScaler` instance to the training data, then transpose the validation and test data by the instance.
#
# For advanced preprocessing operations for images and text (which we won't be covering in this module, but may be of interest for your MSc projects or in Applied Machine Learning next term), you can also use classes defined in the `tensorflow.keras.preprocessing` module ([see here](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing)).

# %%
scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

# %% [markdown]
# Confirm the shape of the feature matrix:
#
# While it is always a good idea to check the dimensions of your data, this is particularly important when defining a neural network in `tensorflow.keras` as we need to know the shape (dimension) of the input (feature).

# %%
print('The shape of `X_train`:', X_train.shape)
print('The shape of `X_valid`:', X_valid.shape)
print('The shape of `X_test`:', X_test.shape)
# Out:
# The shape of `X_train`: (12384, 8)
# The shape of `X_valid`: (4128, 8)
# The shape of `X_test`: (4128, 8)

# %% [markdown]
# The above results show that, for example, we have 12384 data points in the training data, and the features of each data point is 8-dimensional.

# %% [markdown]
# ## 1.2 Create a neural network model by composing `tensorflow.keras` layers.
# In the machine learning context, many of the models we have been spending a long time working with are defined as a parametrized function, so our task here is how we can achieve that for a Neural Network model.
#
# In `tensorflow.keras`, we define this parametrized function by composing neural network layers, each of which are themselves a Neural Network. Likewise, the graph structure of the neural network is defined by the composition of these layers.

# %% [markdown]
# ### 1.2.1 Define neural network layers
# First, we create layer instances to be composed to define our neural network model. Specifically, we create instances of classes in the `tensorflow.keras.layers` module, specifying an activation function by taking a function in the `tensorflow.keras.activations` module as an `activation` argument in the initializer of the layer class.
#
# As an example, we create `tensorflow.keras.layers.Dense` instances (fully connected layers) in the cell below.
#
# The function defined by the `Dense` layer is as follows:
# $$
# {\Vec{a}^{\mathrm{out}}} = f (\Vec{b} + {\Vec{a}^{\mathrm{in}}} \Mat{W}),
# $$
# where
#
# - ${\Vec{a}^{\mathrm{in}}}$: the input row vector of the layer. We denote the dimensionality of the ${\Vec{a}^{\mathrm{in}}}$ by $n^{\mathrm{in}}$.
# - ${\Vec{a}^{\mathrm{out}}}$: the output row vector of the layer. We denote the dimensionality of the ${\Vec{a}^{\mathrm{out}}}$ by $n^{\mathrm{out}}$. We specify $n^{\mathrm{out}}$ by the `units` parameter in the `Dense` class's initializer.
# - $\Mat{W}$: a matrix of size $n^{\mathrm{in}} \times n^{\mathrm{out}}$ called the "kernel" parameter of the layer. Each parameter of the matrix is a learnable parameter.
# - $\Vec{b}$: an $n^{\mathrm{out}}$-dimensional row vector called the "bias" parameter of the layer. Each parameter of the vector is a learnable parameter.
# - $f$: a scalar function called the "activation function" of the layer. Although $f$ is defined as a scalar function, it is applied to an $n^{\mathrm{out}}$-dimensional vector elementwisely in the layer. Note that $f$ is fixed and not learnable, that is, invariant throughout the training process. The activation function $f$ is specified by the `activation` parameter in the `Dense` class's initializer.
#
# The activation function of the first and second layers we are going to use in this case is the sigmoid function given by `tensorflow.keras.activation.sigmoid` function, and that of the third layer is the identity function given by the `tensorflow.keras.activation.linear` function.
#
# The sigmoid function $\varsigma$ is defined by
# $$
# \varsigma (z) = \frac{1}{1 + \exp(- z)},
# $$
# and the identity function $\mathop{\mathrm{id}}$ is defined by
# $$
# \mathop{\mathrm{id}} (z) = z.
# $$
#
# For other layers, see [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers) and for other activation functions, see [here](https://www.tensorflow.org/api_docs/python/tf/keras/activations). I would say that while traditionally the sigmoid function was widely used in dense layers, it has now been largely superseded as the 'default' choice by the Relu function, which is less computationally expensive and less likely to suffer issues with vanishing gradients.
# $$
# ReLU(z) = max(0,z)
# $$
# Note: For regression problems we should always use the identity function, but the other activations become more important for classification.

# %%
# Define the first `Dense` layer.
# The output dimension is 5, so we specify `units=5`.
# The activation function is the sigmoid function, we specify `activation=sigmoid`.
first_layer = Dense(units=5, activation=sigmoid)

# Define the second `Dense` layer.
# The output dimension is 5, so we specify `units=5`.
# The activation function is the sigmoid function, we specify `activation=sigmoid`.
second_layer = Dense(units=5, activation=sigmoid)

# Define the third `Dense` layer.
# The output dimension is 1, so we specify `units=1`.
# The activation function is the identity function, we specify `activation=linear`.
third_layer = Dense(units=1, activation=linear)

# %% [markdown]
# ### 1.2.2 Compose layers.
#
# First, we create a `tensorflow.keras.layers.Input` instance as a **virtual input**, specifying the input shape as a `shape` argument in the initializer.
# Here, we omit the data size (the number of data points) from the argument. For example, our training data shape (`X_train.shape`) is `(12384, 8)` where the zeroth element indicates the data size and the first element is the number of features/columns, which will be our input. Hence we can manually specify `shape=(8, )` or extract the data using `shape=X_train.shape[1:]`.

# %%
# Extract the number of features for our Networks input dimension
features=X_train.shape[1:]
# Define the "virtual" input
input = Input(shape=features)

# %% [markdown]
# Note: For image processing problems, the input shape is often like `(data_size, width, height, channels)`, meaning we specify `shape=(width, height, channels)`.

# %% [markdown]
# Once we create a `Input` instance, we "call" the first layer instance taking the `Input` instance as an argument.
# Subsequently, we call the second layer instance taking the output of the first layer as an argument. We continue this process for as many layers as we require.

# %%
# Call the layers in a row to get a "virtual" output
output = first_layer(input)
output = second_layer(output)
output = third_layer(output)

# %% [markdown]
# Once we have composed our final virtual output, we can create a `tf.keras.models.Model` instance, taking the virtual input (the `Input` instance) and virtual output (the return value of the last layer). This `Model` instance is the NN model that we have implemented, that can now be trained on data and used to make predictions like we have done with the `linear` model instances in previous weeks.

# %%
# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='multi_layer_perceptron')

# %% [markdown]
# We can show the summary of our model by `summary` method of our `Model` instance. Which is always a good sanity check to ensure that our model seems to be functioning how we would expect.

# %%
model.summary()
# Out:
# Model: "multi_layer_perceptron"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_32 (InputLayer)     │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_103 (Dense)               │ (None, 5)              │            45 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_104 (Dense)               │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_105 (Dense)               │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Note: I am going to be using the TensorFlow functional API for creating Neural Networks in these tutorials. There are other methods, in particular the TensorFlow sequential API is very popular and probably a little easier to gasp from the start (See Appendix 1). The functional API has some advantages that allows for more complicated models to be constructed easily, but the sequential API is also fine for the majority of cases, and I do not mind which method you use to construct your NN's in your coursework.

# %% [markdown]
# ## 1.2.3 Example of the hypothesis function created by above model
# The above neural network represent the composition of the functions represented by the three `Dense` layers. Below is how we would write this NN model in functional form.

# %% [markdown]
# Let ${\Vec{x}}^\top$ be the input row vector. The output $\eta$ of the neural network is given by
# $$
# {\Vec{a}^{[1]}}^\top = \varsigma ({\Vec{b}^{[1]}}^\top + {\Vec{x}}^\top \Mat{W}^{[1]}), \\
# {\Vec{a}^{[2]}}^\top = \varsigma ({\Vec{b}^{[2]}}^\top + {\Vec{a}^{[1]}}^\top \Mat{W}^{[2]}), \\
# \eta = b^{[3]} + {\Vec{a}^{[2]}}^\top \Vec{w}^{[3]}. \\
# $$
# where
#
# - $\Mat{W}^{[1]}$: the "kernel" parameter of the first layer, a matrix of size $8 \times 5$.
# - ${\Vec{b}^{[1]}}^\top$: the "bias" parameter of the first layer, an $5$-dimensional row vector.
# - $\Mat{W}^{[2]}$: the "kernel" parameter of the second layer, a matrix of size $5 \times 5$.
# - ${\Vec{b}^{[2]}}^\top$: the "bias" parameter of the second layer, an $5$-dimensional row vector.
# - $\Vec{w}^{[3]}$: the "kernel" parameter of the third layer, a 5-dimensional row vector.
# - $b^{[3]}$: the "bias" parameter of the third layer, a scalar.
#
# We can also write the function in one line as follows:
#
# $$
# \eta = b^{[3]} + \varsigma ({\Vec{b}^{[2]}}^\top + \varsigma ({\Vec{b}^{[1]}}^\top + {\Vec{x}}^\top \Mat{W}^{[1]}) \Mat{W}^{[2]}) \Vec{w}^{[3]}
# $$
#
# Which really underlines just how the outputs of multi-layered neural networks are really just nested parameterised functions.

# %% [markdown]
# ## 1.3 Training the model.

# %% [markdown]
# ### 1.3.1 "Compile" the model: specifying a loss function and optimizer.
# Now we have defined a machine learning model as a set of parametrized functions, to train the model (or find the optimal parameters) we need to specify a loss function and an optimizer (an optimization algorithm).
#
# We can applly this by "compiling" the model. We execute this process by the `compile` method of the `Model` instance.
#
# In `tensorflow.keras`, we use an instance of a class in the `tensorflow.keras.losses` module as a loss function, and one in the `tensorflow.keras.optimizers` module as an optimizer. Specifically, we take a loss instance and optimizer instance as a `loss` and `optimizer` arguments of the `compile` method.
#
# In the cell below, we use a `tensorflow.keras.losses.MeanSquaredError` instance as a loss function, and a `tensorflow.keras.optimizers.SGD` (vanilla stochastic gradient descent) instance as an optimizer. For other loss functions, see [here](https://www.tensorflow.org/api_docs/python/tf/keras/losses) and for other optimizers, see  [here](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers). `tensorflow.keras.optimizers.Adam` is also often used and ha become a very widely used 'default' optimiser.

# %%
# Compile the model by specifying the optimization algorithm and the loss function.
# Here, we specify the vanilla stochastic gradient descent
# (a `tensorflow.keras.optimizers.SGD` instance) as an optimizer,
# and mean squared error (a `MeanSquaredError` instance) as a loss function.
sgd = SGD(learning_rate=0.01)
mse = MeanSquaredError()
model.compile(optimizer=sgd, loss=mse)

# %% [markdown]
# ### 1.3.2 "Fit" the model to the training data: Optimizing the parameters.
# Similar to a machine learning model instance in `sklearn`, we can train a neural network machine learning model defined by `tensorflow` using the `fit` method. The `fit` method apply the **forwardpropagation and backpropagation** to calculate the gradient vector.
#
# Here, we specify the number of epochs (`epochs`) and the mini batch size (`batch_size`). The definitions of these terms are as follows:
#
# In the optimization by a stochastic gradient descent method, each update does not consider all the training data points at the same time.
# Instead, each update considers a subset of the dataset, called a **mini batch**.
# We first shuffle the training data points and divide them into multiple mini batches.
# Then, we update parameters based on the loss function and gradient vector for each mini batch.
# A pass through the mini batches that cover all the training data points once is called an **epoch**.
# Once we completed the updates based on all the mini batches in an epoch, we shuffle the training data points and divide them into new mini batches again, which begins a new epoch.
#
# For example, if we have 12384 training data points and the mini batch size is 1000, each epoch contains 13 mini batches, where each of the first 12 mini batches contains 1000 training data points and the last mini batch contains 384 data points. Hence, each epoch conducts 13 updates. If the number of epochs is 10, the algorithm updates the parameters 13x10=130 times.
#
# We can also input the validation data. If you input them, the loss function on the validation data will be displayed during the training. Note that the validation data does not affect the training results but can be used to identify overfitting.

# %%
# Train the model.
# `epochs` determines the number of epochs.
# `batch_size` determines the batch_size.
# We don't actually need to save the fit model to a new variable to train our model, but saving the output this ways lets us make a graph of the training and validation performance.
history = model.fit(X_train, y_train, batch_size=1000, epochs=100, validation_data=(X_valid, y_valid))

# Plot validation MSE, alwys nice to have plots to help us visualise things!
plt.plot(history.history['loss'], label='MSE')
plt.plot(history.history['val_loss'], label = 'val_MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(loc='lower right')
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3461 - val_loss: 2.7909
# Epoch 2/100
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_138']. Received: the structure of inputs=*
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3400 - val_loss: 1.6705
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5110 - val_loss: 1.3593
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2978 - val_loss: 1.2715
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2361 - val_loss: 1.2447
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2257 - val_loss: 1.2335
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1967 - val_loss: 1.2268
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2095 - val_loss: 1.2218
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2035 - val_loss: 1.2172
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2111 - val_loss: 1.2130
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2068 - val_loss: 1.2083
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2038 - val_loss: 1.2037
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2028 - val_loss: 1.1994
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1857 - val_loss: 1.1947
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1693 - val_loss: 1.1901
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1818 - val_loss: 1.1856
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1705 - val_loss: 1.1810
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1728 - val_loss: 1.1764
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1850 - val_loss: 1.1716
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1475 - val_loss: 1.1665
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1648 - val_loss: 1.1616
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1669 - val_loss: 1.1568
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1314 - val_loss: 1.1518
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1470 - val_loss: 1.1469
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1300 - val_loss: 1.1421
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1106 - val_loss: 1.1369
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1219 - val_loss: 1.1316
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1315 - val_loss: 1.1264
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1143 - val_loss: 1.1212
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1179 - val_loss: 1.1163
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0939 - val_loss: 1.1106
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1172 - val_loss: 1.1051
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0631 - val_loss: 1.0993
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0928 - val_loss: 1.0940
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1046 - val_loss: 1.0885
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0706 - val_loss: 1.0829
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0680 - val_loss: 1.0771
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0747 - val_loss: 1.0716
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0614 - val_loss: 1.0657
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0731 - val_loss: 1.0599
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0504 - val_loss: 1.0541
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0620 - val_loss: 1.0481
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0416 - val_loss: 1.0422
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0163 - val_loss: 1.0362
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0132 - val_loss: 1.0301
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0093 - val_loss: 1.0243
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0013 - val_loss: 1.0180
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0029 - val_loss: 1.0120
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0097 - val_loss: 1.0061
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0010 - val_loss: 1.0000
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9632 - val_loss: 0.9937
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9757 - val_loss: 0.9877
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9818 - val_loss: 0.9814
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9583 - val_loss: 0.9752
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9510 - val_loss: 0.9693
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9452 - val_loss: 0.9630
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9485 - val_loss: 0.9571
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9288 - val_loss: 0.9510
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9273 - val_loss: 0.9449
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9297 - val_loss: 0.9389
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9252 - val_loss: 0.9330
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9226 - val_loss: 0.9270
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9115 - val_loss: 0.9209
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8958 - val_loss: 0.9150
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8900 - val_loss: 0.9091
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8860 - val_loss: 0.9034
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8673 - val_loss: 0.8976
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8647 - val_loss: 0.8918
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8925 - val_loss: 0.8862
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8897 - val_loss: 0.8805
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8724 - val_loss: 0.8750
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8556 - val_loss: 0.8694
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8599 - val_loss: 0.8640
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8422 - val_loss: 0.8586
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8255 - val_loss: 0.8533
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8183 - val_loss: 0.8482
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8230 - val_loss: 0.8430
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8102 - val_loss: 0.8377
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8223 - val_loss: 0.8327
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8105 - val_loss: 0.8276
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8202 - val_loss: 0.8227
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7781 - val_loss: 0.8178
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8002 - val_loss: 0.8129
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7882 - val_loss: 0.8083
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7812 - val_loss: 0.8035
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7680 - val_loss: 0.7989
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7785 - val_loss: 0.7943
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7657 - val_loss: 0.7897
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7676 - val_loss: 0.7852
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7590 - val_loss: 0.7809
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7514 - val_loss: 0.7765
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7464 - val_loss: 0.7722
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7501 - val_loss: 0.7680
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7522 - val_loss: 0.7639
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7397 - val_loss: 0.7597
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7255 - val_loss: 0.7555
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7170 - val_loss: 0.7515
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7235 - val_loss: 0.7475
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7318 - val_loss: 0.7435
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7180 - val_loss: 0.7395

# %% [markdown]
# You can see that each epoch contains 13 mini batches. `loss` and `val_loss` show the loss (the mean squared error) on the training data and the validation data, respectively. The losses decrease throughout the training and in this case our validation MSE is lower than our training, as both are still continuing to reduce there is no overfitting but we should consider training this model for longer.

# %% [markdown]
# ## 1.4 Evaluation of the NN model
# We can evaluate the loss function on a new dataset by the `evaluate` method of the `Model` instance.

# %%
mse_on_test = model.evaluate(X_test, y_test)
print('The mean squared error on the test data:', mse_on_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 274us/step - loss: 0.7762
# The mean squared error on the test data: 0.7445269227027893

# %% [markdown]
# This MSE looks to be in the same region as we saw for our validation data, so no evidence of overfitting here.
# We can make a prediction using the `predict` method just as we did in the `sklearn` cases. We can see how these predictions compare with our observed values and calculate the score function just as we did with out linear models.

# %%
y_test_pred = model.predict(X_test)

# Plot our predictions
plt.scatter(X_test_raw[:,0], y_test,  color='black', label='y_true') # Observed y values
plt.scatter(X_test_raw[:,0], y_test_pred, color='blue', label='y_pred') # predicted y values
plt.xlabel('MedInc')
plt.ylabel('house price')
plt.legend()
plt.show()

# The R2 score: 1 is perfect prediction
print('R2 score: {:.4f}'.format(sklearn.metrics.r2_score(y_test, y_test_pred)))
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step
# R2 score: 0.4290

# %% [markdown]
# ## 1.5 Exercise 1
# So, our model above is performing okay, but honestly the Neural Network we've made here isn't that great and clearly needs more training if nothing else. Don't spend too long on this, but manually experiment with the model to see if you can make it more accurate (ideally without just training it for 1000's of steps!).
#
# Some things to try changing:
# *   More hidden layers
# *   More units in the hidden layers (remember that we generally want the same number of hidden units in each layer)
# *   Different activation functions in the hidden layers (say `relu` which is probably more appropriate for this type of problem, but you can try others, again these should generally be the same for each layer other than the output.)
# *   Different compiler option hyperparameters such as batch size, number of epochs, learning rate.

# %%
##############################################################
# Your code here
##############################################################
X_pd, y_pd = sklearn.datasets.fetch_california_housing(return_X_y=True, as_frame=True)

X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()


X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

first_layer = Dense(units=128*4, activation=relu)
second_layer = Dense(units=128*4, activation=relu)
third_layer = Dense(units=128*4, activation=relu)
forth_layer = Dense(units=128*4, activation=relu)
fifth_layer = Dense(units=128*4, activation=relu)
out_layer = Dense(units=1, activation=linear)

input = Input(shape=X_train.shape[1:])
output = first_layer(input)
output = second_layer(output)
output = third_layer(output)
output = forth_layer(output)
output = fifth_layer(output)
output = out_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='Exercise_1')
model.summary()
# Out:
# Model: "Exercise_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_33 (InputLayer)     │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_106 (Dense)               │ (None, 512)            │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_107 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_108 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_109 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_110 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_111 (Dense)               │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,055,745 (4.03 MB)
#  Trainable params: 1,055,745 (4.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model by specifying the optimization algorithm and the loss function.
sgd = SGD(learning_rate=0.01)
mse = MeanSquaredError()
model.compile(optimizer=sgd, loss=mse)

# Train the model.
history = model.fit(X_train, y_train, batch_size=1000, epochs=100, validation_data=(X_valid, y_valid), verbose=1)

# Plot validation MSE, alwys nice to have plots to help us visualise things!
plt.plot(history.history['loss'], label='MSE')
plt.plot(history.history['val_loss'], label = 'val_MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(loc='lower right')
# Out:
# Epoch 1/100
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - loss: 5.6018
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_142']. Received: the structure of inputs=*
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2651 - val_loss: 1.8650
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2892 - val_loss: 1.1286
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8415 - val_loss: 0.8137
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.7328 - val_loss: 0.7103
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6769 - val_loss: 0.6699
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6330 - val_loss: 0.6422
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6141 - val_loss: 0.6178
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5866 - val_loss: 0.5966
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5679 - val_loss: 0.5779
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5660 - val_loss: 0.5606
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5341 - val_loss: 0.5451
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5120 - val_loss: 0.5295
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4984 - val_loss: 0.5182
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4924 - val_loss: 0.5031
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4761 - val_loss: 0.4924
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4615 - val_loss: 0.4776
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4574 - val_loss: 0.4678
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4395 - val_loss: 0.4590
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4353 - val_loss: 0.4501
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4208 - val_loss: 0.4467
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4262 - val_loss: 0.4356
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4082 - val_loss: 0.4328
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4072 - val_loss: 0.4236
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4006 - val_loss: 0.4188
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3983 - val_loss: 0.4173
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3864 - val_loss: 0.4081
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3908 - val_loss: 0.4059
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3878 - val_loss: 0.4006
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3676 - val_loss: 0.4041
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3794 - val_loss: 0.3930
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3722 - val_loss: 0.3904
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3750 - val_loss: 0.3882
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3704 - val_loss: 0.3864
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3650 - val_loss: 0.3982
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3619 - val_loss: 0.3811
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3682 - val_loss: 0.3832
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3683 - val_loss: 0.3796
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3516 - val_loss: 0.3764
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3611 - val_loss: 0.3746
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3610 - val_loss: 0.3731
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3477 - val_loss: 0.3736
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3536 - val_loss: 0.3701
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3499 - val_loss: 0.3708
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3460 - val_loss: 0.3689
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3481 - val_loss: 0.3684
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3358 - val_loss: 0.3658
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3412 - val_loss: 0.3703
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3496 - val_loss: 0.3683
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3378 - val_loss: 0.3636
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3432 - val_loss: 0.3629
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3387 - val_loss: 0.3624
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3478 - val_loss: 0.3709
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3369 - val_loss: 0.3615
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3278 - val_loss: 0.3601
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3382 - val_loss: 0.3605
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3382 - val_loss: 0.3615
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3283 - val_loss: 0.3596
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3222 - val_loss: 0.3577
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3417 - val_loss: 0.3561
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3422 - val_loss: 0.3563
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3333 - val_loss: 0.3553
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3299 - val_loss: 0.3542
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3226 - val_loss: 0.3571
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3273 - val_loss: 0.3540
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3244 - val_loss: 0.3537
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3273 - val_loss: 0.3567
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3260 - val_loss: 0.3557
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3269 - val_loss: 0.3552
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3267 - val_loss: 0.3552
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3221 - val_loss: 0.3512
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3221 - val_loss: 0.3525
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3216 - val_loss: 0.3565
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3228 - val_loss: 0.3494
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3215 - val_loss: 0.3594
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3288 - val_loss: 0.3485
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3165 - val_loss: 0.3515
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3256 - val_loss: 0.3487
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3157 - val_loss: 0.3469
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3111 - val_loss: 0.3498
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3200 - val_loss: 0.3485
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3169 - val_loss: 0.3471
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3127 - val_loss: 0.3456
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3170 - val_loss: 0.3445
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3096 - val_loss: 0.3443
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3185 - val_loss: 0.3461
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3119 - val_loss: 0.3427
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3207 - val_loss: 0.3441
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3100 - val_loss: 0.3453
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3047 - val_loss: 0.3437
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3179 - val_loss: 0.3484
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3171 - val_loss: 0.3633
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3178 - val_loss: 0.3413
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3082 - val_loss: 0.3473
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3133 - val_loss: 0.3403
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3130 - val_loss: 0.3426
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2963 - val_loss: 0.3833
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3203 - val_loss: 0.3396
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3021 - val_loss: 0.3581
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3073 - val_loss: 0.3442
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3120 - val_loss: 0.3505

# %%
mse_on_test = model.evaluate(X_test, y_test)
print('The mean squared error on the test data:', mse_on_test)

y_test_pred = model.predict(X_test)

# Plot our predictions
plt.scatter(X_test_raw[:,0], y_test,  color='black', label='y_true') # Observed y values
plt.scatter(X_test_raw[:,0], y_test_pred, color='blue', label='y_pred') # predicted y values
plt.xlabel('MedInc')
plt.ylabel('house price')
plt.legend()
plt.show()

# The R2 score: 1 is perfect prediction
print('R2 score: {:.4f}'.format(sklearn.metrics.r2_score(y_test, y_test_pred)))
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3432
# The mean squared error on the test data: 0.3286275267601013
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R2 score: 0.7480

# %% [markdown]
# # 2. Classification with Neural Networks
#
# Above we were using a Neural network to solve a regression problem. The process is very similar for classification problems, but there are some important distinctions we need to consider.

# %% [markdown]
# ## 2.1 Data preparation

# %% [markdown]
# As with the regression case, all of this should be quite familiar, and in this case we will be using the breast cancer data for our classification task.

# %%
# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_breast_cancer(return_X_y=True, as_frame=True)

# Display the dataset
Xy_pd = pd.concat([X_pd, y_pd], axis=1)
display(Xy_pd)

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
#I'm going to just take a few columns, otherwise the problem is too easy!
X_raw =  X_raw[:,0:2]
y = y_pd.to_numpy()

# Split the data into training/test data
# While we have 569 pairs of a feature and target, we use 20% only for the test, not for training and validation.
# `shuffle=True` for non-time series case. You should set `shuffle=False` to avoid future data being contaminated in the training data.
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %% [markdown]
# Confirm the shape of the feature matrix:
#
# While it is always a good idea to check the dimensions of your data, this is particularly important when defining a neural network in `tensorflow.keras` as we need to know the shape (dimension) of the input (feature).

# %%
print('The shape of `X_train`:', X_train.shape)
print('The shape of `X_valid`:', X_valid.shape)
print('The shape of `X_test`:', X_test.shape)
# Out:
# The shape of `X_train`: (341, 2)
# The shape of `X_valid`: (114, 2)
# The shape of `X_test`: (114, 2)

# %% [markdown]
# The above results show that, for example, we have 341 data points in the training data, and the features for each data point is 30-dimensional.

# %% [markdown]
# ## 2.2 Create a neural network model.
# For classification, we define a discriminant function, which output a real value. This is because the loss function is defined on the output of the discriminant function, not of the hypothesis function, which outputs the target value.
#
# The activation function is very important for our output layer in classification. You can just use a `linear` identify function, but you will have to manually do something to this output to make it work for classification. Generally for binary classification `sigmoid` is uses (as it gives a value between 0 and 1) and for multi class classification `softmax` is used (as it gives a probability for each class).

# %%
# Define the `Dense` layer.
# The output dimension is 1, so we specify `units=1`.
# lets use relu for the dense layer activation this time
# The as we are performing binary classification, we specify `activation=sigmoid`.
dense_layer_1 = Dense(units=10, activation=relu)
output_layer = Dense(units=1, activation=sigmoid)

# Define the "virtual" input
input = Input(shape=X_train.shape[1:])

# Define the "virtual" output
output = dense_layer_1(input)
output = output_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='logistic_regression')

# Output the summary of the model.
model.summary()
# Out:
# Model: "logistic_regression"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_34 (InputLayer)     │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_112 (Dense)               │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_113 (Dense)               │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##2.3 Train the model

# %% [markdown]
# ### 2.3.1 "Compile" the model: specifying a loss function, metrics and an optimizer.
# Since logistic regression's loss function is the cross entropy, we create a `tensorflow.keras.losses.BinaryCrossentropy` instance and specify it as a `loss` argument of the `compile` method of the `Model` instance.
# The binary cross entropy loss is defined as follows:
# $$
# \log (1 + \exp(- y \cdot \eta)),
# $$
# where $y$ is the true target value converted to either 0 or 1 and $\eta$ is the output of the discriminant function.
#
# Also, since we may also wish to observe evaluation metrics different from the loss function in classification, such as the accuracy score, we can specify metrics in the `compile` method. Specifically, we can input a list or tuple of instances of classes in the `tensorflow.keras.metrics` module. In the following cell, we create a `tensorflow.keras.metrics.BinaryAccuracy` instance and specify a list containing the `BinaryAccuracy` instance as a `metrics` argument of the `compile` method of the `Model` instance.
#
# For other metrics, see [here](https://www.tensorflow.org/api_docs/python/tf/keras/metrics).

# %%
# Compile the model by specifying the optimization algorithm and the loss function.
# Here, we specify the vanilla stochastic gradient descent
# (a `tensorflow.keras.optimizers.SGD` instance) as an optimizer,
# and the binary cross entropy function (a `BinaryCrossentropy` instance)
# as a loss function.

# If we want to observe metrics other than the loss function we specified,
# we can also specify the metrics in the `metrics` parameter
# in the `compile` method.

sgd = SGD(learning_rate=0.01)
ce = BinaryCrossentropy()
acc = BinaryAccuracy()
model.compile(optimizer=sgd, loss=ce, metrics=[acc])

# %% [markdown]
# ### 2.3.2 "Fit" the model to the training data: Optimizing the parameters.
# In `tensorflow.keras`, we specify a class weight when we fit the model. Here, we have to specify the weight manually. Specifically, we create a Python dictionary such that keys are the class labels and values indicate the class weight. Revise Lecture 06 for the class weight.

# %%
# Train the model.
# `epochs` determines the number of epochs.
# `batch_size` determines the batch_size.

history = model.fit(X_train, y_train, batch_size=100, epochs=50, validation_data=(X_valid, y_valid))


# Plot validation MSE, always nice to have plots to help us visualise things!
plt.plot(history.history['binary_accuracy'], label='accuracy')
plt.plot(history.history['val_binary_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - binary_accuracy: 0.8253 - loss: 0.5106 - val_binary_accuracy: 0.7982 - val_loss: 0.5371
# Epoch 2/50
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_149']. Received: the structure of inputs=*
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8346 - loss: 0.5178 - val_binary_accuracy: 0.7982 - val_loss: 0.5348
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8213 - loss: 0.5111 - val_binary_accuracy: 0.7982 - val_loss: 0.5325
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8298 - loss: 0.4951 - val_binary_accuracy: 0.7982 - val_loss: 0.5302
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8391 - loss: 0.4996 - val_binary_accuracy: 0.7982 - val_loss: 0.5281
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8328 - loss: 0.4967 - val_binary_accuracy: 0.7982 - val_loss: 0.5259
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8298 - loss: 0.4913 - val_binary_accuracy: 0.7982 - val_loss: 0.5237
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8396 - loss: 0.4935 - val_binary_accuracy: 0.7982 - val_loss: 0.5216
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8458 - loss: 0.4830 - val_binary_accuracy: 0.7982 - val_loss: 0.5195
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8366 - loss: 0.4801 - val_binary_accuracy: 0.7982 - val_loss: 0.5174
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8146 - loss: 0.5021 - val_binary_accuracy: 0.8070 - val_loss: 0.5154
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8325 - loss: 0.4808 - val_binary_accuracy: 0.8070 - val_loss: 0.5133
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8318 - loss: 0.4849 - val_binary_accuracy: 0.8070 - val_loss: 0.5114
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8405 - loss: 0.4771 - val_binary_accuracy: 0.8070 - val_loss: 0.5095
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8477 - loss: 0.4681 - val_binary_accuracy: 0.8070 - val_loss: 0.5076
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8503 - loss: 0.4732 - val_binary_accuracy: 0.8070 - val_loss: 0.5057
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8406 - loss: 0.4656 - val_binary_accuracy: 0.8070 - val_loss: 0.5040
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8346 - loss: 0.4719 - val_binary_accuracy: 0.8070 - val_loss: 0.5021
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8223 - loss: 0.4687 - val_binary_accuracy: 0.8070 - val_loss: 0.5002
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8360 - loss: 0.4677 - val_binary_accuracy: 0.8070 - val_loss: 0.4983
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8323 - loss: 0.4762 - val_binary_accuracy: 0.8070 - val_loss: 0.4964
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8216 - loss: 0.4654 - val_binary_accuracy: 0.8070 - val_loss: 0.4946
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.8350 - loss: 0.4635 - val_binary_accuracy: 0.8070 - val_loss: 0.4928
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8516 - loss: 0.4509 - val_binary_accuracy: 0.8158 - val_loss: 0.4911
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8502 - loss: 0.4652 - val_binary_accuracy: 0.8158 - val_loss: 0.4894
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8462 - loss: 0.4495 - val_binary_accuracy: 0.8158 - val_loss: 0.4877
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8495 - loss: 0.4548 - val_binary_accuracy: 0.8158 - val_loss: 0.4859
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8398 - loss: 0.4540 - val_binary_accuracy: 0.8158 - val_loss: 0.4841
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8359 - loss: 0.4492 - val_binary_accuracy: 0.8158 - val_loss: 0.4824
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8482 - loss: 0.4359 - val_binary_accuracy: 0.8158 - val_loss: 0.4807
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8365 - loss: 0.4444 - val_binary_accuracy: 0.8158 - val_loss: 0.4790
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8363 - loss: 0.4520 - val_binary_accuracy: 0.8158 - val_loss: 0.4775
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8418 - loss: 0.4415 - val_binary_accuracy: 0.8158 - val_loss: 0.4759
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8502 - loss: 0.4428 - val_binary_accuracy: 0.8158 - val_loss: 0.4742
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8505 - loss: 0.4409 - val_binary_accuracy: 0.8158 - val_loss: 0.4726
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8588 - loss: 0.4348 - val_binary_accuracy: 0.8158 - val_loss: 0.4710
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8453 - loss: 0.4339 - val_binary_accuracy: 0.8158 - val_loss: 0.4694
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8580 - loss: 0.4251 - val_binary_accuracy: 0.8158 - val_loss: 0.4679
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8592 - loss: 0.4301 - val_binary_accuracy: 0.8158 - val_loss: 0.4664
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8539 - loss: 0.4337 - val_binary_accuracy: 0.8158 - val_loss: 0.4648
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8462 - loss: 0.4347 - val_binary_accuracy: 0.8158 - val_loss: 0.4632
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8589 - loss: 0.4351 - val_binary_accuracy: 0.8158 - val_loss: 0.4617
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8577 - loss: 0.4319 - val_binary_accuracy: 0.8158 - val_loss: 0.4602
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8444 - loss: 0.4326 - val_binary_accuracy: 0.8246 - val_loss: 0.4586
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8410 - loss: 0.4375 - val_binary_accuracy: 0.8246 - val_loss: 0.4571
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8494 - loss: 0.4294 - val_binary_accuracy: 0.8333 - val_loss: 0.4556
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8680 - loss: 0.4088 - val_binary_accuracy: 0.8333 - val_loss: 0.4542
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8617 - loss: 0.4297 - val_binary_accuracy: 0.8333 - val_loss: 0.4527
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8570 - loss: 0.4186 - val_binary_accuracy: 0.8333 - val_loss: 0.4512
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8707 - loss: 0.4273 - val_binary_accuracy: 0.8333 - val_loss: 0.4498

# %% [markdown]
# You can see that each epoch contains 4 mini batches. `loss` and `val_loss` show the loss function being used (the Binary Cross Entropy) on the training data and the validation data, but now we can also see our chosen accuracy metric for our model.

# %% [markdown]
# ## 2.4 Evaluation of the NN model
# we can calculate the loss and score at the same time using the `evaluate` method of the `Model` instance.

# %%
ce_test, acc_test = model.evaluate(X_test, y_test)
print('The cross entropy loss on the test data:', ce_test)
print('The accuracy on the test data:', acc_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.8191 - loss: 0.4566
# The cross entropy loss on the test data: 0.4416465759277344
# The accuracy on the test data: 0.8421052694320679

# %% [markdown]
# This seems to be less accurate than our previous model outputs may lead us to expect, so possibly some overfitting is occuring, but we will come to that shortly.
#
# We can make a prediction using the `predict` method just as we did in the `sklearn` cases.
#
# Although our objective is classification, the `tensorflow.keras` model itself does not distinguish classification and regression. Hence, the outputs using the `predict` method is that of the discriminant function. For this reason, we will get a sequence of real values.

# %%
y_test_logit = model.predict(X_test)
print(y_test_logit[:10]) # just show you the first 10 to not spam you
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [[0.50019836]
#  [0.43989858]
#  [0.79658836]
#  [0.62340087]
#  [0.69220245]
#  [0.75950503]
#  [0.48435298]
#  [0.7040575 ]
#  [0.49290457]
#  [0.9401084 ]]

# %% [markdown]
# We can convert the above results to binary prediction by thresholding at 0.5.

# %%
y_test_pred = (y_test_logit > 0.5).astype(int)
print(y_test_pred[:10])
# Out:
# [[1]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]
#  [0]
#  [1]
#  [0]
#  [1]]

# %% [markdown]
# Finally, let's plot our outputs and look at our confusion matrix to further explore how well our model performed.

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred))
disp.plot(cmap=plt.cm.Blues)
plt.grid(False)

acc_test = accuracy_score(y_test, y_test_pred)
f1_test = f1_score(y_test, y_test_pred, pos_label=1)
print('The accuracy on the test data with the selected hyperparameter:', acc_test)
print('The F1 score on the test data with the selected hyperparameter:', f1_test)
pre_test = precision_score(y_test, y_test_pred, pos_label=1)
print('Precision on test data:', pre_test)
reca_test = recall_score(y_test, y_test_pred, pos_label=1)
print('Recall on test data:', reca_test)
# Out:
# The accuracy on the test data with the selected hyperparameter: 0.8421052631578947
# The F1 score on the test data with the selected hyperparameter: 0.8571428571428571
# Precision on test data: 0.9152542372881356
# Recall on test data: 0.8059701492537313

# %% [markdown]
# ## 2.5 Class imbalances

# %% [markdown]
# As covered in previous weeks, when performing classification, the number of instances in each class can have an impact on how well the model predicts each class.
#
# For the breast cancer dataset, the class imbalance isn't too bad, however we do have a slight imbalance that may be impacting our model. The first part of creating our model is the same:

# %%
# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_breast_cancer(return_X_y=True, as_frame=True)

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
X_raw =  X_raw[:,0:2]
y = y_pd.to_numpy()

# Split the data into training/test data
# While we have 569 pairs of a feature and target, we use 20% only for the test, not for training and validation.
# `shuffle=True` for non-time series case. You should set `shuffle=False` to avoid future data being contaminated in the training data.
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)


# Define the `Dense` layers.
dense_layer_1 = Dense(units=10, activation=relu)
output_layer = Dense(units=1, activation=sigmoid)

# Define the "virtual" input
input = Input(shape=X_train.shape[1:])

# Define the "virtual" output
output = dense_layer_1(input)
output = output_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='logistic_regression_balanced')

# Output the summary of the model.
model.summary()


sgd = SGD(learning_rate=0.01)
ce = BinaryCrossentropy()
acc = BinaryAccuracy()
model.compile(optimizer=sgd, loss=ce, metrics=[acc])
# Out:
# Model: "logistic_regression_balanced"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_35 (InputLayer)     │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_114 (Dense)               │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_115 (Dense)               │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# What we change is at the 'fitting' stage - in `tensorflow.keras`, we can specify a class weight when we fit the model.
#
# Here, we have to specify the weight manually. Specifically, we create a Python dictionary such that keys are the class labels and values indicate the class weight.

# %%
# Train the model.
# `epochs` determines the number of epochs.
# `batch_size` determines the batch_size.

m = {}
m[0] = np.sum((y_train == 0).astype(int)) # Count how many times `0` appears in the target matrix.
m[1] = np.sum((y_train == 1).astype(int)) # Count how many times `1` appears in the target matrix.
m_total = m[0] + m[1]
class_weight = {0: m_total / (2.0 * m[0]), 1: m_total / (2.0 * m[1])}

history = model.fit(X_train, y_train, batch_size=100, epochs=50, validation_data=(X_valid, y_valid), class_weight=class_weight)

# Plot validation MSE, alawys nice to have plots to help us visualise things!
plt.plot(history.history['binary_accuracy'], label='accuracy')
plt.plot(history.history['val_binary_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Out:
# Epoch 1/50
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.5572 - loss: 0.810500
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_152']. Received: the structure of inputs=*
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - binary_accuracy: 0.5596 - loss: 0.8073 - val_binary_accuracy: 0.4825 - val_loss: 0.7462
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5782 - loss: 0.7713 - val_binary_accuracy: 0.4912 - val_loss: 0.7305
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.5656 - loss: 0.7502 - val_binary_accuracy: 0.4912 - val_loss: 0.7154
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5784 - loss: 0.7250 - val_binary_accuracy: 0.4737 - val_loss: 0.7020
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5821 - loss: 0.7154 - val_binary_accuracy: 0.5351 - val_loss: 0.6892
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5886 - loss: 0.6997 - val_binary_accuracy: 0.5526 - val_loss: 0.6777
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.6195 - loss: 0.6749 - val_binary_accuracy: 0.6140 - val_loss: 0.6663
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.6790 - loss: 0.6666 - val_binary_accuracy: 0.6667 - val_loss: 0.6567
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.7294 - loss: 0.6519 - val_binary_accuracy: 0.7018 - val_loss: 0.6478
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.7672 - loss: 0.6451 - val_binary_accuracy: 0.7368 - val_loss: 0.6393
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.7847 - loss: 0.6331 - val_binary_accuracy: 0.7544 - val_loss: 0.6313
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.7941 - loss: 0.6226 - val_binary_accuracy: 0.7544 - val_loss: 0.6237
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8296 - loss: 0.6074 - val_binary_accuracy: 0.7544 - val_loss: 0.6169
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8248 - loss: 0.5986 - val_binary_accuracy: 0.7544 - val_loss: 0.6104
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8138 - loss: 0.5886 - val_binary_accuracy: 0.7544 - val_loss: 0.6042
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8201 - loss: 0.5838 - val_binary_accuracy: 0.7544 - val_loss: 0.5983
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8018 - loss: 0.5826 - val_binary_accuracy: 0.7544 - val_loss: 0.5927
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8081 - loss: 0.5720 - val_binary_accuracy: 0.7632 - val_loss: 0.5873
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - binary_accuracy: 0.8151 - loss: 0.5595 - val_binary_accuracy: 0.7719 - val_loss: 0.5823
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.8101 - loss: 0.5563 - val_binary_accuracy: 0.7719 - val_loss: 0.5776
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8144 - loss: 0.5473 - val_binary_accuracy: 0.7719 - val_loss: 0.5728
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8205 - loss: 0.5542 - val_binary_accuracy: 0.7895 - val_loss: 0.5684
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8271 - loss: 0.5408 - val_binary_accuracy: 0.7895 - val_loss: 0.5641
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8233 - loss: 0.5373 - val_binary_accuracy: 0.8070 - val_loss: 0.5599
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8201 - loss: 0.5359 - val_binary_accuracy: 0.8070 - val_loss: 0.5559
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8322 - loss: 0.5275 - val_binary_accuracy: 0.8158 - val_loss: 0.5519
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8525 - loss: 0.5222 - val_binary_accuracy: 0.8246 - val_loss: 0.5482
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8291 - loss: 0.5200 - val_binary_accuracy: 0.8333 - val_loss: 0.5444
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8347 - loss: 0.5118 - val_binary_accuracy: 0.8333 - val_loss: 0.5408
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8490 - loss: 0.5069 - val_binary_accuracy: 0.8333 - val_loss: 0.5373
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8478 - loss: 0.5119 - val_binary_accuracy: 0.8333 - val_loss: 0.5339
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8465 - loss: 0.5020 - val_binary_accuracy: 0.8333 - val_loss: 0.5306
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8458 - loss: 0.4957 - val_binary_accuracy: 0.8333 - val_loss: 0.5274
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8525 - loss: 0.4937 - val_binary_accuracy: 0.8333 - val_loss: 0.5243
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8505 - loss: 0.4858 - val_binary_accuracy: 0.8246 - val_loss: 0.5213
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8647 - loss: 0.4853 - val_binary_accuracy: 0.8246 - val_loss: 0.5184
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8597 - loss: 0.4768 - val_binary_accuracy: 0.8246 - val_loss: 0.5157
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8353 - loss: 0.4793 - val_binary_accuracy: 0.8246 - val_loss: 0.5129
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8458 - loss: 0.4776 - val_binary_accuracy: 0.8246 - val_loss: 0.5101
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8578 - loss: 0.4835 - val_binary_accuracy: 0.8246 - val_loss: 0.5074
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8445 - loss: 0.4701 - val_binary_accuracy: 0.8246 - val_loss: 0.5049
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8412 - loss: 0.4708 - val_binary_accuracy: 0.8246 - val_loss: 0.5023
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8432 - loss: 0.4689 - val_binary_accuracy: 0.8246 - val_loss: 0.4997
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8462 - loss: 0.4642 - val_binary_accuracy: 0.8246 - val_loss: 0.4972
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.8577 - loss: 0.4621 - val_binary_accuracy: 0.8333 - val_loss: 0.4947
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8390 - loss: 0.4623 - val_binary_accuracy: 0.8333 - val_loss: 0.4923
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8440 - loss: 0.4667 - val_binary_accuracy: 0.8333 - val_loss: 0.4898
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8450 - loss: 0.4574 - val_binary_accuracy: 0.8333 - val_loss: 0.4875
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8410 - loss: 0.4572 - val_binary_accuracy: 0.8333 - val_loss: 0.4852
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8527 - loss: 0.4437 - val_binary_accuracy: 0.8333 - val_loss: 0.4828

# %% [markdown]
# As the `class_weight` is not supported in the `evaluate` method for tensorflow if you want to measure this metric we can use `sklearn` functions.

# %%
y_test_logit = model.predict(X_test)
y_test_pred = (y_test_logit > 0.5).astype(int)
bacc = balanced_accuracy_score(y_test, y_test_pred)
print('The balanced accuracy score on the test data:', bacc)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# The balanced accuracy score on the test data: 0.8667831057478566

# %% [markdown]
# But let's also use the same evaluation metrics we used for the unbalanced model. As we can see, by some metrics it performs better (precision), but by other worse. So as always with regression whether this makes for a better solution depends on what the model is being used for. Accounting for class weights can help, but don't automatically make your models better in all cases!

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred))
disp.plot(cmap=plt.cm.Blues)
plt.grid(False)

acc_test = accuracy_score(y_test, y_test_pred)
f1_test = f1_score(y_test, y_test_pred, pos_label=1)
print('The accuracy on the test data with the selected hyperparameter:', acc_test)
print('The F1 score on the test data with the selected hyperparameter:', f1_test)
pre_test = precision_score(y_test, y_test_pred, pos_label=1)
print('Precision on test data:', pre_test)
reca_test = recall_score(y_test, y_test_pred, pos_label=1)
print('Recall on test data:', reca_test)
# Out:
# The accuracy on the test data with the selected hyperparameter: 0.8508771929824561
# The F1 score on the test data with the selected hyperparameter: 0.859504132231405
# Precision on test data: 0.9629629629629629
# Recall on test data: 0.7761194029850746

# %% [markdown]
# ##2.6 Exercise 2
#
# So far we have just been using a neural network with one layer and not many units. Add more layers, units and features to our NN and see if we can obtain even greater accuracy. I was able to get an f1 score of 0.97, can you beat me? (Though do remember, there is a stochastic element to the training of Neural Networks, so you may not always get the same accuracy running the same model multiple times from the start. Still, if your model is well constructed they should be comparable)

# %%
##############################################################
# Your code here
##############################################################
# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_breast_cancer(return_X_y=True, as_frame=True)

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

# Define the regularizer.
alpha = 0.01
kernel_regularizer = L2(l2=alpha)

# Define the `Dense` layer.
dense_layer_1 = Dense(units=50, activation=relu, kernel_regularizer=kernel_regularizer)
dense_layer_2 = Dense(units=50, activation=relu, kernel_regularizer=kernel_regularizer)
out_layer = Dense(units=1, activation=sigmoid, kernel_regularizer=kernel_regularizer)

# Define the "virtual" input
input = Input(shape=X_train.shape[1:])

# Define the "virtual" output
output = dense_layer_1(input)
output = dense_layer_2(output)
output = out_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='Exercise_3')

# Output the summary of the model.
model.summary()

sgd = SGD(learning_rate=0.01)
ce = BinaryCrossentropy(from_logits=False)
acc = BinaryAccuracy()
model.compile(optimizer=sgd, loss=ce, metrics=[acc])

# Train the model.
m = {}
m[0] = np.sum((y_train == 0).astype(int)) # Count how many times `0` appears in the target matrix.
m[1] = np.sum((y_train == 1).astype(int)) # Count how many times `1` appears in the target matrix.
m_total = m[0] + m[1]
class_weight = {0: m_total / (2.0 * m[0]), 1: m_total / (2.0 * m[1])}

history = model.fit(X_train, y_train, batch_size=100, epochs=100, validation_data=(X_valid, y_valid), class_weight=class_weight)

# Plot validation MSE, alwys nice to have plots to help us visualise things!
plt.plot(history.history['binary_accuracy'], label='accuracy')
plt.plot(history.history['val_binary_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

y_test_logit = model.predict(X_test)
y_test_pred = (y_test_logit > 0.5).astype(int)

disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred))
disp.plot(cmap=plt.cm.Blues)
plt.grid(False)
plt.show()

acc_test = accuracy_score(y_test, y_test_pred)
f1_test = f1_score(y_test, y_test_pred, pos_label=1)
print('The accuracy on the test data with the selected hyperparameter:', acc_test)
print('The F1 score on the test data with the selected hyperparameter:', f1_test)
pre_test = precision_score(y_test, y_test_pred, pos_label=1)
print('Precision on test data:', pre_test)
reca_test = precision_score(y_test, y_test_pred, pos_label=1)
print('Recall on test data:', reca_test)
# Out:
# Model: "Exercise_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_36 (InputLayer)     │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_116 (Dense)               │ (None, 50)             │         1,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_117 (Dense)               │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_118 (Dense)               │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,151 (16.21 KB)
#  Trainable params: 4,151 (16.21 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.2800 - loss: 1.6743
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_155']. Received: the structure of inputs=*
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - binary_accuracy: 0.3102 - loss: 1.6694 - val_binary_accuracy: 0.4386 - val_loss: 1.6026
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.4300 - loss: 1.5947 - val_binary_accuracy: 0.5439 - val_loss: 1.5545
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.5452 - loss: 1.5612 - val_binary_accuracy: 0.6754 - val_loss: 1.5143
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.6177 - loss: 1.5104 - val_binary_accuracy: 0.7368 - val_loss: 1.4806
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.6840 - loss: 1.4732 - val_binary_accuracy: 0.7895 - val_loss: 1.4508
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.7097 - loss: 1.4398 - val_binary_accuracy: 0.8246 - val_loss: 1.4243
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.7725 - loss: 1.4185 - val_binary_accuracy: 0.8421 - val_loss: 1.4001
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8069 - loss: 1.3975 - val_binary_accuracy: 0.8684 - val_loss: 1.3781
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8592 - loss: 1.3796 - val_binary_accuracy: 0.8772 - val_loss: 1.3578
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8659 - loss: 1.3569 - val_binary_accuracy: 0.8860 - val_loss: 1.3391
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8622 - loss: 1.3421 - val_binary_accuracy: 0.9035 - val_loss: 1.3219
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8694 - loss: 1.3175 - val_binary_accuracy: 0.9035 - val_loss: 1.3061
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8786 - loss: 1.3111 - val_binary_accuracy: 0.9211 - val_loss: 1.2914
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8664 - loss: 1.3010 - val_binary_accuracy: 0.9211 - val_loss: 1.2773
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9004 - loss: 1.2853 - val_binary_accuracy: 0.9211 - val_loss: 1.2653
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8896 - loss: 1.2693 - val_binary_accuracy: 0.9298 - val_loss: 1.2533
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - binary_accuracy: 0.8933 - loss: 1.2631 - val_binary_accuracy: 0.9386 - val_loss: 1.2421
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9128 - loss: 1.2453 - val_binary_accuracy: 0.9386 - val_loss: 1.2315
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9061 - loss: 1.2431 - val_binary_accuracy: 0.9561 - val_loss: 1.2215
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9026 - loss: 1.2316 - val_binary_accuracy: 0.9561 - val_loss: 1.2123
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8986 - loss: 1.2311 - val_binary_accuracy: 0.9561 - val_loss: 1.2030
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9131 - loss: 1.2109 - val_binary_accuracy: 0.9561 - val_loss: 1.1944
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8985 - loss: 1.2187 - val_binary_accuracy: 0.9561 - val_loss: 1.1860
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9066 - loss: 1.2044 - val_binary_accuracy: 0.9561 - val_loss: 1.1779
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8988 - loss: 1.1992 - val_binary_accuracy: 0.9561 - val_loss: 1.1701
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9148 - loss: 1.1831 - val_binary_accuracy: 0.9561 - val_loss: 1.1629
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9213 - loss: 1.1747 - val_binary_accuracy: 0.9561 - val_loss: 1.1562
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9166 - loss: 1.1698 - val_binary_accuracy: 0.9561 - val_loss: 1.1499
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9086 - loss: 1.1657 - val_binary_accuracy: 0.9561 - val_loss: 1.1433
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9110 - loss: 1.1771 - val_binary_accuracy: 0.9561 - val_loss: 1.1370
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9203 - loss: 1.1543 - val_binary_accuracy: 0.9561 - val_loss: 1.1315
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9287 - loss: 1.1431 - val_binary_accuracy: 0.9561 - val_loss: 1.1255
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9160 - loss: 1.1495 - val_binary_accuracy: 0.9561 - val_loss: 1.1197
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9140 - loss: 1.1555 - val_binary_accuracy: 0.9561 - val_loss: 1.1142
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9232 - loss: 1.1383 - val_binary_accuracy: 0.9561 - val_loss: 1.1091
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9305 - loss: 1.1276 - val_binary_accuracy: 0.9737 - val_loss: 1.1041
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9308 - loss: 1.1248 - val_binary_accuracy: 0.9737 - val_loss: 1.0993
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9340 - loss: 1.1233 - val_binary_accuracy: 0.9737 - val_loss: 1.0948
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9385 - loss: 1.1139 - val_binary_accuracy: 0.9737 - val_loss: 1.0903
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9365 - loss: 1.1098 - val_binary_accuracy: 0.9737 - val_loss: 1.0855
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9312 - loss: 1.1112 - val_binary_accuracy: 0.9737 - val_loss: 1.0813
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9397 - loss: 1.1013 - val_binary_accuracy: 0.9737 - val_loss: 1.0773
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9414 - loss: 1.1063 - val_binary_accuracy: 0.9737 - val_loss: 1.0736
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.9444 - loss: 1.0925 - val_binary_accuracy: 0.9737 - val_loss: 1.0698
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9384 - loss: 1.0962 - val_binary_accuracy: 0.9737 - val_loss: 1.0659
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9437 - loss: 1.0914 - val_binary_accuracy: 0.9737 - val_loss: 1.0619
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9410 - loss: 1.0884 - val_binary_accuracy: 0.9737 - val_loss: 1.0580
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - binary_accuracy: 0.9387 - loss: 1.0799 - val_binary_accuracy: 0.9737 - val_loss: 1.0547
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9350 - loss: 1.0760 - val_binary_accuracy: 0.9737 - val_loss: 1.0512
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9280 - loss: 1.0835 - val_binary_accuracy: 0.9737 - val_loss: 1.0477
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9431 - loss: 1.0665 - val_binary_accuracy: 0.9737 - val_loss: 1.0449
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9394 - loss: 1.0726 - val_binary_accuracy: 0.9737 - val_loss: 1.0415
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9494 - loss: 1.0492 - val_binary_accuracy: 0.9737 - val_loss: 1.0385
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9464 - loss: 1.0506 - val_binary_accuracy: 0.9737 - val_loss: 1.0355
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9467 - loss: 1.0583 - val_binary_accuracy: 0.9737 - val_loss: 1.0325
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9437 - loss: 1.0582 - val_binary_accuracy: 0.9737 - val_loss: 1.0292
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9317 - loss: 1.0598 - val_binary_accuracy: 0.9737 - val_loss: 1.0263
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9310 - loss: 1.0566 - val_binary_accuracy: 0.9737 - val_loss: 1.0234
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9384 - loss: 1.0529 - val_binary_accuracy: 0.9737 - val_loss: 1.0206
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9542 - loss: 1.0421 - val_binary_accuracy: 0.9737 - val_loss: 1.0178
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9414 - loss: 1.0491 - val_binary_accuracy: 0.9737 - val_loss: 1.0149
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9486 - loss: 1.0314 - val_binary_accuracy: 0.9737 - val_loss: 1.0122
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9492 - loss: 1.0377 - val_binary_accuracy: 0.9737 - val_loss: 1.0095
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9549 - loss: 1.0211 - val_binary_accuracy: 0.9737 - val_loss: 1.0074
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9446 - loss: 1.0304 - val_binary_accuracy: 0.9737 - val_loss: 1.0049
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9412 - loss: 1.0274 - val_binary_accuracy: 0.9737 - val_loss: 1.0027
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9456 - loss: 1.0247 - val_binary_accuracy: 0.9737 - val_loss: 1.0003
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9591 - loss: 1.0159 - val_binary_accuracy: 0.9737 - val_loss: 0.9979
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9551 - loss: 1.0125 - val_binary_accuracy: 0.9737 - val_loss: 0.9959
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9451 - loss: 1.0242 - val_binary_accuracy: 0.9737 - val_loss: 0.9934
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9454 - loss: 1.0234 - val_binary_accuracy: 0.9737 - val_loss: 0.9911
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9494 - loss: 1.0162 - val_binary_accuracy: 0.9737 - val_loss: 0.9890
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9534 - loss: 1.0083 - val_binary_accuracy: 0.9737 - val_loss: 0.9865
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9434 - loss: 1.0146 - val_binary_accuracy: 0.9737 - val_loss: 0.9843
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.9434 - loss: 1.0108 - val_binary_accuracy: 0.9737 - val_loss: 0.9821
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9511 - loss: 1.0022 - val_binary_accuracy: 0.9737 - val_loss: 0.9800
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9524 - loss: 0.9954 - val_binary_accuracy: 0.9737 - val_loss: 0.9778
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9501 - loss: 0.9991 - val_binary_accuracy: 0.9737 - val_loss: 0.9760
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9601 - loss: 0.9846 - val_binary_accuracy: 0.9737 - val_loss: 0.9740
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9544 - loss: 0.9855 - val_binary_accuracy: 0.9737 - val_loss: 0.9725
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9521 - loss: 0.9945 - val_binary_accuracy: 0.9825 - val_loss: 0.9705
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9417 - loss: 1.0027 - val_binary_accuracy: 0.9825 - val_loss: 0.9684
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9534 - loss: 0.9836 - val_binary_accuracy: 0.9825 - val_loss: 0.9664
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9594 - loss: 0.9782 - val_binary_accuracy: 0.9825 - val_loss: 0.9648
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.9494 - loss: 0.9833 - val_binary_accuracy: 0.9825 - val_loss: 0.9627
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9601 - loss: 0.9797 - val_binary_accuracy: 0.9825 - val_loss: 0.9610
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9554 - loss: 0.9765 - val_binary_accuracy: 0.9737 - val_loss: 0.9595
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9541 - loss: 0.9754 - val_binary_accuracy: 0.9737 - val_loss: 0.9578
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9481 - loss: 0.9845 - val_binary_accuracy: 0.9737 - val_loss: 0.9560
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9602 - loss: 0.9685 - val_binary_accuracy: 0.9737 - val_loss: 0.9540
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9502 - loss: 0.9738 - val_binary_accuracy: 0.9737 - val_loss: 0.9523
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9499 - loss: 0.9840 - val_binary_accuracy: 0.9737 - val_loss: 0.9505
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9562 - loss: 0.9727 - val_binary_accuracy: 0.9737 - val_loss: 0.9489
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9456 - loss: 0.9755 - val_binary_accuracy: 0.9737 - val_loss: 0.9471
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9607 - loss: 0.9615 - val_binary_accuracy: 0.9737 - val_loss: 0.9454
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9648 - loss: 0.9657 - val_binary_accuracy: 0.9737 - val_loss: 0.9435
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9668 - loss: 0.9568 - val_binary_accuracy: 0.9737 - val_loss: 0.9418
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - binary_accuracy: 0.9588 - loss: 0.9663 - val_binary_accuracy: 0.9737 - val_loss: 0.9400
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9561 - loss: 0.9656 - val_binary_accuracy: 0.9737 - val_loss: 0.9383
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9624 - loss: 0.9620 - val_binary_accuracy: 0.9737 - val_loss: 0.9366
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# The accuracy on the test data with the selected hyperparameter: 0.9210526315789473
# The F1 score on the test data with the selected hyperparameter: 0.9302325581395349
# Precision on test data: 0.967741935483871
# Recall on test data: 0.967741935483871

# %% [markdown]
# ## 2.7 Multi-class classification

# %% [markdown]
# Of course, as we learnt in previous weeks, we can also have classification problems with multiple classes. The implementation to solve these using Neural Networks isn't massively different, but as always has some differences we need to keep in mind.
#
# We will start by loading and scaling the Iris dataset as usual:

# %%
# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_iris(return_X_y=True, as_frame=True)

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

# %% [markdown]
# Constructing the model architecture is mostly the same - but now we need to use the `softmax` activation function. For softmax to work properly we need to also change the output units to be the number of classes in our dataset (`3` in this case). This means the model will actually be outputting three target columns containing the probabilities for each class. We'll talk about how we deal with this in a moment.

# %%
# Define the `Dense` layer.
dense_layer_1 = Dense(units=50, activation=relu)
dense_layer_2 = Dense(units=50, activation=relu)
out_layer = Dense(units=3, activation=softmax)

# Define the "virtual" input
input = Input(shape=X_raw.shape[1:])

# Define the "virtual" output
output = dense_layer_1(input)
output = dense_layer_2(output)
output = out_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='Multi_class_Classification')

# Output the summary of the model.
model.summary()
# Out:
# Model: "Multi_class_Classification"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_37 (InputLayer)     │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_119 (Dense)               │ (None, 50)             │           250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_120 (Dense)               │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_121 (Dense)               │ (None, 3)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,953 (11.54 KB)
#  Trainable params: 2,953 (11.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# When compiling our model, any optimiser still works, but we now need to think what loss functions and accuracy metrics to use.
#
# Because we are outputting columns we have a complication, as our dataset has the target in a single column. One option would be to one hot encode our target column, but tensorflow can also handle this mismatch is we use these `Sparse` loss/accuracy functions which know how to force the outputted data into the correct format for comparison with a single column target.

# %%
# Import 'Sparse' losses/metrics
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy

# Compile the model
sgd = SGD(learning_rate=0.01)
ce = SparseCategoricalCrossentropy()
acc = SparseCategoricalAccuracy()
model.compile(optimizer=sgd, loss=ce, metrics=[acc])

# Train the model.
history = model.fit(X_train, y_train, batch_size=20, epochs=100, validation_data=(X_valid, y_valid))

# Plot validation MSE, always nice to have plots to help us visualise things!
plt.plot(history.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1658 - sparse_categorical_accuracy: 0.3282 - val_loss: 1.0852 - val_sparse_categorical_accuracy: 0.4000
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0802 - sparse_categorical_accuracy: 0.3866 - val_loss: 1.0336 - val_sparse_categorical_accuracy: 0.4000
# Epoch 3/100
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_159']. Received: the structure of inputs=*
#   warnings.warn(
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0285 - sparse_categorical_accuracy: 0.4012 - val_loss: 0.9883 - val_sparse_categorical_accuracy: 0.4000
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0115 - sparse_categorical_accuracy: 0.4109 - val_loss: 0.9461 - val_sparse_categorical_accuracy: 0.4667
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9568 - sparse_categorical_accuracy: 0.5914 - val_loss: 0.9087 - val_sparse_categorical_accuracy: 0.7000
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9280 - sparse_categorical_accuracy: 0.6616 - val_loss: 0.8750 - val_sparse_categorical_accuracy: 0.7667
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8592 - sparse_categorical_accuracy: 0.7227 - val_loss: 0.8453 - val_sparse_categorical_accuracy: 0.7667
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8576 - sparse_categorical_accuracy: 0.6715 - val_loss: 0.8168 - val_sparse_categorical_accuracy: 0.7667
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8235 - sparse_categorical_accuracy: 0.7162 - val_loss: 0.7897 - val_sparse_categorical_accuracy: 0.7667
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8075 - sparse_categorical_accuracy: 0.7100 - val_loss: 0.7644 - val_sparse_categorical_accuracy: 0.7667
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7642 - sparse_categorical_accuracy: 0.7317 - val_loss: 0.7414 - val_sparse_categorical_accuracy: 0.8000
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7150 - sparse_categorical_accuracy: 0.7819 - val_loss: 0.7193 - val_sparse_categorical_accuracy: 0.8000
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7194 - sparse_categorical_accuracy: 0.7891 - val_loss: 0.7000 - val_sparse_categorical_accuracy: 0.8333
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6796 - sparse_categorical_accuracy: 0.8472 - val_loss: 0.6814 - val_sparse_categorical_accuracy: 0.8333
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6630 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.6635 - val_sparse_categorical_accuracy: 0.8333
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6314 - sparse_categorical_accuracy: 0.8634 - val_loss: 0.6476 - val_sparse_categorical_accuracy: 0.8333
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6367 - sparse_categorical_accuracy: 0.8803 - val_loss: 0.6312 - val_sparse_categorical_accuracy: 0.8333
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6280 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.6165 - val_sparse_categorical_accuracy: 0.8000
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6150 - sparse_categorical_accuracy: 0.8667 - val_loss: 0.6028 - val_sparse_categorical_accuracy: 0.8000
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6266 - sparse_categorical_accuracy: 0.8593 - val_loss: 0.5891 - val_sparse_categorical_accuracy: 0.8000
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5870 - sparse_categorical_accuracy: 0.8829 - val_loss: 0.5762 - val_sparse_categorical_accuracy: 0.8000
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5396 - sparse_categorical_accuracy: 0.8954 - val_loss: 0.5652 - val_sparse_categorical_accuracy: 0.8000
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5489 - sparse_categorical_accuracy: 0.8822 - val_loss: 0.5544 - val_sparse_categorical_accuracy: 0.8000
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5302 - sparse_categorical_accuracy: 0.8808 - val_loss: 0.5432 - val_sparse_categorical_accuracy: 0.8000
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5367 - sparse_categorical_accuracy: 0.8704 - val_loss: 0.5331 - val_sparse_categorical_accuracy: 0.8000
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5546 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.5229 - val_sparse_categorical_accuracy: 0.8000
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5101 - sparse_categorical_accuracy: 0.8725 - val_loss: 0.5135 - val_sparse_categorical_accuracy: 0.8000
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5100 - sparse_categorical_accuracy: 0.8606 - val_loss: 0.5048 - val_sparse_categorical_accuracy: 0.8000
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4806 - sparse_categorical_accuracy: 0.9037 - val_loss: 0.4970 - val_sparse_categorical_accuracy: 0.8000
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4763 - sparse_categorical_accuracy: 0.8676 - val_loss: 0.4894 - val_sparse_categorical_accuracy: 0.8000
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4712 - sparse_categorical_accuracy: 0.9025 - val_loss: 0.4820 - val_sparse_categorical_accuracy: 0.8000
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4635 - sparse_categorical_accuracy: 0.9025 - val_loss: 0.4750 - val_sparse_categorical_accuracy: 0.8000
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4550 - sparse_categorical_accuracy: 0.8887 - val_loss: 0.4681 - val_sparse_categorical_accuracy: 0.8000
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4322 - sparse_categorical_accuracy: 0.8882 - val_loss: 0.4616 - val_sparse_categorical_accuracy: 0.8333
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4644 - sparse_categorical_accuracy: 0.8806 - val_loss: 0.4556 - val_sparse_categorical_accuracy: 0.8333
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4231 - sparse_categorical_accuracy: 0.9148 - val_loss: 0.4495 - val_sparse_categorical_accuracy: 0.8333
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4508 - sparse_categorical_accuracy: 0.8523 - val_loss: 0.4438 - val_sparse_categorical_accuracy: 0.8333
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3918 - sparse_categorical_accuracy: 0.9252 - val_loss: 0.4384 - val_sparse_categorical_accuracy: 0.8333
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3834 - sparse_categorical_accuracy: 0.9190 - val_loss: 0.4332 - val_sparse_categorical_accuracy: 0.8333
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3899 - sparse_categorical_accuracy: 0.9036 - val_loss: 0.4285 - val_sparse_categorical_accuracy: 0.8333
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3767 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.4237 - val_sparse_categorical_accuracy: 0.8333
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3655 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.4192 - val_sparse_categorical_accuracy: 0.8333
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3594 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.4149 - val_sparse_categorical_accuracy: 0.8333
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3591 - sparse_categorical_accuracy: 0.9250 - val_loss: 0.4107 - val_sparse_categorical_accuracy: 0.8333
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3301 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.4068 - val_sparse_categorical_accuracy: 0.8333
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3383 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.4029 - val_sparse_categorical_accuracy: 0.8333
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3336 - sparse_categorical_accuracy: 0.9042 - val_loss: 0.3990 - val_sparse_categorical_accuracy: 0.8333
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3315 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.3956 - val_sparse_categorical_accuracy: 0.8333
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3261 - sparse_categorical_accuracy: 0.9035 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8333
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3313 - sparse_categorical_accuracy: 0.8979 - val_loss: 0.3885 - val_sparse_categorical_accuracy: 0.8333
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2990 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.3855 - val_sparse_categorical_accuracy: 0.8333
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3130 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.3824 - val_sparse_categorical_accuracy: 0.8333
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3298 - sparse_categorical_accuracy: 0.9285 - val_loss: 0.3795 - val_sparse_categorical_accuracy: 0.8333
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2930 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.3765 - val_sparse_categorical_accuracy: 0.8333
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3418 - sparse_categorical_accuracy: 0.9225 - val_loss: 0.3736 - val_sparse_categorical_accuracy: 0.8333
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3050 - sparse_categorical_accuracy: 0.9356 - val_loss: 0.3708 - val_sparse_categorical_accuracy: 0.8333
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3078 - sparse_categorical_accuracy: 0.9366 - val_loss: 0.3680 - val_sparse_categorical_accuracy: 0.8333
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3073 - sparse_categorical_accuracy: 0.9377 - val_loss: 0.3654 - val_sparse_categorical_accuracy: 0.8333
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2582 - sparse_categorical_accuracy: 0.9602 - val_loss: 0.3630 - val_sparse_categorical_accuracy: 0.8333
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2853 - sparse_categorical_accuracy: 0.9519 - val_loss: 0.3605 - val_sparse_categorical_accuracy: 0.8333
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2680 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.3580 - val_sparse_categorical_accuracy: 0.8333
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2606 - sparse_categorical_accuracy: 0.9414 - val_loss: 0.3559 - val_sparse_categorical_accuracy: 0.8333
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2831 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.3536 - val_sparse_categorical_accuracy: 0.8333
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2920 - sparse_categorical_accuracy: 0.9435 - val_loss: 0.3514 - val_sparse_categorical_accuracy: 0.8333
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2487 - sparse_categorical_accuracy: 0.9498 - val_loss: 0.3495 - val_sparse_categorical_accuracy: 0.8333
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2630 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3476 - val_sparse_categorical_accuracy: 0.8333
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2552 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8333
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2509 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.3434 - val_sparse_categorical_accuracy: 0.8333
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2776 - sparse_categorical_accuracy: 0.9519 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8333
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2443 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.3396 - val_sparse_categorical_accuracy: 0.8333
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2424 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.3378 - val_sparse_categorical_accuracy: 0.8333
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.8333
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.9407 - val_loss: 0.3345 - val_sparse_categorical_accuracy: 0.8333
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2780 - sparse_categorical_accuracy: 0.9366 - val_loss: 0.3328 - val_sparse_categorical_accuracy: 0.8333
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2414 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.3313 - val_sparse_categorical_accuracy: 0.8333
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2320 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.3298 - val_sparse_categorical_accuracy: 0.8333
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2487 - sparse_categorical_accuracy: 0.9414 - val_loss: 0.3281 - val_sparse_categorical_accuracy: 0.8333
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9532 - val_loss: 0.3265 - val_sparse_categorical_accuracy: 0.8333
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2314 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.3249 - val_sparse_categorical_accuracy: 0.8333
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2109 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8333
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2171 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.8333
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2173 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.3205 - val_sparse_categorical_accuracy: 0.8333
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2160 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.3191 - val_sparse_categorical_accuracy: 0.8333
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2186 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3178 - val_sparse_categorical_accuracy: 0.8333
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1995 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.3166 - val_sparse_categorical_accuracy: 0.8333
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.3152 - val_sparse_categorical_accuracy: 0.8333
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1982 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3140 - val_sparse_categorical_accuracy: 0.8333
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2186 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.3126 - val_sparse_categorical_accuracy: 0.8333
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2117 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.3114 - val_sparse_categorical_accuracy: 0.8333
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1992 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.3099 - val_sparse_categorical_accuracy: 0.8333
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2242 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.3087 - val_sparse_categorical_accuracy: 0.8333
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2140 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.3075 - val_sparse_categorical_accuracy: 0.8333
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1785 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.3062 - val_sparse_categorical_accuracy: 0.8333
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1999 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.3052 - val_sparse_categorical_accuracy: 0.8333
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1972 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.3041 - val_sparse_categorical_accuracy: 0.8333
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2038 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.3031 - val_sparse_categorical_accuracy: 0.8333
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1927 - sparse_categorical_accuracy: 0.9542 - val_loss: 0.3020 - val_sparse_categorical_accuracy: 0.8333
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1827 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.3008 - val_sparse_categorical_accuracy: 0.8333
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1885 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.2997 - val_sparse_categorical_accuracy: 0.8333
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2012 - sparse_categorical_accuracy: 0.9521 - val_loss: 0.2986 - val_sparse_categorical_accuracy: 0.8333

# %% [markdown]
# Now we can make predictions with our model. See below that our predictions still give three columns:

# %%
y_test_logit = model.predict(X_test)
print(y_test_logit)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.00655771 0.085741   0.9077013 ]
#  [0.01818644 0.91807806 0.06373548]
#  [0.9953532  0.00283165 0.00181519]
#  [0.00316561 0.0888635  0.90797096]
#  [0.9813729  0.01279041 0.00583669]
#  [0.00417197 0.02088072 0.97494733]
#  [0.9839172  0.01118859 0.00489426]
#  [0.04897097 0.49261174 0.4584174 ]
#  [0.02457138 0.58582985 0.38959873]
#  [0.06327358 0.77271825 0.16400826]
#  [0.0178157  0.47594556 0.5062387 ]
#  [0.08807538 0.4943242  0.41760042]
#  [0.05520494 0.7235079  0.22128709]
#  [0.0307491  0.5565631  0.41268778]
#  [0.05832109 0.5766151  0.3650639 ]
#  [0.99070174 0.00617237 0.00312588]
#  [0.06101921 0.5543417  0.3846391 ]
#  [0.04753264 0.83027357 0.12219385]
#  [0.9523361  0.03630985 0.01135392]
#  [0.9892837  0.00698849 0.00372782]
#  [0.02259609 0.27628452 0.70111936]
#  [0.09189358 0.5916075  0.31649894]
#  [0.9773217  0.01577879 0.00689943]
#  [0.9534544  0.03664496 0.00990067]
#  [0.02133432 0.29727018 0.6813955 ]
#  [0.9921578  0.00568241 0.00215976]
#  [0.98387206 0.01058603 0.00554188]
#  [0.06921473 0.70688903 0.2238962 ]
#  [0.05644096 0.88222367 0.06133539]
#  [0.97133386 0.02042889 0.00823736]]

# %% [markdown]
# We can use the `argmax` function to force this into a single column selecting the highest probability class:

# %%
y_test_pred = np.argmax(y_test_logit, axis=1)
print(y_test_pred)
# Out:
# [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0]

# %% [markdown]
# This allows us to use this prediction in our confusion matrix and using our metrics - remember that other than accuracy they generally now need to be averaged ('macro' - for equal weighing of classes and 'weighted' to take into account class imbalance). to give us a good idea of the overall accuracy.

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred))
disp.plot(cmap=plt.cm.Blues)
plt.grid(False)
plt.show()

acc_test = accuracy_score(y_test, y_test_pred)
f1_test = f1_score(y_test, y_test_pred, average='macro')
print('The accuracy on the test data with the selected hyperparameter:', acc_test)
print('The F1 score on the test data with the selected hyperparameter:', f1_test)
pre_test = precision_score(y_test, y_test_pred, average='macro')
print('Precision on test data:', pre_test)
reca_test = recall_score(y_test, y_test_pred, average='macro')
print('Recall on test data:', reca_test)
# Out:
# The accuracy on the test data with the selected hyperparameter: 1.0
# The F1 score on the test data with the selected hyperparameter: 1.0
# Precision on test data: 1.0
# Recall on test data: 1.0

# %% [markdown]
# # 3. Parametric testing with Neural Networks

# %% [markdown]
# When constructing a Neural Network there are a number of things you may want to experiment with, including, but not limited to:
#
# 1. Type of preprocessing used (Standardization vs Normalization, different encoding, missing data imputation, etc)
# 2. Changing the number of hidden units in the network
# 3. Changing the number of layers in the network
# 4. Using different activation functions in the hidden layers (Relu is a good default choice, but others may work better)
# 5. Compiling the model with different optimizers (Adam is a safe choice, but there are other options)
# 6. Changing the learning rates
# 7. Train the model for more epochs
# 8. Changing the batch sizes
# 9. Trying different accuracy metrics
# 10. Accounting for class imbalances
#
# When testing these, you need to make sure you go about it systematically and keep records of what improves or harms your model accuracy - don't just change things ad hoc and hope you eventually hit on the perfect model randomly!
#
# For some hyperparameters in particular (learning rate, regularisation strength, batch size, number of layers, number of units, etc) it is beneficial to tune these to obtain the best network.
#
# While we may want to experiment with some of these manually, in general the smart way to do things involves automating the process as much as possible. In past week's you have been shown how to do this for the regularisation strength, so let's do it again here for a Neural Network!

# %%
# First we can define some functions to create our model then compile and train it
# This should make our lives a bit easier and the code clearer when it comes to finding the parameters
# This is a very simple one just for varying the number of hidden units, but using loops you could make something allowing much more complexity.
def create_model(n_hidden=50):
    dense_layer_1 = Dense(units=n_hidden, activation=relu)
    dense_layer_2 = Dense(units=n_hidden, activation=relu)
    out_layer = Dense(units=1, activation=sigmoid)
    input=Input(shape=X_train.shape[1:])

    output = dense_layer_1(input)
    output = dense_layer_2(output)
    output = out_layer(output)
    model = Model(inputs=[input], outputs=[output], name='ParaTest')
    return model

def model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 10, batch_size=100):
    model.compile(optimizer=SGD(learning_rate=learning_rate), loss=BinaryCrossentropy(), metrics=[BinaryAccuracy()])
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, validation_data=(X_valid, y_valid), verbose=0) # Verbose=0 suppresses the output
    return model, history

# %% [markdown]
# Now we can run the automated loop (make sure you give enough training time for a fair comparison - I have chosen a relatively small number of epochs just for this quick example, but I would usually expect you to do at least a few 100 to give all models a fair chance to converge):

# %%
# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_breast_cancer(return_X_y=True, as_frame=True)

# Convert the target column vector `y_pd` into 2-dimensional array (a `pd.DataFrame` instance)
y_pd = y_pd.to_frame()

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

HUs = [10, 20, 50, 100]
train_array = np.full([len(HUs)], np.nan)
valid_array = np.full([len(HUs)], np.nan)
f1_train_array = np.full([len(HUs)], np.nan)
f1_valid_array = np.full([len(HUs)], np.nan)

for HU_index, HU in enumerate(HUs):
  # Run our two functions to create and compile the model
  model = create_model(n_hidden=HU)
  model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 50, batch_size=100)

  y_pred_train = model.predict(X_train)
  y_pred_train = (y_pred_train > 0.5).astype(int)

  train_array[HU_index] = accuracy_score(y_train, y_pred_train)
  f1_train_array[HU_index] = f1_score(y_train, y_pred_train, pos_label=1)

  y_pred_valid = model.predict(X_valid)
  y_pred_valid = (y_pred_valid > 0.5).astype(int)

  valid_array[HU_index] = accuracy_score(y_valid, y_pred_valid)
  f1_valid_array[HU_index] = f1_score(y_valid, y_pred_valid, pos_label=1)


# Select our best performing C (biggest f1)
best_HU_index = np.argmax(f1_valid_array)
best_HU= HUs[best_HU_index]
print('The best number of hidden units:', best_HU)

# plot the results
plt.figure()
plt.plot(HUs, f1_train_array, '-x', label='training f1')
plt.plot(HUs, f1_valid_array, '-x', label= 'val f1')
plt.xlabel('Hidden Units')
plt.ylabel('Final F1 score')
plt.legend()
# Out:
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_163']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_167']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_171']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_175']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# The best number of hidden units: 20

# %% [markdown]
# ## 3.1 Addressing Overfitting

# %% [markdown]
# As explained in the lecture, Neural Networks are just as prone to overfitting as other complex models.
#
# There are various manual approaches you can take such as:
# *   Removing Neurons and/or layers from the model (lowering complexity)
# *   Obtaining more training data
# *   Removing unneeded features
#
# But as with our linear models, manually experimenting with these things can be quite slow. While simplifying needlessly complex models and data is never a bad thing, there are a selection of automatic techniques which are quick and easy to implement that should help with any overfitting.

# %% [markdown]
# ###3.1.1 Regularisation

# %% [markdown]
# As we discussed in previous lectures, we need regularisation to make the optimization stable as well as to avoid overfitting which can be useful for both regression and classification models.
#
# You can integrate regularisation directly into your dense layers, and this can also apply for Regression problems where it performs the same purpose as it did in general models where it adds a term to the cost function that will encourage the model to minimise the magnitude of edge weights (parameters) being used by the model. We can again specify L1 (Lasso) regularisation and L2 (Ridge) regression. Of course, if you use regularisation you need to be careful with picking you hyperparameter $\alpha$, otherwise you could either end up underfitting if it is too high and the regularisation will have no effect if it is too small.
#
# For other regularizers, see [here](https://www.tensorflow.org/api_docs/python/tf/keras/regularizers).
#
# See below for an example of the code you need to include in your network to add regularisation:

# %%
# Define the regularizer.
alpha = 0.001
#Pick one of the Regularisation methods
kernel_regularizer = L1(l1=alpha) #Lasso
kernel_regularizer = L2(l2=alpha) #Ridge
layer = Dense(units=10, activation=relu, kernel_regularizer=kernel_regularizer)

# %% [markdown]
# ###3.1.2 Dropout Layers

# %% [markdown]
# In order to simulate training multiple models in parallel and combining them, adding dropout layers randomly turn off nodes in the network with every epoch to make the Network more robust to overfitting particular nodes/edges. The proportion of dropouts and even the number of dropout nodes are both other hyperparameters that need considering when constructing your model (if you decide to include dropout). A single dropout layer may not be enough in truly complicated networks!
#
# See below for an example of a basic model with a dropout layer added. Often you will have dropout layers to correspond with every dense layer, but as always in ML there are many different strategies used.
#
# Note: this is quite a simple network and having dropout nodes is probably a bit overkill, though adding dropout to your layers is usually a good thing as it should make the network more robust.

# %%
X_pd, y_pd = sklearn.datasets.fetch_california_housing(return_X_y=True, as_frame=True)
y_pd = y_pd.to_frame()

X_raw = X_pd.to_numpy()
X_raw=X_raw[0:1000,0:2]
y = y_pd.to_numpy()
y=y[0:1000]

X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

first_layer = Dense(units=128*4, activation=relu)
##############################
# Set proportion of nodes to deactivate with every training iteration (20% in this case)
second_layer = Dropout(0.2)
##############################
third_layer = Dense(units=128*4, activation=relu)
forth_layer = Dense(units=128*4, activation=relu)
fifth_layer = Dense(units=128*4, activation=relu)
out_layer = Dense(units=1, activation=linear)

input = Input(shape=X_train.shape[1:])
output = first_layer(input)
output = second_layer(output)
output = third_layer(output)
output = forth_layer(output)
output = fifth_layer(output)
output = out_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='Dropout')
model.summary()
# Out:
# Model: "Dropout"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_42 (InputLayer)     │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_135 (Dense)               │ (None, 512)            │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_136 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_137 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_138 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_139 (Dense)               │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 790,017 (3.01 MB)
#  Trainable params: 790,017 (3.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model by specifying the optimization algorithm and the loss function.
sgd = SGD(learning_rate=0.01)
mse = MeanSquaredError()
model.compile(optimizer=sgd, loss=mse)

# Train the model.
history = model.fit(X_train, y_train, batch_size=1000, epochs=100, validation_data=(X_valid, y_valid), verbose=1)

# Plot validation MSE, always nice to have plots to help us visualise things!
plt.plot(history.history['loss'], label='MSE')
plt.plot(history.history['val_loss'], label = 'val_MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(loc='lower right')
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 5.0917
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_179']. Received: the structure of inputs=*
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 5.0917 - val_loss: 4.6004
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.6194 - val_loss: 4.1853
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.1923 - val_loss: 3.8050
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.8083 - val_loss: 3.4472
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.4372 - val_loss: 3.1044
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.0862 - val_loss: 2.7755
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.7433 - val_loss: 2.4617
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.4240 - val_loss: 2.1648
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.1179 - val_loss: 1.8876
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.8308 - val_loss: 1.6326
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.5716 - val_loss: 1.4046
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.3369 - val_loss: 1.2056
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.1343 - val_loss: 1.0369
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.9515 - val_loss: 0.8991
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.8112 - val_loss: 0.7903
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.7029 - val_loss: 0.7060
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.6175 - val_loss: 0.6432
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5489 - val_loss: 0.5973
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5083 - val_loss: 0.5637
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4711 - val_loss: 0.5390
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4569 - val_loss: 0.5204
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.4396 - val_loss: 0.5055
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4219 - val_loss: 0.4937
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.4138 - val_loss: 0.4838
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4006 - val_loss: 0.4753
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3937 - val_loss: 0.4675
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3921 - val_loss: 0.4606
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3797 - val_loss: 0.4540
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3792 - val_loss: 0.4478
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3741 - val_loss: 0.4420
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3694 - val_loss: 0.4365
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3683 - val_loss: 0.4313
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3590 - val_loss: 0.4264
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3575 - val_loss: 0.4216
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3555 - val_loss: 0.4172
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3488 - val_loss: 0.4132
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3424 - val_loss: 0.4093
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3459 - val_loss: 0.4056
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3397 - val_loss: 0.4020
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3424 - val_loss: 0.3988
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3347 - val_loss: 0.3952
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3277 - val_loss: 0.3923
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3235 - val_loss: 0.3895
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3266 - val_loss: 0.3869
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3280 - val_loss: 0.3843
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3195 - val_loss: 0.3819
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3234 - val_loss: 0.3798
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3159 - val_loss: 0.3777
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3158 - val_loss: 0.3756
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3125 - val_loss: 0.3736
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3197 - val_loss: 0.3718
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3170 - val_loss: 0.3702
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3130 - val_loss: 0.3686
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3045 - val_loss: 0.3668
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3015 - val_loss: 0.3653
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3071 - val_loss: 0.3638
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3063 - val_loss: 0.3623
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3033 - val_loss: 0.3611
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3037 - val_loss: 0.3599
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3013 - val_loss: 0.3587
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2982 - val_loss: 0.3575
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2958 - val_loss: 0.3565
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2986 - val_loss: 0.3554
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2981 - val_loss: 0.3544
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2926 - val_loss: 0.3535
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2964 - val_loss: 0.3526
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2959 - val_loss: 0.3518
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2957 - val_loss: 0.3511
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2929 - val_loss: 0.3504
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2860 - val_loss: 0.3496
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2937 - val_loss: 0.3490
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2874 - val_loss: 0.3483
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2904 - val_loss: 0.3478
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2892 - val_loss: 0.3473
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2871 - val_loss: 0.3467
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2847 - val_loss: 0.3461
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2881 - val_loss: 0.3457
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2822 - val_loss: 0.3451
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2864 - val_loss: 0.3447
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2894 - val_loss: 0.3443
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2831 - val_loss: 0.3438
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2817 - val_loss: 0.3433
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2791 - val_loss: 0.3430
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2809 - val_loss: 0.3426
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2822 - val_loss: 0.3423
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2776 - val_loss: 0.3419
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2797 - val_loss: 0.3415
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2836 - val_loss: 0.3412
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2767 - val_loss: 0.3409
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2827 - val_loss: 0.3407
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2810 - val_loss: 0.3405
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.2813 - val_loss: 0.3402
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2820 - val_loss: 0.3400
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2792 - val_loss: 0.3396
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2773 - val_loss: 0.3395
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2716 - val_loss: 0.3393
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2759 - val_loss: 0.3390
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2749 - val_loss: 0.3388
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2732 - val_loss: 0.3385
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2720 - val_loss: 0.3384

# %% [markdown]
# ###3.1.3 Early Stopping
#
# Early stopping simply monitors the validation data, and if it identifies that the validation accuracy/error is deteriorating then it will stop training the model further. However, you do want to leave some leeway as fitting Neural Networks can be a bit stochastic, so you don't want to immediately stop the first time the validation loss increases. This tolerance is called the `patience` and is a hyperparamter that says how many iterations it will tolerate with a loss above the best observed value. You may need to experiment with so that you can hit the sweet spot of not overfitting but also not ending your training prematurely.
#
# This can simply be done by making a callback instance and defining this when fitting the model, there is an example on a simple model below (callback information in the second cell)

# %%
X_pd, y_pd = sklearn.datasets.fetch_california_housing(return_X_y=True, as_frame=True)
y_pd = y_pd.to_frame()

X_raw = X_pd.to_numpy()
X_raw=X_raw[0:500,0:2]
y = y_pd.to_numpy()
y=y[0:500]

X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

first_layer = Dense(units=128*4, activation=relu)
second_layer = Dense(units=128*4, activation=relu)
third_layer = Dense(units=128*4, activation=relu)
forth_layer = Dense(units=128*4, activation=relu)
fifth_layer = Dense(units=128*4, activation=relu)
out_layer = Dense(units=1, activation=linear)

input = Input(shape=X_train.shape[1:])
output = first_layer(input)
output = second_layer(output)
output = third_layer(output)
output = forth_layer(output)
output = fifth_layer(output)
output = out_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='Early_Stop')
model.summary()
# Out:
# Model: "Early_Stop"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_43 (InputLayer)     │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_140 (Dense)               │ (None, 512)            │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_141 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_142 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_143 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_144 (Dense)               │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_145 (Dense)               │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,052,673 (4.02 MB)
#  Trainable params: 1,052,673 (4.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model by specifying the optimization algorithm and the loss function.
sgd = SGD(learning_rate=0.1)
mse = MeanSquaredError()
model.compile(optimizer=sgd, loss=mse)

###################################################################################
# Early Stopping
# Choose what metric to monitor (validation accuracy a good metric for overfitting in regression)
# Patience is how many iterations with a loss above the lowest observed value will be tolerated
callback = EarlyStopping(monitor='val_loss', patience=3)
####################################################################################

# Train the model.
history = model.fit(X_train, y_train, batch_size=1000, epochs=100, validation_data=(X_valid, y_valid), verbose=1, callbacks=[callback])

# Plot validation MSE, always nice to have plots to help us visualise things!
plt.plot(history.history['loss'], label='MSE')
plt.plot(history.history['val_loss'], label = 'val_MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(loc='lower right')
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 4.5855
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_186']. Received: the structure of inputs=*
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.5855 - val_loss: 2.2278
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.1574 - val_loss: 0.9564
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.9326 - val_loss: 0.7480
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.7416 - val_loss: 0.6456
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.6337 - val_loss: 0.5504
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5494 - val_loss: 0.4934
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4920 - val_loss: 0.4450
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4619 - val_loss: 0.4440
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4536 - val_loss: 0.4189
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.4567 - val_loss: 0.4814
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4923 - val_loss: 0.4562
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5144 - val_loss: 0.6532

# %% [markdown]
# ##3.2 Continuing training

# %% [markdown]
# One thing you may not have noticed is that you can continue training your model without having to start from scratch each time. You can do this simply by rerunning (you can change things like the `epoch` so you don't have to run it under exactly the same conditions):
#
# `history = model.fit(....)`
#
# which will take the existing model you have already trained and continue training from there. This can be useful if you think your model is nearly converged and you just want to run it for a little longer and/or you don't want to lose the time you spent training previously.
#
# Of course, you may not always want to do this, and you can 'reset' your model weights by rerunning the code that defines the model object:
#
# `model = Model(...)`

# %% [markdown]
# ## 3.3 Saving your model
#
# Sometimes it can take a long time to train a model that uses big data or is very complex, so obviously you don't want to lose this progress, but one issue with using Colab is that it clears out your runtime every time you stop using it.
#
# For that reason, you may want to save the trained weights of your model so you can come back to it later and improve it or use it for making predictions on other data.
#
# If you are interested in learning more about this, I would direct you to [TensorFLow's tutorial on the topic.](https://www.tensorflow.org/tutorials/keras/save_and_load)
#
# I won't go into this in any further detail here, as it should not be an issue for your coursework or any of the tutorials. But I thought it would be useful to let you know this is an option in case it is relevant to you later in your MSC project or in your work.

# %% [markdown]
# ## 3.4 Exercise 3

# %% [markdown]
# Try using this rough framework to experiment with a few different parameters to optimise the breast cancer dataset
#
#
# 1.   Try training the models for more epochs when calculating the regularisation weight.
# 2.   Try altering the learning rate.
# 3.   Try testing different number of hidden units.
# 4.   Change the number of layers and try testing some of the above again, do you get different results?

# %%
##############################################################
# Your code here
##############################################################

# First we can define some functions to create our model then compile and train it
# This should make our lives a bit easier and the code clearer when it comes to finding the parameters
def create_model(n_hidden=50):
    dense_layer_1 = Dense(units=n_hidden, activation=relu)
    dense_layer_2 = Dense(units=n_hidden, activation=relu)
    out_layer = Dense(units=1, activation=sigmoid)
    input=Input(shape=X_train.shape[1:])
    # Note, we can stack our layers in a single line like this to save space, but this approach does make it harder adding and removing layers.
    output = out_layer(dense_layer_2(dense_layer_1(input)))
    model = Model(inputs=[input], outputs=[output], name='Exercise_3')
    return model

def model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 10, batch_size=100):
    model.compile(optimizer=SGD(learning_rate=learning_rate), loss=BinaryCrossentropy(), metrics=[BinaryAccuracy()])
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, validation_data=(X_valid, y_valid), verbose=0) # Verbose=0 suppresses the output
    return model, history

# %%
# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_breast_cancer(return_X_y=True, as_frame=True)

# Convert the target column vector `y_pd` into 2-dimensional array (a `pd.DataFrame` instance)
y_pd = y_pd.to_frame()

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

hidden_units = [10, 50, 100, 200, 500]
train_array = np.full([len(hidden_units)], np.nan)
valid_array = np.full([len(hidden_units)], np.nan)
f1_train_array = np.full([len(hidden_units)], np.nan)
f1_valid_array = np.full([len(hidden_units)], np.nan)

for HU_index, nh in enumerate(hidden_units):
  # Run our two functions to create and compile the model
  model = create_model(n_hidden=nh)
  model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 50, batch_size=100)

  y_pred_train = model.predict(X_train)
  y_pred_train = (y_pred_train > 0.5).astype(int)

  train_array[HU_index] = accuracy_score(y_train, y_pred_train)
  f1_train_array[HU_index] = f1_score(y_train, y_pred_train, pos_label=1)

  y_pred_valid = model.predict(X_valid)
  y_pred_valid = (y_pred_valid > 0.5).astype(int)

  valid_array[HU_index] = accuracy_score(y_valid, y_pred_valid)
  f1_valid_array[HU_index] = f1_score(y_valid, y_pred_valid, pos_label=1)


# Select our best performing number of units (biggest f1)
best_hidden_index = np.argmax(f1_valid_array)
best_units = hidden_units[best_hidden_index]
print('The best number of units:', best_units)

# plot the results
plt.figure()
plt.plot(hidden_units, f1_train_array, '-x', label='training f1')
plt.plot(hidden_units, f1_valid_array, '-x', label= 'val f1')
plt.xlabel('Number of hidden units')
plt.ylabel('Final F1 score')
plt.legend()
# Out:
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_193']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_197']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_201']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_205']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_209']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# The best number of units: 100

# %%
def create_model(reg_str=0.01,n_hidden=50):
    kernel_regularizer = L2(l2=reg_str)
    dense_layer_1 = Dense(units=n_hidden, activation=relu, kernel_regularizer=kernel_regularizer)
    dense_layer_2 = Dense(units=n_hidden, activation=relu, kernel_regularizer=kernel_regularizer)
    out_layer = Dense(units=1, activation=sigmoid, kernel_regularizer=kernel_regularizer)
    input=Input(shape=X_train.shape[1:])
    # Note, we can stack our layers in a single line like this to save space, but this approach does make it harder adding and removing layers.
    output = out_layer(dense_layer_2(dense_layer_1(input)))
    model = Model(inputs=[input], outputs=[output], name='Exercise_4')
    return model

def model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 10, batch_size=100):
    model.compile(optimizer=SGD(learning_rate=learning_rate), loss=BinaryCrossentropy(), metrics=[BinaryAccuracy()])
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, validation_data=(X_valid, y_valid), verbose=0) # Verbose=0 suppresses the output
    return model, history

# %%
# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_breast_cancer(return_X_y=True, as_frame=True)

# Convert the target column vector `y_pd` into 2-dimensional array (a `pd.DataFrame` instance)
y_pd = y_pd.to_frame()

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

Cs = [0.0001, 0.001, 0.01, 0.1, 1.0]
train_array = np.full([len(Cs)], np.nan)
valid_array = np.full([len(Cs)], np.nan)
f1_train_array = np.full([len(Cs)], np.nan)
f1_valid_array = np.full([len(Cs)], np.nan)

for C_index, C in enumerate(Cs):
  # Run our two functions to create and compile the model
  model = create_model(reg_str=C,n_hidden=200)
  model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 50, batch_size=100)

  y_pred_train = model.predict(X_train)
  y_pred_train = (y_pred_train > 0.5).astype(int)

  train_array[C_index] = accuracy_score(y_train, y_pred_train)
  f1_train_array[C_index] = f1_score(y_train, y_pred_train, pos_label=1)

  y_pred_valid = model.predict(X_valid)
  y_pred_valid = (y_pred_valid > 0.5).astype(int)

  valid_array[C_index] = accuracy_score(y_valid, y_pred_valid)
  f1_valid_array[C_index] = f1_score(y_valid, y_pred_valid, pos_label=1)


# Select our best performing C (biggest f1)
best_C_index = np.argmax(f1_valid_array)
best_C = Cs[best_C_index]
print('The best C:', best_C)

# plot the results
plt.figure()
plt.plot(Cs, f1_train_array, '-x', label='training f1')
plt.plot(Cs, f1_valid_array, '-x', label= 'val f1')
plt.xlabel('Regularisation Strength')
plt.ylabel('Final F1 score')
plt.legend()
# Out:
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_213']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_217']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_221']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_225']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_229']. Received: the structure of inputs=*
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# The best C: 0.001

# %%
model = create_model(reg_str=best_C,n_hidden=200)
model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 50, batch_size=100)
# Out:
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_233']. Received: the structure of inputs=*
#   warnings.warn(

# %%
y_pred_test = model.predict(X_test)
y_pred_test = (y_pred_test > 0.5).astype(int)

disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_test))
disp.plot(cmap=plt.cm.Blues)
plt.grid(False)

acc_test = accuracy_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test, pos_label=1)
print('The accuracy on the test data with the selected hyperparameter:', acc_test)
print('The F1 score on the test data with the selected hyperparameter:', f1_test)
pre_test = precision_score(y_test, y_pred_test, pos_label=1)
print('Precision on test data:', pre_test)
reca_test = recall_score(y_test, y_pred_test, pos_label=1)
print('Recall on test data:', reca_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# The accuracy on the test data with the selected hyperparameter: 0.9385964912280702
# The F1 score on the test data with the selected hyperparameter: 0.948905109489051
# Precision on test data: 0.9285714285714286
# Recall on test data: 0.9701492537313433

# %% [markdown]
# ##3.5 Exercise 4

# %% [markdown]
# Use this parametric testing approach used above to try exploring the hyperparameters for your regression problem in **Exercise 1** to obtain the best model you can. I don't have a particular 'perfect' answer in mind here, what I want you to do is experiment with many of the aspects of a neural network discussed at the start of this section to see what the best model you can obtain is. This may involve multiple passes where you change the number of layers in the model (or their activation function, or some other fundamental change) and then you can work on optimising the hyperparameters.
#
# **Warning**: It may take some time for the parametric test to complete if you are running a model with many layers/units for potentially hundreds of epochs. It's impossible to train every permutation of model ever, all we can hope to do is advance things logically and systematically (e.g. pick an initial model structure, try tuning the hyperparameters on this model, once you have these hyperparameters you can experiment with changing the model layout. Then you may want to go back again and see if tuning the hyperparameters for this new model improves things). You also may want to try fitting a model on a subset of the data for speed, then try doing the final tunings on the full dataset once you have a model setup you are fairly happy with.

# %%
##############################################################
# Your code here
##############################################################
# First we can define some functions to create our model then compile and train it
# This should make our lives a bit easier and the code clearer when it comes to finding the paramaters
def create_model(reg_str=0.01,n_hidden=50):
    kernel_regularizer = L2(l2=reg_str)
    dense_layer_1 = Dense(units=n_hidden, activation=relu, kernel_regularizer=kernel_regularizer)
    dense_layer_2 = Dense(units=n_hidden, activation=relu, kernel_regularizer=kernel_regularizer)
    out_layer = Dense(units=1, activation=linear, kernel_regularizer=kernel_regularizer)
    input=Input(shape=X_train.shape[1:])
    # Note, we can stack our layers in a single line like this to save space, but this approach does make it harder adding and removing layers.
    output = out_layer(dense_layer_2(dense_layer_1(input)))
    model = Model(inputs=[input], outputs=[output], name='Exercise_5')
    return model

def model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 10, batch_size=100):
    model.compile(optimizer=SGD(learning_rate=learning_rate), loss=MeanSquaredError())
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, validation_data=(X_valid, y_valid), verbose=0) # Verbose=0 suppresses the output
    return model, history

# %%
# This is just an example of how I would automate choosing the number of layers for the california housing data.
# I would expect you to do a lot more experimentation to ultimately find a model much better than this one!

X_pd, y_pd = sklearn.datasets.fetch_california_housing(return_X_y=True, as_frame=True)

X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

hidden_units = [10, 25, 50, 75, 100]
train_array = np.full([len(hidden_units)], np.nan)
valid_array = np.full([len(hidden_units)], np.nan)

for HU_index, nh in enumerate(hidden_units):
  # Run our two functions to create and compile the model
  model = create_model(reg_str=0.01,n_hidden=nh)
  model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 50, batch_size=100)

  train_array[HU_index] = model.evaluate(X_train, y_train)
  valid_array[HU_index] = model.evaluate(X_valid, y_valid)


# Select our best performing number of units (smallest MSE)
best_hidden_index = np.argmin(valid_array)
best_units = hidden_units[best_hidden_index]
print('The best number of units:', best_units)

# plot the results
plt.figure()
plt.plot(hidden_units, train_array, '-x', label='training MSE')
plt.plot(hidden_units, valid_array, '-x', label= 'val MSE')
plt.xlabel('Number of hidden units')
plt.ylabel('MSE')
plt.legend()
plt.show()

model = create_model(reg_str=0.01,n_hidden=best_units)
model_compile_and_training(X_train, y_train, X_valid, y_valid, learning_rate= 0.01, n_epochs= 50, batch_size=100)

mse_on_test = model.evaluate(X_test, y_test)
print('The mean squared error on the test data:', mse_on_test)

y_test_pred = model.predict(X_test)

# Plot our predictions
plt.scatter(X_test_raw[:,0], y_test,  color='black', label='y_true') # Observed y values
plt.scatter(X_test_raw[:,0], y_test_pred, color='blue', label='y_pred') # predicted y values
plt.xlabel('MedInc')
plt.ylabel('house price')
plt.legend()
plt.show()

# The R2 score: 1 is perfect prediction
print('R2 score: {:.4f}'.format(sklearn.metrics.r2_score(y_test, y_test_pred)))
# Out:
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_99']. Received: the structure of inputs=*
#   warnings.warn(
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step - loss: 0.4738
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 260us/step - loss: 0.4934
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_103']. Received: the structure of inputs=*
#   warnings.warn(
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 0.4752
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 0.4989
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_107']. Received: the structure of inputs=*
#   warnings.warn(
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 251us/step - loss: 0.5024
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 258us/step - loss: 0.5244
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_111']. Received: the structure of inputs=*
#   warnings.warn(
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 0.5232
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.5473
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_115']. Received: the structure of inputs=*
#   warnings.warn(
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 0.5410
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.5666
# The best number of units: 25
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_119']. Received: the structure of inputs=*
#   warnings.warn(
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step - loss: 0.4884
# The mean squared error on the test data: 0.47516870498657227
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 271us/step
# R2 score: 0.7187

# %% [markdown]
# ##3.6 Exercise 5
#
# Try using everything we've learnt to find a model that provides good results on the Wine Dataset (`sklearn.datasets.load_wine()` - a multi class classification problem). This is quite an easy dataset, so I was able to get perfect accuracy on my test data!

# %%
##############################################################
# Your code here
##############################################################

# I didn't even have to do a study - just a little messing around with the setup and it gave me a perfect result
# Don't expect this to happen to you in real life!

# Load the breast cancer dataset
X_pd, y_pd = sklearn.datasets.load_wine(return_X_y=True, as_frame=True)

# prepare NumPy ndarrays
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

# Split the data into training/test data
X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

# Define the `Dense` layer.
dense_layer_1 = Dense(units=50, activation=relu)
dense_layer_2 = Dense(units=50, activation=relu)
out_layer = Dense(units=3, activation=softmax)

# Define the "virtual" input
input = Input(shape=X_raw.shape[1:])

# Define the "virtual" output
output = dense_layer_1(input)
output = dense_layer_2(output)
output = out_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='Multi_class_Classification')

# Output the summary of the model.
model.summary()

# COmpile the model
sgd = SGD(learning_rate=0.01)
ce = SparseCategoricalCrossentropy()
acc = SparseCategoricalAccuracy()
model.compile(optimizer=sgd, loss=ce, metrics=[acc])

# Train the model.
history = model.fit(X_train, y_train, batch_size=20, epochs=100, validation_data=(X_valid, y_valid))

# Plot validation MSE, alwys nice to have plots to help us visualise things!
plt.plot(history.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

y_test_logit = model.predict(X_test)
y_test_pred = np.argmax(y_test_logit, axis=1)

disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred))
disp.plot(cmap=plt.cm.Blues)
plt.grid(False)
plt.show()

acc_test = accuracy_score(y_test, y_test_pred)
f1_test = f1_score(y_test, y_test_pred, average='macro')
print('The accuracy on the test data with the selected hyperparameter:', acc_test)
print('The F1 score on the test data with the selected hyperparameter:', f1_test)
pre_test = precision_score(y_test, y_test_pred, average='macro')
print('Precision on test data:', pre_test)
reca_test = recall_score(y_test, y_test_pred, average='macro')
print('Recall on test data:', reca_test)
# Out:
# Model: "Multi_class_Classification"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_29 (InputLayer)     │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_94 (Dense)                │ (None, 50)             │           700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_96 (Dense)                │ (None, 3)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,403 (13.29 KB)
#  Trainable params: 3,403 (13.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1245 - sparse_categorical_accuracy: 0.3311 - val_loss: 1.0973 - val_sparse_categorical_accuracy: 0.2500
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0821 - sparse_categorical_accuracy: 0.5260 - val_loss: 1.0458 - val_sparse_categorical_accuracy: 0.3889
# Epoch 3/100
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_123']. Received: the structure of inputs=*
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0168 - sparse_categorical_accuracy: 0.5970 - val_loss: 1.0009 - val_sparse_categorical_accuracy: 0.5278
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9764 - sparse_categorical_accuracy: 0.6337 - val_loss: 0.9567 - val_sparse_categorical_accuracy: 0.6389
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9251 - sparse_categorical_accuracy: 0.7574 - val_loss: 0.9152 - val_sparse_categorical_accuracy: 0.7778
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8944 - sparse_categorical_accuracy: 0.7444 - val_loss: 0.8776 - val_sparse_categorical_accuracy: 0.8611
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8447 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.8412 - val_sparse_categorical_accuracy: 0.8611
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.8059 - val_sparse_categorical_accuracy: 0.8611
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7996 - sparse_categorical_accuracy: 0.8734 - val_loss: 0.7735 - val_sparse_categorical_accuracy: 0.8889
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7648 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.7425 - val_sparse_categorical_accuracy: 0.9167
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7239 - sparse_categorical_accuracy: 0.8766 - val_loss: 0.7111 - val_sparse_categorical_accuracy: 0.9444
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6883 - sparse_categorical_accuracy: 0.8972 - val_loss: 0.6798 - val_sparse_categorical_accuracy: 0.9722
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6468 - sparse_categorical_accuracy: 0.9482 - val_loss: 0.6504 - val_sparse_categorical_accuracy: 0.9722
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6278 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.6236 - val_sparse_categorical_accuracy: 0.9444
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6142 - sparse_categorical_accuracy: 0.9318 - val_loss: 0.5975 - val_sparse_categorical_accuracy: 0.9444
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5725 - sparse_categorical_accuracy: 0.9279 - val_loss: 0.5717 - val_sparse_categorical_accuracy: 0.9444
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5572 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.5474 - val_sparse_categorical_accuracy: 0.9444
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5185 - sparse_categorical_accuracy: 0.9562 - val_loss: 0.5231 - val_sparse_categorical_accuracy: 0.9722
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4971 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.5006 - val_sparse_categorical_accuracy: 0.9444
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5054 - sparse_categorical_accuracy: 0.9562 - val_loss: 0.4781 - val_sparse_categorical_accuracy: 0.9722
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4468 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.4569 - val_sparse_categorical_accuracy: 0.9722
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4430 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.4366 - val_sparse_categorical_accuracy: 0.9722
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4181 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.4175 - val_sparse_categorical_accuracy: 0.9722
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4054 - sparse_categorical_accuracy: 0.9798 - val_loss: 0.3988 - val_sparse_categorical_accuracy: 0.9722
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3780 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3819 - val_sparse_categorical_accuracy: 0.9722
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3462 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3655 - val_sparse_categorical_accuracy: 0.9444
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3594 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3504 - val_sparse_categorical_accuracy: 0.9444
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3460 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.9722
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3236 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3220 - val_sparse_categorical_accuracy: 0.9722
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3133 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3094 - val_sparse_categorical_accuracy: 0.9722
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3002 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2964 - val_sparse_categorical_accuracy: 0.9722
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2940 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2851 - val_sparse_categorical_accuracy: 0.9722
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2894 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2739 - val_sparse_categorical_accuracy: 0.9722
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2659 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2636 - val_sparse_categorical_accuracy: 0.9722
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2569 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2541 - val_sparse_categorical_accuracy: 0.9722
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2396 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2456 - val_sparse_categorical_accuracy: 0.9722
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2225 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2372 - val_sparse_categorical_accuracy: 0.9722
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2345 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2289 - val_sparse_categorical_accuracy: 0.9722
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2235 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2212 - val_sparse_categorical_accuracy: 0.9722
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2110 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2141 - val_sparse_categorical_accuracy: 0.9722
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2140 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2073 - val_sparse_categorical_accuracy: 0.9722
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1968 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2006 - val_sparse_categorical_accuracy: 0.9722
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1806 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1949 - val_sparse_categorical_accuracy: 0.9722
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1747 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9722
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1660 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1844 - val_sparse_categorical_accuracy: 0.9722
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1805 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1796 - val_sparse_categorical_accuracy: 0.9722
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1746 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1749 - val_sparse_categorical_accuracy: 0.9722
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1652 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1706 - val_sparse_categorical_accuracy: 0.9722
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1638 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1667 - val_sparse_categorical_accuracy: 0.9722
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1688 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1629 - val_sparse_categorical_accuracy: 0.9722
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1401 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1595 - val_sparse_categorical_accuracy: 0.9722
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1555 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1564 - val_sparse_categorical_accuracy: 0.9722
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1328 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1532 - val_sparse_categorical_accuracy: 0.9722
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1243 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1503 - val_sparse_categorical_accuracy: 0.9722
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1399 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1476 - val_sparse_categorical_accuracy: 0.9722
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1230 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1448 - val_sparse_categorical_accuracy: 0.9722
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1259 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1418 - val_sparse_categorical_accuracy: 0.9722
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1119 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1396 - val_sparse_categorical_accuracy: 0.9722
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1168 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1374 - val_sparse_categorical_accuracy: 0.9722
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1220 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1354 - val_sparse_categorical_accuracy: 0.9722
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1287 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1334 - val_sparse_categorical_accuracy: 0.9722
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1149 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1313 - val_sparse_categorical_accuracy: 0.9722
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1111 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1294 - val_sparse_categorical_accuracy: 0.9722
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1043 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1275 - val_sparse_categorical_accuracy: 0.9444
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1101 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1256 - val_sparse_categorical_accuracy: 0.9444
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0918 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1240 - val_sparse_categorical_accuracy: 0.9444
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0881 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1221 - val_sparse_categorical_accuracy: 0.9722
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0944 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1206 - val_sparse_categorical_accuracy: 0.9722
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0919 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1195 - val_sparse_categorical_accuracy: 0.9722
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0974 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1182 - val_sparse_categorical_accuracy: 0.9722
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0988 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1169 - val_sparse_categorical_accuracy: 0.9722
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1156 - val_sparse_categorical_accuracy: 0.9722
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0738 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1150 - val_sparse_categorical_accuracy: 0.9722
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0882 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1136 - val_sparse_categorical_accuracy: 0.9722
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0916 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1123 - val_sparse_categorical_accuracy: 0.9722
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0874 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1114 - val_sparse_categorical_accuracy: 0.9722
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0789 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1106 - val_sparse_categorical_accuracy: 0.9444
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0688 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1101 - val_sparse_categorical_accuracy: 0.9444
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0850 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1085 - val_sparse_categorical_accuracy: 0.9444
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0735 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1076 - val_sparse_categorical_accuracy: 0.9722
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0740 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1069 - val_sparse_categorical_accuracy: 0.9722
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0700 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1062 - val_sparse_categorical_accuracy: 0.9722
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0639 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1058 - val_sparse_categorical_accuracy: 0.9444
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0641 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1045 - val_sparse_categorical_accuracy: 0.9444
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0822 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1037 - val_sparse_categorical_accuracy: 0.9444
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0695 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1030 - val_sparse_categorical_accuracy: 0.9444
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0607 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1022 - val_sparse_categorical_accuracy: 0.9444
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0723 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1016 - val_sparse_categorical_accuracy: 0.9444
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0652 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1012 - val_sparse_categorical_accuracy: 0.9444
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0703 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1006 - val_sparse_categorical_accuracy: 0.9444
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0626 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0999 - val_sparse_categorical_accuracy: 0.9444
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0594 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0994 - val_sparse_categorical_accuracy: 0.9444
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0691 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0988 - val_sparse_categorical_accuracy: 0.9444
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0611 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0982 - val_sparse_categorical_accuracy: 0.9444
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0591 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0976 - val_sparse_categorical_accuracy: 0.9444
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0646 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0971 - val_sparse_categorical_accuracy: 0.9444
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0626 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0966 - val_sparse_categorical_accuracy: 0.9444
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0545 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0961 - val_sparse_categorical_accuracy: 0.9444
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0598 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0955 - val_sparse_categorical_accuracy: 0.9444
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0514 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0950 - val_sparse_categorical_accuracy: 0.9444
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# The accuracy on the test data with the selected hyperparameter: 1.0
# The F1 score on the test data with the selected hyperparameter: 1.0
# Precision on test data: 1.0
# Recall on test data: 1.0

# %% [markdown]
# #Appendix 1: Sequential Models (Bonus Exercise)

# %% [markdown]
# In this tutorial we have been using the *functional* (`Model`) api for creating our neural networks ([see here for documentation](https://www.tensorflow.org/guide/keras/functional/)), but this isn't the only way we can create them.
#
# Another very common way of constructing Neural Networks is to use the `Sequential` model api ([see here for documentation](https://www.tensorflow.org/guide/keras/sequential_model)). Less common (in my experience), but you may also encounter how to make models using *subclassing*, which I won't cover here ([see here for documentation](https://www.tensorflow.org/guide/keras/custom_layers_and_models/)).
#
# I have chosen to use the `Model` api as I feel it offers you the best compromise between useability and being able to quite easily incorporate some more advanced functionality (such as transfer learning and multiple outputs).
#
# However, if you just want to create a linear Neural Network from scratch, the `Sequential` api is perfectly acceptable and quite intuitive to use, so feel free to use either method for your coursework.
#
# Below I have just implemented the first basic Neural Network we used at the start of the tutorial.
#
# **Bonus Exercise** This model is quite bad (certainly needs more training), see if you can get to grips with the sequential API and remake whatever your solution was for *Exercise 1*. You could also try remaking one of your classification models using this approach.

# %%
X_pd, y_pd = sklearn.datasets.fetch_california_housing(return_X_y=True, as_frame=True)
y_pd = y_pd.to_frame()

X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()


X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

##################################################
# Everything else in this should be the same as our initial example
# Here we define our model first and add dense layers one at a time
# While a bit simpler to understand, this approach is less flexible and doesn't allow us to do as much as the functional api.
model = Sequential()
# Note, we don't need to define an input layer, just specidy the input dimension for the first layer.
model.add(Dense(5, input_dim=len(X_train[1]),activation='sigmoid'))
model.add(Dense(5, activation='sigmoid'))
model.add(Dense(1, activation='linear'))
##################################################

# Should see that this is the same as the model we made earlier in the first example.
model.summary()

sgd = SGD(learning_rate=0.01)
mse = MeanSquaredError()
model.compile(optimizer=sgd, loss=mse)

history = model.fit(X_train, y_train, batch_size=1000, epochs=100, validation_data=(X_valid, y_valid), verbose=1)

# Plot validation MSE, alwys nice to have plots to help us visualise things!
plt.plot(history.history['loss'], label='MSE')
plt.plot(history.history['val_loss'], label = 'val_MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(loc='lower right')
plt.show()

mse_on_test = model.evaluate(X_test, y_test)
print('The mean squared error on the test data:', mse_on_test)

y_test_pred = model.predict(X_test)

# Plot our predictions
plt.scatter(X_test_raw[:,0], y_test,  color='black', label='y_true') # Observed y values
plt.scatter(X_test_raw[:,0], y_test_pred, color='blue', label='y_pred') # predicted y values
plt.xlabel('MedInc')
plt.ylabel('house price')
plt.legend()
plt.show()

# The R2 score: 1 is perfect prediction
print('R2 score: {:.4f}'.format(sklearn.metrics.r2_score(y_test, y_test_pred)))
# Out:
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_97 (Dense)                │ (None, 5)              │            45 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_98 (Dense)                │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_99 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7399 - val_loss: 1.7901
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6752 - val_loss: 1.4694
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4387 - val_loss: 1.3978
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3799 - val_loss: 1.3779
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3771 - val_loss: 1.3708
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3629 - val_loss: 1.3663
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3543 - val_loss: 1.3621
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3219 - val_loss: 1.3580
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3297 - val_loss: 1.3546
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3209 - val_loss: 1.3508
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3305 - val_loss: 1.3474
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3058 - val_loss: 1.3438
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3364 - val_loss: 1.3403
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3297 - val_loss: 1.3368
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3182 - val_loss: 1.3334
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3119 - val_loss: 1.3300
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3371 - val_loss: 1.3269
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3492 - val_loss: 1.3235
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2818 - val_loss: 1.3200
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3104 - val_loss: 1.3165
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3091 - val_loss: 1.3132
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3045 - val_loss: 1.3097
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2957 - val_loss: 1.3062
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3036 - val_loss: 1.3030
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2760 - val_loss: 1.2997
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2936 - val_loss: 1.2958
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3034 - val_loss: 1.2926
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2830 - val_loss: 1.2890
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2702 - val_loss: 1.2858
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2779 - val_loss: 1.2823
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2989 - val_loss: 1.2787
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2480 - val_loss: 1.2753
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2405 - val_loss: 1.2714
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2745 - val_loss: 1.2680
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2605 - val_loss: 1.2643
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2597 - val_loss: 1.2606
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2529 - val_loss: 1.2568
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2393 - val_loss: 1.2531
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2358 - val_loss: 1.2496
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2238 - val_loss: 1.2459
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2140 - val_loss: 1.2419
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2190 - val_loss: 1.2382
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2191 - val_loss: 1.2345
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2456 - val_loss: 1.2304
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2131 - val_loss: 1.2264
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2148 - val_loss: 1.2226
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2083 - val_loss: 1.2185
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2027 - val_loss: 1.2145
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1890 - val_loss: 1.2103
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1724 - val_loss: 1.2063
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2156 - val_loss: 1.2021
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1957 - val_loss: 1.1978
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2150 - val_loss: 1.1935
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1779 - val_loss: 1.1892
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1780 - val_loss: 1.1849
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1598 - val_loss: 1.1806
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1590 - val_loss: 1.1761
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1457 - val_loss: 1.1716
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1439 - val_loss: 1.1671
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1565 - val_loss: 1.1625
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1479 - val_loss: 1.1579
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1430 - val_loss: 1.1532
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1344 - val_loss: 1.1487
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1376 - val_loss: 1.1438
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1357 - val_loss: 1.1390
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1137 - val_loss: 1.1341
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1191 - val_loss: 1.1292
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1230 - val_loss: 1.1242
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1107 - val_loss: 1.1192
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1079 - val_loss: 1.1143
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0875 - val_loss: 1.1091
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0780 - val_loss: 1.1040
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0869 - val_loss: 1.0994
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0860 - val_loss: 1.0944
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0762 - val_loss: 1.0888
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0723 - val_loss: 1.0839
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0533 - val_loss: 1.0784
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0566 - val_loss: 1.0730
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0400 - val_loss: 1.0676
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0652 - val_loss: 1.0621
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0475 - val_loss: 1.0567
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0333 - val_loss: 1.0510
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0252 - val_loss: 1.0456
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0168 - val_loss: 1.0399
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0087 - val_loss: 1.0344
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0046 - val_loss: 1.0288
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0090 - val_loss: 1.0231
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9950 - val_loss: 1.0176
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0027 - val_loss: 1.0121
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9950 - val_loss: 1.0061
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0026 - val_loss: 1.0006
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9996 - val_loss: 0.9949
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9800 - val_loss: 0.9892
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9847 - val_loss: 0.9835
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9736 - val_loss: 0.9779
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9548 - val_loss: 0.9719
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9500 - val_loss: 0.9659
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9483 - val_loss: 0.9604
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9555 - val_loss: 0.9547
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9405 - val_loss: 0.9491
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 268us/step - loss: 0.9687
# The mean squared error on the test data: 0.9259966611862183
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step
# R2 score: 0.2899

# %% [markdown]
# #Appendix 2: Multiple outputs (Bonus Exercise)

# %% [markdown]
# I haven't mentioned this so far, and you have not been asked to do this for your coursework, but you should be aware that your models (not just Neural Networks) are capable of predicting multiple target outputs. Of course, you could just make two separate models to do this, but combining them certainly makes the coding workflow easier to follow.
#
# Just to show you how easy this is to do I have made a model predicting both the house value and the average rooms for the California Housing dataset. The functional api actually allows for complicated branching outputs that means you could have entirely separate layers being trained for each output and also means that (for example) a single model could perform regression and classification, among all sorts of other weird and wonderful complicated model constructions. But this becomes quite complicated and is far beyond the scope of what you need to know for this module, so I will leave researching that to you if your are interested.
#
# **Bonus Task** I have not optimised this model very much, so see if you can improve the performance for both targets!

# %%
# Here I am pulling the data into a single frame, then splitting it up into out two column target matrix and our reduced feature matrix (now missing the average rooms)
# There may be a more elegant way to do this process.
X_pd, y_pd = sklearn.datasets.fetch_california_housing(return_X_y=True, as_frame=True)
y_pd = y_pd.to_frame()
Xy_pd = pd.concat([X_pd, y_pd], axis=1)
y_pd=Xy_pd[['MedHouseVal','AveRooms']]
X_pd=Xy_pd
X_pd.drop(columns=['AveRooms','MedHouseVal'], inplace=True)
X_raw = X_pd.to_numpy()
y = y_pd.to_numpy()

X_nontest_raw, X_test_raw, y_nontest, y_test = train_test_split(X_raw, y, test_size=0.20, shuffle=True, random_state=0)
X_train_raw, X_valid_raw, y_train, y_valid = train_test_split(X_nontest_raw, y_nontest, test_size=0.25, shuffle=True, random_state=0)

scaler = StandardScaler()
scaler.fit(X_train_raw)
X_train = scaler.transform(X_train_raw)
X_valid = scaler.transform(X_valid_raw)
X_test = scaler.transform(X_test_raw)

first_layer = Dense(units=10, activation=relu)
second_layer = Dense(units=10, activation=relu)
#############################################
# This is the key step - here we are specifying two output units rather than 1 as we have been doing elsewhere.
out_layer = Dense(units=2, activation=linear)
#############################################

input = Input(shape=X_train.shape[1:])
output = first_layer(input)
output = second_layer(output)
output = out_layer(output)

# Define the neural network model.
model = Model(inputs=[input], outputs=[output], name='Appendix_2')
model.summary()

# Compile the model by specifying the optimization algorithm and the loss function.
sgd = SGD(learning_rate=0.01)
mse = MeanSquaredError()
model.compile(optimizer=sgd, loss=mse)

# Train the model.
history = model.fit(X_train, y_train, batch_size=1000, epochs=100, validation_data=(X_valid, y_valid), verbose=1)

# Plot validation MSE, alwys nice to have plots to help us visualise things!
plt.plot(history.history['loss'], label='MSE')
plt.plot(history.history['val_loss'], label = 'val_MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(loc='lower right')
plt.show()

mse_on_test = model.evaluate(X_test, y_test)
print('The mean squared error on the test data:', mse_on_test)

y_test_pred = model.predict(X_test)

# Plot our predictions
# MedInc
plt.scatter(X_test_raw[:,0], y_test[:,0],  color='black', label='y_true') # Observed y values
plt.scatter(X_test_raw[:,0], y_test_pred[:,0], color='blue', label='y_pred') # predicted y values
plt.xlabel('MedInc')
plt.ylabel('House Price')
plt.legend()
plt.show()
# AveRooms
plt.scatter(X_test_raw[:,0], y_test[:,1],  color='black', label='y_true') # Observed y values
plt.scatter(X_test_raw[:,0], y_test_pred[:,1], color='blue', label='y_pred') # predicted y values
plt.xlabel('MedInc')
plt.ylabel('Average Rooms')
plt.legend()
plt.show()

# The R2 score: 1 is perfect prediction
print('R2 score (House Price): {:.4f}'.format(sklearn.metrics.r2_score(y_test[:,0], y_test_pred[:,0])))
print('R2 score (Average Rooms): {:.4f}'.format(sklearn.metrics.r2_score(y_test[:,1], y_test_pred[:,1])))
# Out:
# Model: "Appendix_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_31 (InputLayer)     │ (None, 7)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_100 (Dense)               │ (None, 10)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_101 (Dense)               │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_102 (Dense)               │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 212 (848.00 B)
#  Trainable params: 212 (848.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.9263 - val_loss: 16.2980
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.1781 - val_loss: 6.4160
# Epoch 3/100
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5116
# /Users/muhammedazhar/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_134']. Received: the structure of inputs=*
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9764 - val_loss: 3.8348
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0328 - val_loss: 2.6469
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1149 - val_loss: 2.0944
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6701 - val_loss: 1.7973
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3802 - val_loss: 1.6087
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2746 - val_loss: 1.4931
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1470 - val_loss: 1.3871
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0602 - val_loss: 1.3104
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0137 - val_loss: 1.2437
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9361 - val_loss: 1.1833
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9269 - val_loss: 1.1407
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8768 - val_loss: 1.0980
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8606 - val_loss: 1.0668
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8072 - val_loss: 1.0410
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8109 - val_loss: 1.0140
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7760 - val_loss: 0.9956
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7750 - val_loss: 0.9790
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7537 - val_loss: 0.9795
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7481 - val_loss: 0.9616
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7270 - val_loss: 0.9392
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7160 - val_loss: 0.9272
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7052 - val_loss: 0.9165
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7037 - val_loss: 0.9162
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7019 - val_loss: 0.9125
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6897 - val_loss: 0.9009
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7039 - val_loss: 0.8981
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6959 - val_loss: 0.8953
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6642 - val_loss: 0.8965
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6921 - val_loss: 0.8940
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6608 - val_loss: 0.8931
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6666 - val_loss: 0.8965
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6764 - val_loss: 0.8778
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6746 - val_loss: 0.8805
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6660 - val_loss: 0.8759
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6799 - val_loss: 0.8723
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6572 - val_loss: 0.8725
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6678 - val_loss: 0.8660
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6714 - val_loss: 0.8669
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6582 - val_loss: 0.8662
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6332 - val_loss: 0.8600
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6611 - val_loss: 0.8592
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6388 - val_loss: 0.8571
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6698 - val_loss: 0.8523
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6370 - val_loss: 0.8665
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6297 - val_loss: 0.8544
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6311 - val_loss: 0.8510
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6305 - val_loss: 0.8495
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6314 - val_loss: 0.8476
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6302 - val_loss: 0.8438
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6219 - val_loss: 0.8526
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6408 - val_loss: 0.8405
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6191 - val_loss: 0.8333
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6145 - val_loss: 0.8422
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6311 - val_loss: 0.8377
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6325 - val_loss: 0.8380
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6094 - val_loss: 0.8342
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6092 - val_loss: 0.8359
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6162 - val_loss: 0.8267
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6159 - val_loss: 0.8574
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6398 - val_loss: 0.8304
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6100 - val_loss: 0.8283
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6290 - val_loss: 0.8278
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6046 - val_loss: 0.8297
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6093 - val_loss: 0.8289
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6125 - val_loss: 0.8261
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6122 - val_loss: 0.8297
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5933 - val_loss: 0.8240
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5946 - val_loss: 0.8133
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5972 - val_loss: 0.8120
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6244 - val_loss: 0.8107
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5910 - val_loss: 0.8102
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5960 - val_loss: 0.8110
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5935 - val_loss: 0.8233
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5952 - val_loss: 0.8117
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5934 - val_loss: 0.8086
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5901 - val_loss: 0.8096
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5973 - val_loss: 0.8371
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5917 - val_loss: 0.8048
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5812 - val_loss: 0.8044
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5957 - val_loss: 0.8075
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6052 - val_loss: 0.8054
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5910 - val_loss: 0.7997
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5689 - val_loss: 0.8045
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5775 - val_loss: 0.7985
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5948 - val_loss: 0.7974
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5739 - val_loss: 0.7993
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5656 - val_loss: 0.8050
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5913 - val_loss: 0.7922
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5946 - val_loss: 0.7912
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5785 - val_loss: 0.7941
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5849 - val_loss: 0.7960
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5815 - val_loss: 0.7939
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5865 - val_loss: 0.7938
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5901 - val_loss: 0.7888
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5732 - val_loss: 0.7886
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5643 - val_loss: 0.7908
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5787 - val_loss: 0.7895
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5748 - val_loss: 0.7887
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.6778
# The mean squared error on the test data: 0.6235910058021545
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step
# R2 score (House Price): 0.5921
# R2 score (Average Rooms): 0.8608

# %% [markdown]
# #Appendix 3: Image inputs (Bonus Exercise)

# %% [markdown]
# Next week we are going to be learning about Convolutional Neural Networks, which are widely used for creating Neural Networks that are good at identifying image features. However, normal Neural Networks are also capable of taking images as an input and classifying them with some accuracy. So, if you want to get a head start on your coursework you might want to have a look at this example of how you can load a dataset I have made of some images and classified them using a standard Neural Network.

# %% [markdown]
# First of all, I take the `shapes_dataset.zip` file I provided on moodle and upload it to your colab work space (don't unzip it first!). We can then use this `!unzip` command to extract these files inside colab, where we can start using them.

# %%
# !unzip shapes_dataset.zip
# Out:
# unzip:  cannot find or open shapes_dataset.zip, shapes_dataset.zip.zip or shapes_dataset.zip.ZIP.

# %% [markdown]
# And we can load the data like so (there are other methods such as using generators that I will touch on next week).

# %%
# We need some extra packages to help us interact with the colab file system and load in the images
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load metadata from the CSV file - this allows us to know what class each picture belongs to.
metadata = pd.read_csv("shapes_dataset/metadata.csv")

# Define the directory where your images are located (in colab in our case)
image_directory = "shapes_dataset"

# Define image size - this means we can rescale all our images to be the same size
image_size = (100, 100)

# Create lists to store image data and labels
images = []
labels = []

# Load and preprocess images
for index, row in metadata.iterrows():
    image_path = os.path.join(image_directory, row['image_name'])
    image = load_img(image_path, target_size=image_size)
    image_array = img_to_array(image) / 255.0  # Normalize pixel values to [0, 1]
    images.append(image_array)
    labels.append(row['class_label'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[57], line 6
#       3 from tensorflow.keras.preprocessing.image import load_img, img_to_array
#       5 # Load metadata from the CSV file - this allows us to know what class each picture belongs to.
# ----> 6 metadata = pd.read_csv("shapes_dataset/metadata.csv")
#       8 # Define the directory where your images are located (in colab in our case)
#       9 image_directory = "shapes_dataset"
#
# File ~/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.miniconda3/envs/COMP1801-ML/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'shapes_dataset/metadata.csv'

# %% [markdown]
# And now let's visualise the dataset - this is a multi-class classification problem where we have three different shapes to identify!

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the number of rows and columns for image visualization
num_images_to_visualize = 20

num_rows = 4
num_columns = num_images_to_visualize // num_rows

# Get a random subset of images from the validation set
subset_indices = np.random.choice(20, num_images_to_visualize, replace=False)

# Create a figure with subplots
fig, axes = plt.subplots(num_rows, num_columns, figsize=(15, 7))

# Loop through the subset of images
for i, index in enumerate(subset_indices):
    row = i // num_columns
    col = i % num_columns

    imd=(images[index]*255).astype(np.uint8)

    # Plot the image
    axes[row, col].imshow(imd)
    axes[row, col].axis('off')

    # Set the title with both true and predicted labels
    title = f"Label: {labels[index]}\n"
    axes[row, col].set_title(title)

# Adjust spacing and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Now let's try solving this with a Neural Network! Pay attention to my comments to understand what is going on.

# %%
from tensorflow.keras.utils import to_categorical # another way to `one hot encode` your target using tensorflow
from tensorflow.keras.layers import Flatten # we need to use the 'flatten' layer to convert our images into a form our 'dense' layers can use.

# Convert class labels to integers
class_mapping = {'square': 0, 'circle': 1, 'triangle': 2}
labels = [class_mapping[label] for label in labels]

# Convert lists to NumPy arrays
images = np.array(images)
labels = np.array(labels)

# Split the data into training and validation sets
X_non_test, X_test, y_non_test, y_test = train_test_split(images, labels, test_size=1/10, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_non_test, y_non_test, test_size=1/9, random_state=42)

# Convert labels to one-hot encoded format (required for softmax - though we could also use 'sparse' loss/metrics)
y_train_encoded = to_categorical(y_train, num_classes=3)
y_valid_encoded = to_categorical(y_valid, num_classes=3)
y_test_encoded = to_categorical(y_test, num_classes=3)

# Define input layer - note this is actually a three channel colour image, we could probably convert to being grayscale for our case, but I will leave it this way for the example.
input_layer = Input(shape=(100, 100, 3))

# Define the model using the functional API
x = Flatten()(input_layer) # we have to flatten our image for the dense layers - makes our data '1D'
x = Dense(1000, activation=relu)(x)
x = Dense(1000, activation=relu)(x)
output_layer = Dense(3, activation=softmax)(x)

model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model using your training data
history = model.fit(X_train, y_train_encoded, epochs=20, validation_data=(X_valid, y_valid_encoded))

# Evaluate the model on the validation and test data
validation_loss, validation_accuracy = model.evaluate(X_valid, y_valid_encoded)
test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded)

print(f"Validation loss: {validation_loss:.4f}")
print(f"Validation accuracy: {validation_accuracy:.4f}")
print(f"Test loss: {test_loss:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")

# %% [markdown]
# Let's evaluate our network now:

# %%
ce_test, acc_test = model.evaluate(X_test, y_test_encoded)
print('The cross entropy loss on the test data:', ce_test)
print('The accuracy on the test data:', acc_test)

y_test_logit = model.predict(X_test)

y_test_pred = np.argmax(y_test_logit, axis=1)

disp = ConfusionMatrixDisplay(confusion_matrix(np.array(y_test, dtype=int), y_test_pred))
disp.plot(cmap=plt.cm.Blues)
plt.grid(False)

acc_test = accuracy_score(np.array(y_test, dtype=int), y_test_pred)
f1_test = f1_score(np.array(y_test, dtype=int), y_test_pred, pos_label=1, average='macro')
print('The accuracy on the test data with the selected hyperparameter:', acc_test)
print('The F1 score on the test data with the selected hyperparameter:', f1_test)
pre_test = precision_score(np.array(y_test, dtype=int), y_test_pred, pos_label=1, average='macro')
print('Precision on validation data:', pre_test)
reca_test = precision_score(np.array(y_test, dtype=int), y_test_pred, pos_label=1, average='macro')
print('Recall on validation data:', reca_test)

# %% [markdown]
# So not too great! Below I'm outputting some examples to see where our model is succeeding and failing.
#
# Bonus exercise: We're likely to reach an accuracy ceiling without going to Convolutional NN's, but you can try adding more nodes, layers and trying the other methods we've covered to see if you can get a better accuracy for this problem!

# %%
# Define the number of rows and columns for image visualization
num_images_to_visualize = 20

num_rows = 4
num_columns = num_images_to_visualize // num_rows

# Get a random subset of images from the validation set
subset_indices = np.random.choice(20, num_images_to_visualize, replace=False)

# Create a figure with subplots
fig, axes = plt.subplots(num_rows, num_columns, figsize=(15, 7))

predicted_prob = model.predict(X_test)
predicted_classes = np.argmax(predicted_prob, axis=1)

predicted_classes_name = predicted_classes

# Loop through the subset of images
for i, index in enumerate(subset_indices):
    row = i // num_columns
    col = i % num_columns

    imd=(X_test[index]*255).astype(np.uint8)

    # Plot the image
    axes[row, col].imshow(imd)
    axes[row, col].axis('off')

    # Set the title with both true and predicted labels
    title = f"True: {y_test[index]}\nPredicted: {predicted_classes[index]}"
    axes[row, col].set_title(title)

# Adjust spacing and display the plot
plt.tight_layout()
plt.show()
