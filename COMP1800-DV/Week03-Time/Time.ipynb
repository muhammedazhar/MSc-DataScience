# %% [markdown]
# # 1. Line Plot All

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)
print(data.head())

# data.plot.line(linewidth=0.5, figsize=(8, 8))
plt.figure(figsize=(8, 8))
plt.plot(data, linewidth=0.5)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Product Sales', fontsize=20)
plt.legend(data.columns, loc=2)
plt.show()
# Out:
#               A   B   C  D   E    F    G    H   I    J  ...   P   Q  R    S  \
# Date                                                    ...
# 2019-01-01  526   3   9  0  66  472  260  116  45  202  ...  85  38  0   97
# 2019-01-02  504  11  10  0  57  472  157  108   3  223  ...  73   0  0   92
# 2019-01-03  499   0  10  0  42  475  154  104   0  199  ...  65  20  5   84
# 2019-01-04  504   0   7  0  57  464  149   83  17  198  ...  83  19  0   89
# 2019-01-05  499  15   9  0  31  466  159   84  14  219  ...  97  31  0  104
#
#              T  U   V    W   X   Y
# Date
# 2019-01-01  19  7   0  174  55  12
# 2019-01-02  45  0  14  132  65   8
# 2019-01-03  89  0   4  132  39   6
# 2019-01-04   0  0  14  143  57  20
# 2019-01-05   0  8  28   46  44  15
#
# [5 rows x 25 columns]

# %% [markdown]
# # 2. Line Plot High Volume

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

selected = ['A', 'F', 'L']
print(data[selected].head())

# data[selected].plot.line(linewidth=0.5, figsize=(8, 8))
plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('High Volume Product Sales', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               A    F    L
# Date
# 2019-01-01  526  472  374
# 2019-01-02  504  472  343
# 2019-01-03  499  475  363
# 2019-01-04  504  464  348
# 2019-01-05  499  466  375

# %% [markdown]
# # 3. Line Plot High Volume Axis Zeroed

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

selected = ['A', 'F', 'L']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('High Volume Product Sales', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               A    F    L
# Date
# 2019-01-01  526  472  374
# 2019-01-02  504  472  343
# 2019-01-03  499  475  363
# 2019-01-04  504  464  348
# 2019-01-05  499  466  375

# %% [markdown]
# # 4. Line Plot High Volume Averaged

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

sample_rate = 'W'  # weekly
averaged_data = data.resample(sample_rate).mean()

selected = ['A', 'F', 'L']
print(data[selected].head())
print(averaged_data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
plt.plot(averaged_data[selected], linewidth=2)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('High Volume Sales with Weekly Averages', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               A    F    L
# Date
# 2019-01-01  526  472  374
# 2019-01-02  504  472  343
# 2019-01-03  499  475  363
# 2019-01-04  504  464  348
# 2019-01-05  499  466  375
#                      A           F           L
# Date
# 2019-01-06  503.833333  470.000000  357.166667
# 2019-01-13  504.000000  472.428571  363.000000
# 2019-01-20  505.714286  472.285714  355.428571
# 2019-01-27  495.285714  472.428571  371.571429
# 2019-02-03  494.428571  472.142857  363.857143

# %% [markdown]
# # 5. Line Plot High Volume Rolling Averaged

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

period = 7
rolling_average = data.rolling(window=period).mean()

selected = ['A', 'F', 'L']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
plt.plot(rolling_average[selected], linewidth=2)
# plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('High Volume Product Sales\n with 7-day Rolling Average', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               A    F    L
# Date
# 2019-01-01  526  472  374
# 2019-01-02  504  472  343
# 2019-01-03  499  475  363
# 2019-01-04  504  464  348
# 2019-01-05  499  466  375

# %% [markdown]
# # 6. Line Plot High Volume Trendline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

selected = ['A', 'F', 'L']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
for name in selected:
    x = np.arange(len(data[name]))
    z = np.polyfit(x, data[name], 1)
    trend = np.poly1d(z)
    plt.plot(data.index, trend(x), linestyle='--')
# plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('High Volume Product Sales with Trendlines', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               A    F    L
# Date
# 2019-01-01  526  472  374
# 2019-01-02  504  472  343
# 2019-01-03  499  475  363
# 2019-01-04  504  464  348
# 2019-01-05  499  466  375

# %% [markdown]
# # 7. Line Plot Medium Volume

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

selected = ['G', 'H', 'J', 'S', 'W']
print(data[selected].head())

# data[selected].plot.line(linewidth=0.5, figsize=(8, 8))
plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Medium Volume Product Sales', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               G    H    J    S    W
# Date
# 2019-01-01  260  116  202   97  174
# 2019-01-02  157  108  223   92  132
# 2019-01-03  154  104  199   84  132
# 2019-01-04  149   83  198   89  143
# 2019-01-05  159   84  219  104   46

# %% [markdown]
# # 8. Line Plot Medium Volume Rolling Averaged

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

period = 7
rolling_average = data.rolling(window=period).mean()

selected = ['G', 'H', 'J', 'S', 'W']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
plt.plot(rolling_average[selected], linewidth=2)
# plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Medium Volume Product Sales\n with 7-day Rolling Average', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               G    H    J    S    W
# Date
# 2019-01-01  260  116  202   97  174
# 2019-01-02  157  108  223   92  132
# 2019-01-03  154  104  199   84  132
# 2019-01-04  149   83  198   89  143
# 2019-01-05  159   84  219  104   46

# %% [markdown]
# # 9. Line Plot Low Volume Rolling Averaged

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

period = 7
rolling_average = data.rolling(window=period).mean()

selected = ['D', 'E', 'M', 'O', 'P', 'T', 'X']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
plt.plot(rolling_average[selected], linewidth=2)
# plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Low Volume Product Sales\n with 7-day Rolling Average', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#             D   E   M   O   P   T   X
# Date
# 2019-01-01  0  66  51  66  85  19  55
# 2019-01-02  0  57  56  51  73  45  65
# 2019-01-03  0  42  59  49  65  89  39
# 2019-01-04  0  57  42  50  83   0  57
# 2019-01-05  0  31  45  45  97   0  44

# %% [markdown]
# # 10. Line Plot Very Low Volume Rolling Averaged

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

period = 7
rolling_average = data.rolling(window=period).mean()

selected = ['B', 'C', 'I', 'K', 'N', 'Q', 'R', 'U', 'V', 'Y']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(data[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
plt.plot(rolling_average[selected], linewidth=2)
# plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Very Low Volume Product Sales\n with 7-day Rolling Average', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#              B   C   I   K   N   Q  R  U   V   Y
# Date
# 2019-01-01   3   9  45  21   6  38  0  7   0  12
# 2019-01-02  11  10   3  24  22   0  0  0  14   8
# 2019-01-03   0  10   0   7  17  20  5  0   4   6
# 2019-01-04   0   7  17  15   2  19  0  0  14  20
# 2019-01-05  15   9  14  26   0  31  0  8  28  15

# %% [markdown]
# # 11. Line Plot Very Low Volume Average With Trendline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

sample_rate = 'M'  # weekly
averaged_data = data.resample(sample_rate).mean()
period = 7
rolling_average = data.rolling(window=period).mean()

selected = ['B', 'C', 'I', 'K', 'N', 'Q', 'R', 'U', 'V', 'Y']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(averaged_data[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
for name in selected:
    x = np.arange(len(data[name]))
    z = np.polyfit(x, data[name], 1)
    trend = np.poly1d(z)
    plt.plot(data.index, trend(x), linestyle='--')
# plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Very Low Volume Monthly Average\n with Linear Trendlines', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#              B   C   I   K   N   Q  R  U   V   Y
# Date
# 2019-01-01   3   9  45  21   6  38  0  7   0  12
# 2019-01-02  11  10   3  24  22   0  0  0  14   8
# 2019-01-03   0  10   0   7  17  20  5  0   4   6
# 2019-01-04   0   7  17  15   2  19  0  0  14  20
# 2019-01-05  15   9  14  26   0  31  0  8  28  15
# /var/folders/pb/_45838w13ds5fcrv51k520zh0000gn/T/ipykernel_89299/3514499539.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   averaged_data = data.resample(sample_rate).mean()

# %% [markdown]
# # 12. Line Plot Very Low Volume Rolling Average With Cubic Trendline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)

sample_rate = 'SM'  # weekly
averaged_data = data.resample(sample_rate).mean()
period = 28
rolling_average = data.rolling(window=period).mean()

selected = ['B', 'C', 'I', 'K', 'N', 'Q', 'R', 'U', 'V', 'Y']
selected = ['I', 'K', 'Q']
print(data[selected].head())

plt.figure(figsize=(8, 8))
plt.plot(rolling_average[selected], linewidth=0.5)
plt.gca().set_prop_cycle(None)
for name in selected:
    x = np.arange(len(data[name]))
    z = np.polyfit(x, data[name], 3)
    trend = np.poly1d(z)
    plt.plot(data.index, trend(x), linestyle='--')
# plt.ylim(ymin=0)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Very Low Volume 28-day Rolling Average\n with Cubic Trendlines', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#              I   K   Q
# Date
# 2019-01-01  45  21  38
# 2019-01-02   3  24   0
# 2019-01-03   0   7  20
# 2019-01-04  17  15  19
# 2019-01-05  14  26  31
# /var/folders/pb/_45838w13ds5fcrv51k520zh0000gn/T/ipykernel_89299/3101640139.py:10: FutureWarning: 'SM' is deprecated and will be removed in a future version, please use 'SME' instead.
#   averaged_data = data.resample(sample_rate).mean()

# %% [markdown]
# # 13. Area Plot All

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)
print(data.head())

plt.figure(figsize=(8, 8))
# data.plot.area(figsize=(8, 8))
plt.stackplot(data.index, data.transpose())
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Stacked Product Sales', fontsize=20)
plt.legend(data.columns, loc=2)
plt.show()
# Out:
#               A   B   C  D   E    F    G    H   I    J  ...   P   Q  R    S  \
# Date                                                    ...
# 2019-01-01  526   3   9  0  66  472  260  116  45  202  ...  85  38  0   97
# 2019-01-02  504  11  10  0  57  472  157  108   3  223  ...  73   0  0   92
# 2019-01-03  499   0  10  0  42  475  154  104   0  199  ...  65  20  5   84
# 2019-01-04  504   0   7  0  57  464  149   83  17  198  ...  83  19  0   89
# 2019-01-05  499  15   9  0  31  466  159   84  14  219  ...  97  31  0  104
#
#              T  U   V    W   X   Y
# Date
# 2019-01-01  19  7   0  174  55  12
# 2019-01-02  45  0  14  132  65   8
# 2019-01-03  89  0   4  132  39   6
# 2019-01-04   0  0  14  143  57  20
# 2019-01-05   0  8  28   46  44  15
#
# [5 rows x 25 columns]

# %% [markdown]
# # 14. Area Plot All Sorted

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)
print(data.head())

# sort the data according to the sum of each column
data = data.reindex(data.sum().sort_values(ascending=False).index, axis=1)
print(data.head())

plt.figure(figsize=(8, 8))
# data.plot.area(figsize=(8, 8))
plt.stackplot(data.index, data.transpose())
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Stacked Product Sales', fontsize=20)
plt.legend(data.columns, loc=2)
plt.show()
# Out:
#               A   B   C  D   E    F    G    H   I    J  ...   P   Q  R    S  \
# Date                                                    ...
# 2019-01-01  526   3   9  0  66  472  260  116  45  202  ...  85  38  0   97
# 2019-01-02  504  11  10  0  57  472  157  108   3  223  ...  73   0  0   92
# 2019-01-03  499   0  10  0  42  475  154  104   0  199  ...  65  20  5   84
# 2019-01-04  504   0   7  0  57  464  149   83  17  198  ...  83  19  0   89
# 2019-01-05  499  15   9  0  31  466  159   84  14  219  ...  97  31  0  104
#
#              T  U   V    W   X   Y
# Date
# 2019-01-01  19  7   0  174  55  12
# 2019-01-02  45  0  14  132  65   8
# 2019-01-03  89  0   4  132  39   6
# 2019-01-04   0  0  14  143  57  20
# 2019-01-05   0  8  28   46  44  15
#
# [5 rows x 25 columns]
#               F    A    L    J    W    H    S    G   P   M  ...   Q   N   Y  \
# Date                                                        ...
# 2019-01-01  472  526  374  202  174  116   97  260  85  51  ...  38   6  12
# 2019-01-02  472  504  343  223  132  108   92  157  73  56  ...   0  22   8
# 2019-01-03  475  499  363  199  132  104   84  154  65  59  ...  20  17   6
# 2019-01-04  464  504  348  198  143   83   89  149  83  42  ...  19   2  20
# 2019-01-05  466  499  375  219   46   84  104  159  97  45  ...  31   0  15
#
#              V   I   B   C   K  U  R
# Date
# 2019-01-01   0  45   3   9  21  7  0
# 2019-01-02  14   3  11  10  24  0  0
# 2019-01-03   4   0   0  10   7  0  5
# 2019-01-04  14  17   0   7  15  0  0
# 2019-01-05  28  14  15   9  26  8  0
#
# [5 rows x 25 columns]

# %% [markdown]
# # 15. Area Plot Low Volume Sorted

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
pd.plotting.register_matplotlib_converters()
data.index = pd.to_datetime(data.index)
print(data.head())

# sort the data according to the sum of each column
data = data.reindex(data.sum().sort_values(ascending=False).index, axis=1)
print(data.head())

selected = ['D', 'E', 'M', 'O', 'P', 'T', 'X']

plt.figure(figsize=(8, 8))
# data.plot.area(figsize=(8, 8))
plt.stackplot(data.index, data[selected].transpose())
plt.xlabel('Date', fontsize=18)
plt.ylabel('Units sold', fontsize=18)
plt.title('Stacked Low Volume Product Sales', fontsize=20)
plt.legend(selected, loc=2)
plt.show()
# Out:
#               A   B   C  D   E    F    G    H   I    J  ...   P   Q  R    S  \
# Date                                                    ...
# 2019-01-01  526   3   9  0  66  472  260  116  45  202  ...  85  38  0   97
# 2019-01-02  504  11  10  0  57  472  157  108   3  223  ...  73   0  0   92
# 2019-01-03  499   0  10  0  42  475  154  104   0  199  ...  65  20  5   84
# 2019-01-04  504   0   7  0  57  464  149   83  17  198  ...  83  19  0   89
# 2019-01-05  499  15   9  0  31  466  159   84  14  219  ...  97  31  0  104
#
#              T  U   V    W   X   Y
# Date
# 2019-01-01  19  7   0  174  55  12
# 2019-01-02  45  0  14  132  65   8
# 2019-01-03  89  0   4  132  39   6
# 2019-01-04   0  0  14  143  57  20
# 2019-01-05   0  8  28   46  44  15
#
# [5 rows x 25 columns]
#               F    A    L    J    W    H    S    G   P   M  ...   Q   N   Y  \
# Date                                                        ...
# 2019-01-01  472  526  374  202  174  116   97  260  85  51  ...  38   6  12
# 2019-01-02  472  504  343  223  132  108   92  157  73  56  ...   0  22   8
# 2019-01-03  475  499  363  199  132  104   84  154  65  59  ...  20  17   6
# 2019-01-04  464  504  348  198  143   83   89  149  83  42  ...  19   2  20
# 2019-01-05  466  499  375  219   46   84  104  159  97  45  ...  31   0  15
#
#              V   I   B   C   K  U  R
# Date
# 2019-01-01   0  45   3   9  21  7  0
# 2019-01-02  14   3  11  10  24  0  0
# 2019-01-03   4   0   0  10   7  0  5
# 2019-01-04  14  17   0   7  15  0  0
# 2019-01-05  28  14  15   9  26  8  0
#
# [5 rows x 25 columns]
