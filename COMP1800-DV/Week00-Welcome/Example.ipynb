# %% [markdown]
# This is a Jupyter Notebook.
#
# This section contains markdown (just text).
#
# # This is a title
#
# **Here is some text in bold.**
#
# *Here is some text in italics.*
#
# ## This is a subtitle
#
# Here's a bullet point list
# * One
# * Two
# * Three
#
# Here's a numbered list
# 1. One
# 2. Two
# 3. Three
#
# Look at the "Raw" version (rather than "Markdown") to see how to format it.

# %%
# Here's some code
# Let's read in the data

import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('https://tinyurl.com/ChrisCoDV/Products/DailySales.csv', index_col=0)
data.index = pd.to_datetime(data.index)

# %% [markdown]
# There shouldn't be any output from the section above (unless something went wrong).

# %%
# Here's some more code
# Let's print out some details about the data

print(data.head())
print(data.describe())
# Out:
#               A   B   C  D   E    F    G    H   I    J  ...   P   Q  R    S  \
# Date                                                    ...
# 2019-01-01  526   3   9  0  66  472  260  116  45  202  ...  85  38  0   97
# 2019-01-02  504  11  10  0  57  472  157  108   3  223  ...  73   0  0   92
# 2019-01-03  499   0  10  0  42  475  154  104   0  199  ...  65  20  5   84
# 2019-01-04  504   0   7  0  57  464  149   83  17  198  ...  83  19  0   89
# 2019-01-05  499  15   9  0  31  466  159   84  14  219  ...  97  31  0  104
#
#              T  U   V    W   X   Y
# Date
# 2019-01-01  19  7   0  174  55  12
# 2019-01-02  45  0  14  132  65   8
# 2019-01-03  89  0   4  132  39   6
# 2019-01-04   0  0  14  143  57  20
# 2019-01-05   0  8  28   46  44  15
#
# [5 rows x 25 columns]
#                 A           B           C           D           E           F  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean   479.926027   12.298630    9.997260   51.156164   47.805479  483.457534
# std     17.244923    9.086648    1.939325   68.120653   12.758017    8.325882
# min    434.000000    0.000000    2.000000    0.000000    3.000000  464.000000
# 25%    467.000000    5.000000    9.000000    0.000000   39.000000  477.000000
# 50%    480.000000   12.000000   10.000000    0.000000   48.000000  483.000000
# 75%    492.000000   19.000000   11.000000  102.000000   56.000000  490.000000
# max    527.000000   45.000000   15.000000  243.000000   85.000000  506.000000
#
#                 G           H           I           J  ...           P  \
# count  365.000000  365.000000  365.000000  365.000000  ...  365.000000
# mean   123.816438  140.049315   14.380822  173.350685  ...   79.964384
# std     79.269444   27.586782   13.988817   18.246113  ...   10.140840
# min      0.000000   79.000000    0.000000  133.000000  ...   47.000000
# 25%     69.000000  120.000000    0.000000  160.000000  ...   73.000000
# 50%    147.000000  139.000000   12.000000  173.000000  ...   80.000000
# 75%    180.000000  160.000000   23.000000  187.000000  ...   86.000000
# max    284.000000  203.000000   57.000000  223.000000  ...  113.000000
#
#                 Q           R           S           T           U           V  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    17.183562    6.731507  126.643836   57.380822    8.408219   14.602740
# std     11.107950    4.238652   18.089346   39.821237    4.261434   11.743293
# min      0.000000    0.000000   83.000000    0.000000    0.000000    0.000000
# 25%      9.000000    3.000000  113.000000   27.000000    6.000000    4.000000
# 50%     17.000000    7.000000  126.000000   54.000000    8.000000   14.000000
# 75%     25.000000   10.000000  141.000000   84.000000   11.000000   23.000000
# max     55.000000   18.000000  168.000000  178.000000   19.000000   53.000000
#
#                 W           X           Y
# count  365.000000  365.000000  365.000000
# mean   146.621918   43.312329   14.980822
# std     40.172698   10.777010    5.794765
# min      0.000000   13.000000    0.000000
# 25%    122.000000   36.000000   11.000000
# 50%    150.000000   43.000000   15.000000
# 75%    173.000000   50.000000   19.000000
# max    254.000000   72.000000   29.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# We can see from the above that the data has 25 columns and each column has 365 rows (the count value).
#
# For column A, the max value is 527, the min is 434 and the average (mean) is 479.926.

# %%
data.plot.line()
plt.show()

# %% [markdown]
# That's a bit of a mess.
#
# Looks like we need a data explorer to help out.
